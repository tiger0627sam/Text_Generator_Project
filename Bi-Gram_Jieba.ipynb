# %%
import random

# %%
import os
import json

# 路徑設定為 "Data" 資料夾
folder_path = './Data/Jieba/'
files = os.listdir(folder_path)

# 初始化一個空的 bi-gram 列表
all_bi_grams = []

# 讀取資料夾中的所有檔案
allContent = []


for file in files:
    with open(folder_path + file, 'r', encoding='utf-8') as fileRead:
        tempFileJSON = json.load(fileRead)
        tempContentList = tempFileJSON['Context']
        allContent.extend(tempContentList)
        bi_grams = [(tempContentList[i], tempContentList[i + 1]) for i in range(len(tempContentList) - 1)]
        all_bi_grams.extend(bi_grams)
        
allContent[:10]
# Out:
# ['一', '这', '是', '我', '第三次', '到', '这里', '来', '屋里', '的']

# %%
all_bi_grams[:3000]
# Out:
# [('一', '这'),
#  ('这', '是'),
#  ('是', '我'),
#  ('我', '第三次'),
#  ('第三次', '到'),
#  ('到', '这里'),
#  ('这里', '来'),
#  ('来', '屋里'),
#  ('屋里', '的'),
#  ('的', '摆设'),
#  ('摆设', '还是'),
#  ('还是', '很'),
#  ('很', '陈旧'),
#  ('陈旧', '我'),
#  ('我', '局促不安'),
#  ('局促不安', '的'),
#  ('的', '站'),
#  ('站', '着'),
#  ('着', '双手'),
#  ('双手', '在'),
#  ('在', '胸前'),
#  ('胸前', '不停'),
#  ('不停', '的'),
#  ('的', '揉搓'),
#  ('揉搓', '着'),
#  ('着', '我'),
#  ('我', '我'),
#  ('我', '这次'),
#  ('这次', '我'),
#  ('我', '知道'),
#  ('知道', '你'),
#  ('你', '来'),
#  ('来', '是'),
#  ('是', '为了'),
#  ('为了', '什么'),
#  ('什么', '回去'),
#  ('回去', '吧'),
#  ('吧', '我'),
#  ('我', '对面'),
#  ('对面', '的'),
#  ('的', '那个'),
#  ('那个', '男人'),
#  ('男人', '说话'),
#  ('说话', '了'),
#  ('了', '声音'),
#  ('声音', '还是'),
#  ('还是', '很'),
#  ('很', '有力'),
#  ('有力', '可是'),
#  ('可是', '也'),
#  ('也', '只有'),
#  ('只有', '你'),
#  ('你', '了'),
#  ('了', '没'),
#  ('没', '办法'),
#  ('办法', '我'),
#  ('我', '也'),
#  ('也', '不能'),
#  ('不能', '清释'),
#  ('清释', '她'),
#  ('她', '的'),
#  ('的', '血液'),
#  ('血液', '你'),
#  ('你', '一定'),
#  ('一定', '会'),
#  ('会', '有'),
#  ('有', '办法'),
#  ('办法', '的'),
#  ('的', '我'),
#  ('我', '争取'),
#  ('争取', '着'),
#  ('着', '最后'),
#  ('最后', '一丝'),
#  ('一丝', '希望'),
#  ('希望', '你'),
#  ('你', '未免太'),
#  ('未免太', '小看'),
#  ('小看', '四世'),
#  ('四世', '的'),
#  ('的', '原血'),
#  ('原血', '了'),
#  ('了', '吧'),
#  ('吧', '那'),
#  ('那', '男人'),
#  ('男人', '有些'),
#  ('有些', '急'),
#  ('急', '了'),
#  ('了', '可'),
#  ('可', '除了'),
#  ('除了', '你'),
#  ('你', '我'),
#  ('我', '也'),
#  ('也', '不'),
#  ('不', '知道'),
#  ('知道', '去'),
#  ('去', '找'),
#  ('找', '谁'),
#  ('谁', '了'),
#  ('了', '你'),
#  ('你', '可是'),
#  ('可是', '我能'),
#  ('我能', '找到'),
#  ('找到', '的'),
#  ('的', '最'),
#  ('最', '厉害'),
#  ('厉害', '的'),
#  ('的', '血猎'),
#  ('血猎', '了'),
#  ('了', '出去'),
#  ('出去', '吧'),
#  ('吧', '男人'),
#  ('男人', '最后'),
#  ('最后', '说'),
#  ('说', '了'),
#  ('了', '一句'),
#  ('一句', '从'),
#  ('从', '大门'),
#  ('大门', '走'),
#  ('走', '出来'),
#  ('出来', '的'),
#  ('的', '时候'),
#  ('时候', '我'),
#  ('我', '感觉'),
#  ('感觉', '自己'),
#  ('自己', '快'),
#  ('快', '死'),
#  ('死', '掉'),
#  ('掉', '了'),
#  ('了', '屋里'),
#  ('屋里', '的'),
#  ('的', '气氛'),
#  ('气氛', '确实'),
#  ('确实', '很'),
#  ('很', '压抑'),
#  ('压抑', '该死'),
#  ('该死', '的'),
#  ('的', '吸血鬼'),
#  ('吸血鬼', '没用'),
#  ('没用', '的'),
#  ('的', '血猎'),
#  ('血猎', '我'),
#  ('我', '无力'),
#  ('无力', '的'),
#  ('的', '诅咒'),
#  ('诅咒', '着'),
#  ('着', '我'),
#  ('我', '自己'),
#  ('自己', '总会'),
#  ('总会', '有'),
#  ('有', '办法'),
#  ('办法', '的'),
#  ('的', '奥古斯特'),
#  ('奥古斯特', '等'),
#  ('等', '着'),
#  ('着', '我'),
#  ('我', '恨'),
#  ('恨', '恨'),
#  ('恨', '的'),
#  ('的', '说'),
#  ('说', '到'),
#  ('到', '奥古斯特'),
#  ('奥古斯特', '是'),
#  ('是', '一个'),
#  ('一个', '吸血鬼'),
#  ('吸血鬼', '他'),
#  ('他', '是'),
#  ('是', '四世'),
#  ('四世', '现存'),
#  ('现存', '唯一'),
#  ('唯一', '的'),
#  ('的', '四世'),
#  ('四世', '我'),
#  ('我', '是'),
#  ('是', '一个'),
#  ('一个', '血猎'),
#  ('血猎', '吸血鬼'),
#  ('吸血鬼', '猎手'),
#  ('猎手', '那'),
#  ('那', '男人'),
#  ('男人', '是'),
#  ('是', '我'),
#  ('我', '的'),
#  ('的', '老师'),
#  ('老师', '看来'),
#  ('看来', '对于'),
#  ('对于', '四世'),
#  ('四世', '我'),
#  ('我', '老师'),
#  ('老师', '和'),
#  ('和', '我'),
#  ('我', '都'),
#  ('都', '没有'),
#  ('没有', '办法'),
#  ('办法', '二'),
#  ('二', '我'),
#  ('我', '再次'),
#  ('再次', '站'),
#  ('站', '到'),
#  ('到', '117'),
#  ('117', '号'),
#  ('号', '门前'),
#  ('门前', '这里'),
#  ('这里', '是'),
#  ('是', '一栋'),
#  ('一栋', '大'),
#  ('大', '别墅'),
#  ('别墅', '墙壁'),
#  ('墙壁', '上爬'),
#  ('上爬', '满'),
#  ('满', '绿油油'),
#  ('绿油油', '的'),
#  ('的', '植物'),
#  ('植物', '连'),
#  ('连', '门上'),
#  ('门上', '都'),
#  ('都', '是'),
#  ('是', '正面'),
#  ('正面', '的'),
#  ('的', '墙上'),
#  ('墙上', '的'),
#  ('的', '窗户'),
#  ('窗户', '都'),
#  ('都', '被'),
#  ('被', '钉'),
#  ('钉', '上'),
#  ('上', '似乎'),
#  ('似乎', '连光'),
#  ('连光', '到'),
#  ('到', '这里'),
#  ('这里', '都'),
#  ('都', '被'),
#  ('被', '什么'),
#  ('什么', '东西'),
#  ('东西', '吞噬'),
#  ('吞噬', '了'),
#  ('了', '我'),
#  ('我', '推开'),
#  ('推开', '了'),
#  ('了', '门'),
#  ('门', '走'),
#  ('走', '了'),
#  ('了', '进去'),
#  ('进去', '这里'),
#  ('这里', '很'),
#  ('很', '阴冷'),
#  ('阴冷', '屋里'),
#  ('屋里', '很'),
#  ('很', '暗'),
#  ('暗', '几根'),
#  ('几根', '蜡烛'),
#  ('蜡烛', '在'),
#  ('在', '墙角'),
#  ('墙角', '的'),
#  ('的', '烛台'),
#  ('烛台', '上'),
#  ('上', '烧着'),
#  ('烧着', '两排'),
#  ('两排', '楼梯'),
#  ('楼梯', '通向'),
#  ('通向', '二楼'),
#  ('二楼', '楼梯'),
#  ('楼梯', '中间'),
#  ('中间', '一副'),
#  ('一副', '大'),
#  ('大', '油画'),
#  ('油画', '画中'),
#  ('画中', '的'),
#  ('的', '人'),
#  ('人', '笑'),
#  ('笑', '的'),
#  ('的', '很'),
#  ('很', '冷'),
#  ('冷', '奥古斯特'),
#  ('奥古斯特', '我'),
#  ('我', '对'),
#  ('对', '着'),
#  ('着', '油画'),
#  ('油画', '大喊'),
#  ('大喊', '我'),
#  ('我', '知道'),
#  ('知道', '你'),
#  ('你', '在'),
#  ('在', '她'),
#  ('她', '也'),
#  ('也', '在'),
#  ('在', '出来'),
#  ('出来', '我们'),
#  ('我们', '谈谈'),
#  ('谈谈', '谈'),
#  ('谈', '什么'),
#  ('什么', '小血猎'),
#  ('小血猎', '一顾'),
#  ('一顾', '温柔'),
#  ('温柔', '到'),
#  ('到', '极致'),
#  ('极致', '的'),
#  ('的', '声音'),
#  ('声音', '从'),
#  ('从', '虚无'),
#  ('虚无', '中'),
#  ('中', '传来'),
#  ('传来', '我'),
#  ('我', '知道'),
#  ('知道', '那'),
#  ('那', '是'),
#  ('是', '奥古斯特'),
#  ('奥古斯特', '的'),
#  ('的', '声音'),
#  ('声音', '你'),
#  ('你', '又'),
#  ('又', '不能'),
#  ('不能', '伤害'),
#  ('伤害', '到'),
#  ('到', '我'),
#  ('我', '所以'),
#  ('所以', '你'),
#  ('你', '想'),
#  ('想', '谈'),
#  ('谈', '的'),
#  ('的', '根本'),
#  ('根本', '没'),
#  ('没', '希望'),
#  ('希望', '放'),
#  ('放', '了'),
#  ('了', '她'),
#  ('她', '好'),
#  ('好', '吗'),
#  ('吗', '我求'),
#  ('我求', '你'),
#  ('你', '了'),
#  ('了', '我'),
#  ('我', '又'),
#  ('又', '一次'),
#  ('一次', '没骨气'),
#  ('没骨气', '了'),
#  ('了', '在'),
#  ('在', '老师'),
#  ('老师', '那次'),
#  ('那次', '也'),
#  ('也', '一样'),
#  ('一样', '谁'),
#  ('谁', '我'),
#  ('我', '知道'),
#  ('知道', '他'),
#  ('他', '明知故问'),
#  ('明知故问', '方凌'),
#  ('方凌', '哦'),
#  ('哦', '你'),
#  ('你', '说'),
#  ('说', '的'),
#  ('的', '一定'),
#  ('一定', '是'),
#  ('是', '凌'),
#  ('凌', '奥古斯特'),
#  ('奥古斯特', '她'),
#  ('她', '现在'),
#  ('现在', '是'),
#  ('是', '我'),
#  ('我', '的'),
#  ('的', '女人'),
#  ('女人', '她'),
#  ('她', '的'),
#  ('的', '血液'),
#  ('血液', '我'),
#  ('我', '喉咙'),
#  ('喉咙', '沙哑'),
#  ('沙哑', '放心'),
#  ('放心', '四世'),
#  ('四世', '的'),
#  ('的', '原血'),
#  ('原血', '没有'),
#  ('没有', '这么'),
#  ('这么', '快'),
#  ('快', '融合'),
#  ('融合', '的'),
#  ('的', '不过'),
#  ('不过', '在'),
#  ('在', '我'),
#  ('我', '的'),
#  ('的', '帮助'),
#  ('帮助', '下'),
#  ('下', '也'),
#  ('也', '快'),
#  ('快', '了'),
#  ('了', '现在'),
#  ('现在', '你'),
#  ('你', '知道'),
#  ('知道', '的'),
#  ('的', '够'),
#  ('够', '多'),
#  ('多', '了'),
#  ('了', '走'),
#  ('走', '吧'),
#  ('吧', '我'),
#  ('我', '让'),
#  ('让', '我'),
#  ('我', '在'),
#  ('在', '看看'),
#  ('看看', '她'),
#  ('她', '我'),
#  ('我', '乞求'),
#  ('乞求', '着'),
#  ('着', '当'),
#  ('当', '她'),
#  ('她', '完全'),
#  ('完全', '变成'),
#  ('变成', '血族'),
#  ('血族', '中'),
#  ('中', '的'),
#  ('的', '骄傲'),
#  ('骄傲', '的'),
#  ('的', '时候'),
#  ('时候', '她'),
#  ('她', '会'),
#  ('会', '去'),
#  ('去', '找'),
#  ('找', '你'),
#  ('你', '然后'),
#  ('然后', '奥古斯特'),
#  ('奥古斯特', '有'),
#  ('有', '一次'),
#  ('一次', '让'),
#  ('让', '我'),
#  ('我', '知道'),
#  ('知道', '我们'),
#  ('我们', '之间'),
#  ('之间', '的'),
#  ('的', '差距'),
#  ('差距', '他'),
#  ('他', '把'),
#  ('把', '我'),
#  ('我', '扔'),
#  ('扔', '出'),
#  ('出', '别墅'),
#  ('别墅', '我'),
#  ('我', '甚至'),
#  ('甚至', '都'),
#  ('都', '没有'),
#  ('没有', '看到'),
#  ('看到', '他'),
#  ('他', '的'),
#  ('的', '脸'),
#  ('脸', '三'),
#  ('三', '我'),
#  ('我', '从'),
#  ('从', '地'),
#  ('地', '上爬'),
#  ('上爬', '起来'),
#  ('起来', '低着头'),
#  ('低着头', '哭'),
#  ('哭', '了'),
#  ('了', '方凌'),
#  ('方凌', '我爱你'),
#  ('我爱你', '我'),
#  ('我', '对'),
#  ('对', '着'),
#  ('着', '117'),
#  ('117', '号'),
#  ('号', '别墅'),
#  ('别墅', '吼'),
#  ('吼', '着'),
#  ('着', '我'),
#  ('我', '要'),
#  ('要', '和'),
#  ('和', '你'),
#  ('你', '在'),
#  ('在', '一起'),
#  ('一起', '可'),
#  ('可', '别墅'),
#  ('别墅', '那边'),
#  ('那边', '没有'),
#  ('没有', '反应'),
#  ('反应', '我'),
#  ('我', '回家'),
#  ('回家', '走'),
#  ('走', '在'),
#  ('在', '街上'),
#  ('街上', '一个'),
#  ('一个', '人'),
#  ('人', '都'),
#  ('都', '没有'),
#  ('没有', '我边'),
#  ('我边', '走边'),
#  ('走边', '哭'),
#  ('哭', '我'),
#  ('我', '爱'),
#  ('爱', '她'),
#  ('她', '我'),
#  ('我', '是'),
#  ('是', '血猎'),
#  ('血猎', '可'),
#  ('可', '她'),
#  ('她', '马上'),
#  ('马上', '要'),
#  ('要', '成为'),
#  ('成为', '吸血鬼'),
#  ('吸血鬼', '了'),
#  ('了', '我'),
#  ('我', '还'),
#  ('还', '得'),
#  ('得', '去'),
#  ('去', '找'),
#  ('找', '他'),
#  ('他', '那个'),
#  ('那个', '让'),
#  ('让', '我'),
#  ('我', '成为'),
#  ('成为', '血猎'),
#  ('血猎', '的'),
#  ('的', '男人'),
#  ('男人', '我'),
#  ('我', '的'),
#  ('的', '老师'),
#  ('老师', '这'),
#  ('这', '是'),
#  ('是', '我'),
#  ('我', '第四次'),
#  ('第四次', '来'),
#  ('来', '了'),
#  ('了', '那'),
#  ('那', '男人'),
#  ('男人', '还'),
#  ('还', '在'),
#  ('在', '单人'),
#  ('单人', '沙发'),
#  ('沙发', '坐'),
#  ('坐', '着'),
#  ('着', '他'),
#  ('他', '都'),
#  ('都', '没有'),
#  ('没有', '换'),
#  ('换', '过'),
#  ('过', '地方'),
#  ('地方', '你'),
#  ('你', '去'),
#  ('去', '找'),
#  ('找', '奥古斯特'),
#  ('奥古斯特', '了'),
#  ('了', '吧'),
#  ('吧', '他'),
#  ('他', '说'),
#  ('说', '我'),
#  ('我', '点点头'),
#  ('点点头', '我该'),
#  ('我该', '怎么办'),
#  ('怎么办', '没'),
#  ('没', '办法'),
#  ('办法', '即使'),
#  ('即使', '你'),
#  ('你', '杀'),
#  ('杀', '了'),
#  ('了', '奥古斯特'),
#  ('奥古斯特', '方凌'),
#  ('方凌', '还是'),
#  ('还是', '不会'),
#  ('不会', '变'),
#  ('变', '回'),
#  ('回', '人类'),
#  ('人类', '血液'),
#  ('血液', '是'),
#  ('是', '独立'),
#  ('独立', '存在'),
#  ('存在', '的'),
#  ('的', '他'),
#  ('他', '摇'),
#  ('摇', '了'),
#  ('了', '摇头'),
#  ('摇头', '可'),
#  ('可', '我'),
#  ('我', '还'),
#  ('还', '爱'),
#  ('爱', '她'),
#  ('她', '我'),
#  ('我', '想'),
#  ('想', '和'),
#  ('和', '她'),
#  ('她', '在'),
#  ('在', '一起'),
#  ('一起', '我头'),
#  ('我头', '低'),
#  ('低', '得'),
#  ('得', '更'),
#  ('更', '低'),
#  ('低', '了'),
#  ('了', '可'),
#  ('可', '声音'),
#  ('声音', '却'),
#  ('却', '大'),
#  ('大', '了'),
#  ('了', '那'),
#  ('那', '没'),
#  ('没', '办法'),
#  ('办法', '了'),
#  ('了', '你'),
#  ('你', '是'),
#  ('是', '血'),
#  ('血', '猎猎'),
#  ('猎猎', '杀'),
#  ('杀', '吸血鬼'),
#  ('吸血鬼', '是'),
#  ('是', '你'),
#  ('你', '的'),
#  ('的', '天职'),
#  ('天职', '他'),
#  ('他', '语气'),
#  ('语气', '透出'),
#  ('透出', '点'),
#  ('点', '骄傲'),
#  ('骄傲', '好'),
#  ('好', '吧'),
#  ('吧', '好'),
#  ('好', '吧'),
#  ('吧', '我'),
#  ('我', '转身'),
#  ('转身', '离开'),
#  ('离开', '除非'),
#  ('除非', '你'),
#  ('你', '也'),
#  ('也', '边成'),
#  ('边成', '吸血鬼'),
#  ('吸血鬼', '他'),
#  ('他', '突然'),
#  ('突然', '小声'),
#  ('小声', '说'),
#  ('说', '我'),
#  ('我', '回头'),
#  ('回头', '知道'),
#  ('知道', '了'),
#  ('了', '眼神'),
#  ('眼神', '中'),
#  ('中', '充满'),
#  ('充满', '兴奋'),
#  ('兴奋', '四'),
#  ('四', '我'),
#  ('我', '决定'),
#  ('决定', '再'),
#  ('再', '去'),
#  ('去', '找'),
#  ('找', '奥古斯特'),
#  ('奥古斯特', '我'),
#  ('我', '再次'),
#  ('再次', '推开'),
#  ('推开', '了'),
#  ('了', '117'),
#  ('117', '号'),
#  ('号', '的'),
#  ('的', '门'),
#  ('门', '这次'),
#  ('这次', '我'),
#  ('我', '到'),
#  ('到', '了'),
#  ('了', '2'),
#  ('2', '楼'),
#  ('楼', '我'),
#  ('我', '看到'),
#  ('看到', '奥古斯特'),
#  ('奥古斯特', '在'),
#  ('在', '走廊'),
#  ('走廊', '尽头'),
#  ('尽头', '的'),
#  ('的', '沙发'),
#  ('沙发', '上'),
#  ('上', '坐'),
#  ('坐', '着'),
#  ('着', '像'),
#  ('像', '老师'),
#  ('老师', '一样'),
#  ('一样', '棕色'),
#  ('棕色', '的'),
#  ('的', '卷发'),
#  ('卷发', '盖住'),
#  ('盖住', '了'),
#  ('了', '耳朵'),
#  ('耳朵', '他'),
#  ('他', '脸色'),
#  ('脸色', '很白'),
#  ('很白', '嘴唇'),
#  ('嘴唇', '却'),
#  ('却', '很'),
#  ('很', '红'),
#  ('红', '我'),
#  ('我', '走'),
#  ('走', '了'),
#  ('了', '过去'),
#  ('过去', '鞠'),
#  ('鞠', '了'),
#  ('了', '一躬'),
#  ('一躬', '为了'),
#  ('为了', '让'),
#  ('让', '他'),
#  ('他', '感觉'),
#  ('感觉', '到'),
#  ('到', '我'),
#  ('我', '的'),
#  ('的', '礼貌'),
#  ('礼貌', '奥古斯特'),
#  ('奥古斯特', '我'),
#  ('我', '谦卑'),
#  ('谦卑', '的'),
#  ('的', '说'),
#  ('说', '到'),
#  ('到', '毕竟'),
#  ('毕竟', '我'),
#  ('我', '有事'),
#  ('有事', '求'),
#  ('求', '他'),
#  ('他', '什么'),
#  ('什么', '事'),
#  ('事', '刚才'),
#  ('刚才', '没有'),
#  ('没有', '说完'),
#  ('说完', '吗'),
#  ('吗', '他'),
#  ('他', '看'),
#  ('看', '我'),
#  ('我', '一眼'),
#  ('一眼', '眼神'),
#  ('眼神', '很'),
#  ('很', '不屑'),
#  ('不屑', '我'),
#  ('我', '乞求'),
#  ('乞求', '你'),
#  ('你', '将'),
#  ('将', '我'),
#  ('我', '变为'),
#  ('变为', '吸血鬼'),
#  ('吸血鬼', '我'),
#  ('我', '将'),
#  ('将', '腰直'),
#  ('腰直', '了'),
#  ('了', '起来'),
#  ('起来', '刚才'),
#  ('刚才', '弯'),
#  ('弯', '的'),
#  ('的', '很'),
#  ('很', '酸'),
#  ('酸', '你'),
#  ('你', '这'),
#  ('这', '卑微'),
#  ('卑微', '的'),
#  ('的', '人类'),
#  ('人类', '想'),
#  ('想', '成为'),
#  ('成为', '我'),
#  ('我', '高贵'),
#  ('高贵', '的'),
#  ('的', '血族'),
#  ('血族', '中'),
#  ('中', '的'),
#  ('的', '一员'),
#  ('一员', '吗'),
#  ('吗', '不'),
#  ('不', '可能'),
#  ('可能', '的'),
#  ('的', '你'),
#  ('你', '是'),
#  ('是', '血猎'),
#  ('血猎', '我'),
#  ('我', '看不起'),
#  ('看不起', '你'),
#  ('你', '你'),
#  ('你', '手上'),
#  ('手上', '占满'),
#  ('占满', '了'),
#  ('了', '血族'),
#  ('血族', '的'),
#  ('的', '鲜血'),
#  ('鲜血', '他'),
#  ('他', '的'),
#  ('的', '脸色'),
#  ('脸色', '更加'),
#  ('更加', '苍白'),
#  ('苍白', '了'),
#  ('了', '嘴唇'),
#  ('嘴唇', '红'),
#  ('红', '的'),
#  ('的', '更是'),
#  ('更是', '妖艳'),
#  ('妖艳', '告诉'),
#  ('告诉', '我'),
#  ('我', '为什么'),
#  ('为什么', '想'),
#  ('想', '成为'),
#  ('成为', '血族'),
#  ('血族', '他'),
#  ('他', '似乎'),
#  ('似乎', '冷静'),
#  ('冷静', '了'),
#  ('了', '一些'),
#  ('一些', '我'),
#  ('我', '爱方凌'),
#  ('爱方凌', '我'),
#  ('我', '要'),
#  ('要', '和'),
#  ('和', '她'),
#  ('她', '在'),
#  ('在', '一起'),
#  ('一起', '就'),
#  ('就', '这么'),
#  ('这么', '简单'),
#  ('简单', '奥古斯特'),
#  ('奥古斯特', '眉头'),
#  ('眉头', '皱'),
#  ('皱', '了'),
#  ('了', '起来'),
#  ('起来', '就'),
#  ('就', '这么'),
#  ('这么', '简单'),
#  ('简单', '我'),
#  ('我', '说'),
#  ('说', '那'),
#  ('那', '你'),
#  ('你', '回去'),
#  ('回去', '吧'),
#  ('吧', '不'),
#  ('不', '可能'),
#  ('可能', '没有'),
#  ('没有', '机会'),
#  ('机会', '了'),
#  ('了', '吗'),
#  ('吗', '我'),
#  ('我', '尽量'),
#  ('尽量', '是'),
#  ('是', '自己'),
#  ('自己', '看起来'),
#  ('看起来', '更是'),
#  ('更是', '谦卑'),
#  ('谦卑', '奥古斯特'),
#  ('奥古斯特', '没有'),
#  ('没有', '说话'),
#  ('说话', '却'),
#  ('却', '走进'),
#  ('走进', '了'),
#  ('了', '阴暗'),
#  ('阴暗', '里'),
#  ('里', '我'),
#  ('我', '又'),
#  ('又', '失败'),
#  ('失败', '了'),
#  ('了', '这次'),
#  ('这次', '真该'),
#  ('真该', '回家'),
#  ('回家', '了'),
#  ('了', '五'),
#  ('五', '回到'),
#  ('回到', '家里'),
#  ('家里', '我'),
#  ('我', '躺'),
#  ('躺', '在'),
#  ('在', '床上'),
#  ('床上', '手里'),
#  ('手里', '把玩'),
#  ('把玩', '着'),
#  ('着', '银'),
#  ('银', '叉子'),
#  ('叉子', '那'),
#  ('那', '是'),
#  ('是', '我'),
#  ('我', '昨天晚上'),
#  ('昨天晚上', '吃饭'),
#  ('吃饭', '用'),
#  ('用', '的'),
#  ('的', '我'),
#  ('我', '想着'),
#  ('想着', '刚才'),
#  ('刚才', '奥古斯特'),
#  ('奥古斯特', '的话'),
#  ('的话', '我'),
#  ('我', '是'),
#  ('是', '血猎'),
#  ('血猎', '可'),
#  ('可', '我'),
#  ('我', '不是'),
#  ('不是', '自愿'),
#  ('自愿', '的'),
#  ('的', '要不是'),
#  ('要不是', '那'),
#  ('那', '该死'),
#  ('该死', '的'),
#  ('的', '男人'),
#  ('男人', '谁'),
#  ('谁', '知道'),
#  ('知道', '血猎'),
#  ('血猎', '是'),
#  ('是', '个'),
#  ('个', '什么'),
#  ('什么', '东西'),
#  ('东西', '即使'),
#  ('即使', '我'),
#  ('我', '成为'),
#  ('成为', '血猎'),
#  ('血猎', '我'),
#  ('我', '也'),
#  ('也', '没有'),
#  ('没有', '杀过'),
#  ('杀过', '吸血鬼'),
#  ('吸血鬼', '可方凌'),
#  ('可方凌', '我'),
#  ('我', '想'),
#  ('想', '和'),
#  ('和', '你'),
#  ('你', '在'),
#  ('在', '一起'),
#  ('一起', '谁'),
#  ('谁', '帮'),
#  ('帮', '我'),
#  ('我', '我'),
#  ('我', '为'),
#  ('为', '我'),
#  ('我', '自己'),
#  ('自己', '感到'),
#  ('感到', '悲哀'),
#  ('悲哀', '我'),
#  ('我', '没有'),
#  ('没有', '一点'),
#  ('一点', '能力'),
#  ('能力', '我救'),
#  ('我救', '不了'),
#  ('不了', '方凌清释'),
#  ('方凌清释', '不了'),
#  ('不了', '奥古斯特'),
#  ('奥古斯特', '的'),
#  ('的', '原血'),
#  ('原血', '我'),
#  ('我', '让'),
#  ('让', '奥古斯特'),
#  ('奥古斯特', '看不起'),
#  ('看不起', '我'),
#  ('我', '成不了'),
#  ('成不了', '吸血鬼'),
#  ('吸血鬼', '我'),
#  ('我', '不能'),
#  ('不能', '和'),
#  ('和', '方凌'),
#  ('方凌', '在'),
#  ('在', '一起'),
#  ('一起', '我'),
#  ('我', '没用'),
#  ('没用', '闭上眼'),
#  ('闭上眼', '让'),
#  ('让', '眼泪'),
#  ('眼泪', '从'),
#  ('从', '自己'),
#  ('自己', '的'),
#  ('的', '眼眸'),
#  ('眼眸', '中'),
#  ('中', '滑落'),
#  ('滑落', '突然'),
#  ('突然', '我'),
#  ('我', '感觉'),
#  ('感觉', '有人'),
#  ('有人', '吻'),
#  ('吻', '我'),
#  ('我', '的'),
#  ('的', '眼帘'),
#  ('眼帘', '是'),
#  ('是', '凌'),
#  ('凌', '我'),
#  ('我', '睁开眼'),
#  ('睁开眼', '没错'),
#  ('没错', '是'),
#  ('是', '方凌'),
#  ('方凌', '我'),
#  ('我', '坐'),
#  ('坐', '起来'),
#  ('起来', '握住'),
#  ('握住', '她'),
#  ('她', '的'),
#  ('的', '手'),
#  ('手', '她'),
#  ('她', '脸色'),
#  ('脸色', '很白'),
#  ('很白', '是'),
#  ('是', '一种'),
#  ('一种', '很'),
#  ('很', '吓人'),
#  ('吓人', '的'),
#  ('的', '白'),
#  ('白', '我'),
#  ('我', '知道'),
#  ('知道', '那'),
#  ('那', '是'),
#  ('是', '吸收'),
#  ('吸收', '原血'),
#  ('原血', '的'),
#  ('的', '作用'),
#  ('作用', '你'),
#  ('你', '回来'),
#  ('回来', '了'),
#  ('了', '吗'),
#  ('吗', '没有'),
#  ('没有', '奥古斯特'),
#  ('奥古斯特', '让'),
#  ('让', '我'),
#  ('我', '回来'),
#  ('回来', '看看'),
#  ('看看', '他'),
#  ('他', '说'),
#  ('说', '你'),
#  ('你', '还'),
#  ...]

# %%
# 初始化 bi-gram 頻率和單詞頻率字典
bi_gram_freq = {}
word_freq = {}
V = len(set(allContent))  # 詞彙的大小（詞彙中不重複單詞的數量

# %%
# 初始化 word_freq 字典，每個單詞的起始頻率為 V（考慮到每個單詞後都可以跟著 V 種不同的單詞）
for word in set(allContent):
    word_freq[word] = V

# %%
# 計算未平滑的 bi-gram 頻率
for bi_gram in all_bi_grams:
    bi_gram_freq[bi_gram] = bi_gram_freq.get(bi_gram, 0) + 1
    word_freq[bi_gram[0]] += 1

# %%
bi_gram_probs = {bi_gram: freq / word_freq[bi_gram[0]] for bi_gram, freq in bi_gram_freq.items()}

# %%
# 文本生成
import random

current_word = '鬼'
Output = []
Output.append(current_word)

for _ in range(2000):  # 生成500個單詞的文本
    next_words = [pair[1] for pair in bi_gram_probs.keys() if pair[0] == current_word]
    next_word_probs = [bi_gram_probs[(current_word, next_word)] for next_word in next_words]
    
    # 確保有可選的後續單詞
    if next_words and next_word_probs:
        current_word = random.choices(next_words, weights=next_word_probs)[0]
        Output.append(current_word)
        print(current_word, end=' ')
        
    else:
        break  # 如果沒有後續單詞，則終止循環
# Out:
# 昨夜 鬼物 一 裤子 免得 冲撞 了 回忆 中 不住 摔倒 阴将 的 时候 已经 杀 了 果然 是 谁 这么 闭塞 不过 福利 好事儿 的 那个 美丽 的 闺女 进 大厅 再次 见到 了 母亲 拍打着 房门 紧闭 着 一块 跳绳 呀 那 把 梳子 好象 是 在 王明 的 东西长 到 他 家里 还有 那天 竟然 长出 皱纹 就 会 强制 戒毒所 办手续 到 了 陈通 有没有 看见 他 摸了摸 男友 过来 了 走 去 北京 再 来 了 有 冤 啊 把 食指 和 土 啊 砸 在 农村 也 变成 这么 多 了 晚上 飞 又 在 被 烧成 残废 在 他 会 毫无 征兆 地 打了个 哈欠 起身 的 最 恐怖 的 时候 总像 有条 两三步 的 全身 麻醉 因为 平时 密密麻麻 地 注入 油桶 里 其他 一些 箱子 十年 前 一周 以后 母亲 摘下 眼镜 用手 按 常理 更何况 还是 有些 困了 觉得 其实 虚得 一点 都 不 年 正月 营 的 一下 掼 只见 晓宇 只是 被 撞 到 三人刚 上去 能装 六发 弹而 这儿 了 漫长 的 食欲 高成 有 上 高枝 就 因 心脏病 好多年 了 第二天 给与 评价 她 还是 热 的 插进 了 下来 以后 再说 什么 邪 出租车 发生 的 试验品 是 我 当时 的 感觉 桑上 说 什么 时候 曾 离开 了 我 很 失望 和 肢解 其状 如 雪花 突然 想 这些 动物 身上 他 想不到 的 面孔 乞丐 的 人 看在眼里 痛 了 现在 还是 瘦 脸上 略 尖 就 拍 他 的 也 爱 我 顿时 疯 的 腰 有些 苍白 我 还 能 记起 父母亲 生 和 他 的 待客 人 仅仅 为了 监视 了 他 问 了 我 和 一辆 奔驰 牌 我 的 状况 明显 的 水 打棒 的确 是 受欢迎 的 家里 值钱 的 跟 朋友 也 挺 出 这样 他 松 了 不能 指望 它 只 灰色 她 从 上班族 了 我 只 听 我 努力 的 蛛丝马迹 hellip 陈林 则 独个儿 陪 她 妈 便 领 回家 接下来 我们 真急 了 下来 啊 哼 了 老伴 心脏病发 死 前 就 下山 去 松园 路 牌子 上 的 心坎 蓦地 窜出 病房 里 刚好 在 很久以前 奶奶 说 大姐 好汉不吃眼前亏 先 卸妆 晓峰 意料 的 脸 便 连 吓袋 铁锅 里面 住 了 的 珠宝 呢 罗 太太 为此 感到恐惧 但是 如果 不是 单纯 的 男孩 最后 只能 防御 它 送到 医院 全市 人心惶惶 十多个 孩子 吧 我 缩 在 这个 晚上 party 员 那些 冰 啊 怎么 象鬼 一样 停 我 摸 着 粗气 仔细 数 那些 蜘蛛 静静 站 在 这 病 她 补 漏洞 可 不想 知道 这碗 第一次 听 不到 第二个 梦境 中 她 到底 是 苏霖 跑 越 想 快逃 快逃 然后 又 不能 再 一次 全国性 红卫兵 接待站 对 自己 的 原因 的 看家本领 了 进去 没想 开始 每天晚上 都 除去 了 对 审讯 了 朋友 请 了 上来 乌云 吞没 . 后来 发生 什么 鬼怪 邪祟 的 外耳道 在 杀死 小雨 家 烟熏火燎 的 样子 眼睛 睁开 了 两分钟 他 只觉 耳朵 跑 啊 许诺 不管 是 住 上 喘 不 知道 为什么 这么 一说 方尹 说 我 什么 都 堆 在 考场 这 活儿 也 没法 自由 几天 因为 天色 逐渐 消逝 后 一个 很 高 他 为 8 个人 掉下去 砸 在 一个 念头 吓呆了 脑子 也 在 这 宅子 本是 毛 同志 你 是不是 很 郁闷 也 非常 惨不忍睹 刺客 一些 很 感动 的 鬼故事 而 变成 了 最 喜欢 捉弄 自己 是 那么 冤枉 死 人 也 有 礼貌 的 泥土 的 脸上 看不出 她 猛然间 一阵 疼痛 立消 若 是 你 把 他 又 至 美有 最 艰苦 每每 想起 时 就是 干 了 家门 那 块 牛肉 五花肉 的 金项链 在 大 眼看 就要 毕业 的 姥姥 坐 稳定 之后 在 南京 卫戍司令 长官 不让 他 面前 有 一张 黑色 的 庄稼 长得 就 可以 相依 相伴 的 是 我 也 没 碰到 有缘人 嘛 总要 收获 与 城想 看看 那个 完全 凝固 着 向 后拉去 浅蓝 面前 脸色苍白 他 连忙 伸手 一 初出茅芦 的 沙发 上 突然 变得 犀利 的 怪兽 似的 嚎叫声 已经 扭曲 错位 了 定 才 从门 后 的 皮肤 用腻 了 还 兀自 睁 着眼 我 守口如瓶 绝不 应 和 其他 几只 乌鸦 飞过来 将 他 结结巴巴 的 双亲 的 脸影 没有 哭 而且 都 带 着 往 一边 想 了 队长 连忙 扯 下 了 蛊 而 回 什么 都 回不来 了 看丽娜 诡异 便 要 去 图书馆 中 作法 让 许太太 的 大多数 男生 高高 隆起 分明 多 大 摆钟 我 的 父母亲 的 尸体 忽然 没有 做过 检查 完 了 几次 结果 只 觉得 他 面前 的 奖章 啊 那 一阵阵 发紧 就 转回 屋冲 赵 太太 就 怕 惊到 了 过来 就是 乔家 的 笑容 一只 手 知道 你 说 那 一年 也 不管 多大 效果 也 出事 啦 我们 有 可能 是 好事 有时 我 跳 到 的 东西 后 我 不 乐 了 吧 相信 那个 家 在 搜索 牛岛贞雄 万万 没有 朋友 们 说完 王芳 说 对 你 否则 我 感到 很 旧 的 好 价钱 葡萄园 的 肉体 又 一次 比 坟地 那 几亩 地 坐在 石榴树 但是 有 46 : 大半夜 的 房子 里 的 金巴狗 为此 实现 了 用 的 地方 了 一种 莫名 地 说 师傅 吧 众人 吓 得 大叫 其余 几人 没有 看 摄像机 的 目光 来回 地 落到 地上 死死 攥 着 我 见鬼 了 只有 一丛 茎 叶 编成 送给 那 是 你 真的 遭遇 意外 年庭 凡 将 那个 女人 就 不会 有人 接班 交接班 来 让 我 还 没 人 买卖 六 发现 的 超级 划算 嘛 他 只要 目的 一是 抽 她 吻 林子 文 沉沉 梦魇 状态 以 597 分 30 岁 的 身体 叫 了 一大跳 惊醒 她 昨天 发生 了 四楼 的 黑影 就要 变 吊死鬼 走后 他 呆呆地 站 在 椅子 上 了 也 没有 出现 了 变得 直接 奔 去 要 了 突然 停止 了 她 面前 浮现 出 一会 下课 啊 只 爱 听 警察 送到 村 的 说 什么 而且 交谈 你 别忘记 了 浑身 锈迹 斑驳 不说 十分 难 为 他 不想 记起 是 我 一秒钟 门开 了 她 背 或 低头 看书 来 你 不 影响 姑娘 在 脑中 拖住 了 薛浩 的 人 啊 那 请 出鼓 奋力 地 说道 爸爸 不会 蠢到 把 你 能 完成 了 钱 老达 说 过 两个 长 指甲 都 是 7 米 水 喝完 后 第一个 属于 让 他 有 一条 血路 锣鼓 可 还 没 回答 道 一个 教室 看到 车身 颠簸 加上 爱 吃 早餐 后 我们 结婚 哈哈哈 ! 这个 宝宝 一直 追随着 奶奶 数千元 的 爬 了 王 自力 手机 , 便 开始 人们 终于 骷髅头 就 被 禁足 唉 怕 的 重要 的 想法 安慰 我们 现在 打 一个 传说 那 店家 送到 这里 糊纸 人 一起 买 不能 将 右侧 后面 人 的 黑色 的 客套话 然后 她 但 随着 时间 出来 我 身旁 她 的 不 懂 英语 说 罢 于是 苑小青 心细 的 我 受够了 命运 的 祖先 是 一个 女孩子 啊 你 你 娶 的 时间 到 了 自己 有 没 在家 上班 但 也 在 一群 恶鬼 给 他 的 身边 王尧 对于 鲶鱼 的 但是 印象 了 她 神色 我 真的 有 这样 吧 妈妈 杀鱼 煲 了 得不偿失 了 陈唐 在 门口 推开 门 打开 一个 大胆 才 明白 原来 的 可是 看看 一副 很 晚 都 在 雷子 的 转变 了 他 走 多一会 又 出现 了 一趟 但 对 着 那朵 碧莲 交谈 的 他 说 的 大海 或 坎坷 陰陽师 的 一样 外出 提议 用 王母 的 一些 隐隐 的 人 绑架 自己 灭 了 开心 吗 为什么 要 到 醒来 的 胃里 的 拉 着 一只 黑色 的 事 山神庙 他 接过 钞票 所以 大伟 给 他 自知 时日无多 的 三个 人 的 事 可 他们 在 现实 中是 她 也 借机 下 波光粼粼 的 九小仙 的话 也 想不起来 林昕 清楚 又 看 了 身上 传来 一个 小贩 在 当下 与 村里 的 世界 也 不 打算 将 有位 哦 于是 当 他 我 才 会 说好 一会儿 房门 厨房 工作 二话不说 便 消失 第二天 长辈 在 这家 独特 裂纹 我 刚才 看见 了 大批 血液 场景 才 明白 赵龙 的 尽头 时有 一夜 的 人 眼睛 我 跟着 沈聪 的 一动 一静 我 租 的 药 看来 那 小孩 , 于是 袖子 你 再 一问 女人 的 新 A2 呃 呃 恩 进去 我 才 明白 S 君 S 君 直说 吧 于是 雷子 经常 剧烈 的 吧 那个 小女孩 在 除夕 到处 熟悉 忽然 非常 浓烈 的 控制 刚才 出现 方式 化解 的 皮肤 也 比 一天 肖 云天 枪 打 在 农村 一户 人家 刚 说 什么 是 供给 饿鬼 其 不备 给 他 想 跟 他们 还是 活在 这个 金子 , 嘴里 一直 没换 为 之 极 后悔 我 那 被 好似 就 在 阴冷 了 她 却 正是 有 什么 好 的 东西 都 说 了 吧 这个 连环 女案 只是 一片 两个 老人 了 自然 欲言又止 似是 触到 了 所有 能 看到 他们 去 尸 臭味儿 和 她 什么 东西 她 我们 今晚 我 与 大 吕 老板 仔细 看 一下 她 用 ...

# %%
print(Output)
# Out:
# ['鬼', '昨夜', '鬼物', '一', '裤子', '免得', '冲撞', '了', '回忆', '中', '不住', '摔倒', '阴将', '的', '时候', '已经', '杀', '了', '果然', '是', '谁', '这么', '闭塞', '不过', '福利', '好事儿', '的', '那个', '美丽', '的', '闺女', '进', '大厅', '再次', '见到', '了', '母亲', '拍打着', '房门', '紧闭', '着', '一块', '跳绳', '呀', '那', '把', '梳子', '好象', '是', '在', '王明', '的', '东西长', '到', '他', '家里', '还有', '那天', '竟然', '长出', '皱纹', '就', '会', '强制', '戒毒所', '办手续', '到', '了', '陈通', '有没有', '看见', '他', '摸了摸', '男友', '过来', '了', '走', '去', '北京', '再', '来', '了', '有', '冤', '啊', '把', '食指', '和', '土', '啊', '砸', '在', '农村', '也', '变成', '这么', '多', '了', '晚上', '飞', '又', '在', '被', '烧成', '残废', '在', '他', '会', '毫无', '征兆', '地', '打了个', '哈欠', '起身', '的', '最', '恐怖', '的', '时候', '总像', '有条', '两三步', '的', '全身', '麻醉', '因为', '平时', '密密麻麻', '地', '注入', '油桶', '里', '其他', '一些', '箱子', '十年', '前', '一周', '以后', '母亲', '摘下', '眼镜', '用手', '按', '常理', '更何况', '还是', '有些', '困了', '觉得', '其实', '虚得', '一点', '都', '不', '年', '正月', '营', '的', '一下', '掼', '只见', '晓宇', '只是', '被', '撞', '到', '三人刚', '上去', '能装', '六发', '弹而', '这儿', '了', '漫长', '的', '食欲', '高成', '有', '上', '高枝', '就', '因', '心脏病', '好多年', '了', '第二天', '给与', '评价', '她', '还是', '热', '的', '插进', '了', '下来', '以后', '再说', '什么', '邪', '出租车', '发生', '的', '试验品', '是', '我', '当时', '的', '感觉', '桑上', '说', '什么', '时候', '曾', '离开', '了', '我', '很', '失望', '和', '肢解', '其状', '如', '雪花', '突然', '想', '这些', '动物', '身上', '他', '想不到', '的', '面孔', '乞丐', '的', '人', '看在眼里', '痛', '了', '现在', '还是', '瘦', '脸上', '略', '尖', '就', '拍', '他', '的', '也', '爱', '我', '顿时', '疯', '的', '腰', '有些', '苍白', '我', '还', '能', '记起', '父母亲', '生', '和', '他', '的', '待客', '人', '仅仅', '为了', '监视', '了', '他', '问', '了', '我', '和', '一辆', '奔驰', '牌', '我', '的', '状况', '明显', '的', '水', '打棒', '的确', '是', '受欢迎', '的', '家里', '值钱', '的', '跟', '朋友', '也', '挺', '出', '这样', '他', '松', '了', '不能', '指望', '它', '只', '灰色', '她', '从', '上班族', '了', '我', '只', '听', '我', '努力', '的', '蛛丝马迹', 'hellip', '陈林', '则', '独个儿', '陪', '她', '妈', '便', '领', '回家', '接下来', '我们', '真急', '了', '下来', '啊', '哼', '了', '老伴', '心脏病发', '死', '前', '就', '下山', '去', '松园', '路', '牌子', '上', '的', '心坎', '蓦地', '窜出', '病房', '里', '刚好', '在', '很久以前', '奶奶', '说', '大姐', '好汉不吃眼前亏', '先', '卸妆', '晓峰', '意料', '的', '脸', '便', '连', '吓袋', '铁锅', '里面', '住', '了', '的', '珠宝', '呢', '罗', '太太', '为此', '感到恐惧', '但是', '如果', '不是', '单纯', '的', '男孩', '最后', '只能', '防御', '它', '送到', '医院', '全市', '人心惶惶', '十多个', '孩子', '吧', '我', '缩', '在', '这个', '晚上', 'party', '员', '那些', '冰', '啊', '怎么', '象鬼', '一样', '停', '我', '摸', '着', '粗气', '仔细', '数', '那些', '蜘蛛', '静静', '站', '在', '这', '病', '她', '补', '漏洞', '可', '不想', '知道', '这碗', '第一次', '听', '不到', '第二个', '梦境', '中', '她', '到底', '是', '苏霖', '跑', '越', '想', '快逃', '快逃', '然后', '又', '不能', '再', '一次', '全国性', '红卫兵', '接待站', '对', '自己', '的', '原因', '的', '看家本领', '了', '进去', '没想', '开始', '每天晚上', '都', '除去', '了', '对', '审讯', '了', '朋友', '请', '了', '上来', '乌云', '吞没', '.', '后来', '发生', '什么', '鬼怪', '邪祟', '的', '外耳道', '在', '杀死', '小雨', '家', '烟熏火燎', '的', '样子', '眼睛', '睁开', '了', '两分钟', '他', '只觉', '耳朵', '跑', '啊', '许诺', '不管', '是', '住', '上', '喘', '不', '知道', '为什么', '这么', '一说', '方尹', '说', '我', '什么', '都', '堆', '在', '考场', '这', '活儿', '也', '没法', '自由', '几天', '因为', '天色', '逐渐', '消逝', '后', '一个', '很', '高', '他', '为', '8', '个人', '掉下去', '砸', '在', '一个', '念头', '吓呆了', '脑子', '也', '在', '这', '宅子', '本是', '毛', '同志', '你', '是不是', '很', '郁闷', '也', '非常', '惨不忍睹', '刺客', '一些', '很', '感动', '的', '鬼故事', '而', '变成', '了', '最', '喜欢', '捉弄', '自己', '是', '那么', '冤枉', '死', '人', '也', '有', '礼貌', '的', '泥土', '的', '脸上', '看不出', '她', '猛然间', '一阵', '疼痛', '立消', '若', '是', '你', '把', '他', '又', '至', '美有', '最', '艰苦', '每每', '想起', '时', '就是', '干', '了', '家门', '那', '块', '牛肉', '五花肉', '的', '金项链', '在', '大', '眼看', '就要', '毕业', '的', '姥姥', '坐', '稳定', '之后', '在', '南京', '卫戍司令', '长官', '不让', '他', '面前', '有', '一张', '黑色', '的', '庄稼', '长得', '就', '可以', '相依', '相伴', '的', '是', '我', '也', '没', '碰到', '有缘人', '嘛', '总要', '收获', '与', '城想', '看看', '那个', '完全', '凝固', '着', '向', '后拉去', '浅蓝', '面前', '脸色苍白', '他', '连忙', '伸手', '一', '初出茅芦', '的', '沙发', '上', '突然', '变得', '犀利', '的', '怪兽', '似的', '嚎叫声', '已经', '扭曲', '错位', '了', '定', '才', '从门', '后', '的', '皮肤', '用腻', '了', '还', '兀自', '睁', '着眼', '我', '守口如瓶', '绝不', '应', '和', '其他', '几只', '乌鸦', '飞过来', '将', '他', ...

# %%
# 將列表中的單詞連接成一個字符串
combined_text = ''.join(Output)

# 指定檔案名和路徑
output_path = './Results/Bi-Gram_Jieba_V3.txt'

# 寫入文件
with open(output_path, 'w', encoding='utf-8') as file:
    file.write(combined_text)

print("done")
# Out:
# done

# %% [markdown]
# ---

# %%
# # 計算 bi-gram 頻率並應用 Add-one smoothing
# bi_gram_freq = {}
# V = len(set(allContent))  # 詞彙的大小（詞彙中不重複單詞的數量）
# for bi_gram in all_bi_grams:
#     bi_gram_freq[bi_gram] = bi_gram_freq.get(bi_gram, 0) + 1

# %%
# # 應用 Add-one smoothing 到每個頻率
# for bi_gram in bi_gram_freq:
#     bi_gram_freq[bi_gram] += 1

# %%
# # 計算概率
# bi_gram_probs = {}
# for bi_gram, freq in bi_gram_freq.items():
#     word, _ = bi_gram
#     word_freq = sum(1 for bg in all_bi_grams if bg[0] == word) + V
#     bi_gram_probs[bi_gram] = freq / word_freq

# %%
# # 文本生成
# current_word = '吸血鬼'
# for _ in range(100):  # 生成100個單詞的文本
#     next_words = [pair[1] for pair in bi_gram_probs.keys() if pair[0] == current_word]
#     next_word_probs = [bi_gram_probs[(current_word, next_word)] for next_word in next_words]
    
#     # 確保有可選的後續單詞
#     if next_words and next_word_probs:
#         current_word = random.choices(next_words, weights=next_word_probs)[0]
#         print(current_word, end=' ')
#     else:
#         break  # 如果沒有後續單詞，則終止循環

# %%
# # 假設 text 是一個包含大量文本的字符串
# words =   # 分割文本成單詞列表
# bi_grams = [(words[i], words[i + 1]) for i in range(len(words) - 1)]  # 創建 bi-gram 列表

# 建立詞彙表
# vocabulary = set(allContent)  
# word_to_index = {word: i for i, word in enumerate(vocabulary)}

# # 計算 bi-gram 頻率
# bi_gram_freq = {}
# for bi_gram in all_bi_grams:
#     if bi_gram in bi_gram_freq:
#         bi_gram_freq[bi_gram] += 1
#     else:
#         bi_gram_freq[bi_gram] = 1

# # 計算概率
# bi_gram_probs = {}
# for bi_gram, freq in bi_gram_freq.items():
#     word, next_word = bi_gram
#     bi_gram_probs[bi_gram] = freq / allContent.count(word)

# # 文本生成
# current_word = '吸血鬼'
# for _ in range(200):  # 生成100個單詞的文本
#     next_words = [pair[1] for pair in bi_gram_probs.keys() if pair[0] == current_word]
#     next_word_probs = [bi_gram_probs[(current_word, next_word)] for next_word in next_words]
#     current_word = random.choices(next_words, weights=next_word_probs)[0]
#     print(current_word, end=' ')
