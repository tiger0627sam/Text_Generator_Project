# %%
import random

# %%
import os
import json

# 路徑設定為 "Data" 資料夾
folder_path = './Data/Origin/'
files = os.listdir(folder_path)

# 初始化一個空的 bi-gram 列表
all_bi_grams = []

# 讀取資料夾中的所有檔案
allContent = []


for file in files:
    with open(folder_path + file, 'r', encoding='utf-8') as fileRead:
        tempFileJSON = json.load(fileRead)
        tempContentList = tempFileJSON['Context']
        allContent.extend(tempContentList)
        bi_grams = [(tempContentList[i], tempContentList[i + 1]) for i in range(len(tempContentList) - 1)]
        all_bi_grams.extend(bi_grams)
        
allContent[:10]
# Out:
# ['\u3000', '\u3000', '一', '\u3000', '\u3000', '这', '是', '我', '第', '三']

# %%
all_bi_grams[:3000]
# Out:
# [('\u3000', '\u3000'),
#  ('\u3000', '一'),
#  ('一', '\u3000'),
#  ('\u3000', '\u3000'),
#  ('\u3000', '这'),
#  ('这', '是'),
#  ('是', '我'),
#  ('我', '第'),
#  ('第', '三'),
#  ('三', '次'),
#  ('次', '到'),
#  ('到', '这'),
#  ('这', '里'),
#  ('里', '来'),
#  ('来', '，'),
#  ('，', '屋'),
#  ('屋', '里'),
#  ('里', '的'),
#  ('的', '摆'),
#  ('摆', '设'),
#  ('设', '还'),
#  ('还', '是'),
#  ('是', '很'),
#  ('很', '陈'),
#  ('陈', '旧'),
#  ('旧', '。'),
#  ('。', '我'),
#  ('我', '局'),
#  ('局', '促'),
#  ('促', '不'),
#  ('不', '安'),
#  ('安', '的'),
#  ('的', '站'),
#  ('站', '着'),
#  ('着', '，'),
#  ('，', '双'),
#  ('双', '手'),
#  ('手', '在'),
#  ('在', '胸'),
#  ('胸', '前'),
#  ('前', '不'),
#  ('不', '停'),
#  ('停', '的'),
#  ('的', '揉'),
#  ('揉', '搓'),
#  ('搓', '着'),
#  ('着', '“'),
#  ('“', '我'),
#  ('我', '…'),
#  ('…', '…'),
#  ('…', '我'),
#  ('我', '这'),
#  ('这', '次'),
#  ('次', '…'),
#  ('…', '…'),
#  ('…', '”'),
#  ('”', '“'),
#  ('“', '我'),
#  ('我', '知'),
#  ('知', '道'),
#  ('道', '你'),
#  ('你', '来'),
#  ('来', '是'),
#  ('是', '为'),
#  ('为', '了'),
#  ('了', '什'),
#  ('什', '么'),
#  ('么', '，'),
#  ('，', '回'),
#  ('回', '去'),
#  ('去', '吧'),
#  ('吧', '…'),
#  ('…', '…'),
#  ('…', '”'),
#  ('”', '我'),
#  ('我', '对'),
#  ('对', '面'),
#  ('面', '的'),
#  ('的', '那'),
#  ('那', '个'),
#  ('个', '男'),
#  ('男', '人'),
#  ('人', '说'),
#  ('说', '话'),
#  ('话', '了'),
#  ('了', '，'),
#  ('，', '声'),
#  ('声', '音'),
#  ('音', '还'),
#  ('还', '是'),
#  ('是', '很'),
#  ('很', '有'),
#  ('有', '力'),
#  ('力', '。'),
#  ('。', '“'),
#  ('“', '可'),
#  ('可', '是'),
#  ('是', '也'),
#  ('也', '只'),
#  ('只', '有'),
#  ('有', '你'),
#  ('你', '了'),
#  ('了', '。'),
#  ('。', '”'),
#  ('”', '“'),
#  ('“', '没'),
#  ('没', '办'),
#  ('办', '法'),
#  ('法', '，'),
#  ('，', '我'),
#  ('我', '也'),
#  ('也', '不'),
#  ('不', '能'),
#  ('能', '清'),
#  ('清', '释'),
#  ('释', '她'),
#  ('她', '的'),
#  ('的', '血'),
#  ('血', '液'),
#  ('液', '。'),
#  ('。', '”'),
#  ('”', '“'),
#  ('“', '你'),
#  ('你', '一'),
#  ('一', '定'),
#  ('定', '会'),
#  ('会', '有'),
#  ('有', '办'),
#  ('办', '法'),
#  ('法', '的'),
#  ('的', '。'),
#  ('。', '”'),
#  ('”', '我'),
#  ('我', '争'),
#  ('争', '取'),
#  ('取', '着'),
#  ('着', '最'),
#  ('最', '后'),
#  ('后', '一'),
#  ('一', '丝'),
#  ('丝', '希'),
#  ('希', '望'),
#  ('望', '，'),
#  ('，', '“'),
#  ('“', '你'),
#  ('你', '未'),
#  ('未', '免'),
#  ('免', '太'),
#  ('太', '小'),
#  ('小', '看'),
#  ('看', '四'),
#  ('四', '世'),
#  ('世', '的'),
#  ('的', '原'),
#  ('原', '血'),
#  ('血', '了'),
#  ('了', '吧'),
#  ('吧', '。'),
#  ('。', '”'),
#  ('”', '那'),
#  ('那', '男'),
#  ('男', '人'),
#  ('人', '有'),
#  ('有', '些'),
#  ('些', '急'),
#  ('急', '了'),
#  ('了', '。'),
#  ('。', '“'),
#  ('“', '可'),
#  ('可', '，'),
#  ('，', '除'),
#  ('除', '了'),
#  ('了', '你'),
#  ('你', '，'),
#  ('，', '我'),
#  ('我', '也'),
#  ('也', '不'),
#  ('不', '知'),
#  ('知', '道'),
#  ('道', '去'),
#  ('去', '找'),
#  ('找', '谁'),
#  ('谁', '了'),
#  ('了', '，'),
#  ('，', '你'),
#  ('你', '可'),
#  ('可', '是'),
#  ('是', '我'),
#  ('我', '能'),
#  ('能', '找'),
#  ('找', '到'),
#  ('到', '的'),
#  ('的', '最'),
#  ('最', '厉'),
#  ('厉', '害'),
#  ('害', '的'),
#  ('的', '血'),
#  ('血', '猎'),
#  ('猎', '了'),
#  ('了', '。'),
#  ('。', '”'),
#  ('”', '“'),
#  ('“', '出'),
#  ('出', '去'),
#  ('去', '吧'),
#  ('吧', '。'),
#  ('。', '”'),
#  ('”', '男'),
#  ('男', '人'),
#  ('人', '最'),
#  ('最', '后'),
#  ('后', '说'),
#  ('说', '了'),
#  ('了', '一'),
#  ('一', '句'),
#  ('句', '。'),
#  ('。', '\u3000'),
#  ('\u3000', '\u3000'),
#  ('\u3000', '从'),
#  ('从', '大'),
#  ('大', '门'),
#  ('门', '走'),
#  ('走', '出'),
#  ('出', '来'),
#  ('来', '的'),
#  ('的', '时'),
#  ('时', '候'),
#  ('候', '，'),
#  ('，', '我'),
#  ('我', '感'),
#  ('感', '觉'),
#  ('觉', '自'),
#  ('自', '己'),
#  ('己', '快'),
#  ('快', '死'),
#  ('死', '掉'),
#  ('掉', '了'),
#  ('了', '，'),
#  ('，', '屋'),
#  ('屋', '里'),
#  ('里', '的'),
#  ('的', '气'),
#  ('气', '氛'),
#  ('氛', '确'),
#  ('确', '实'),
#  ('实', '很'),
#  ('很', '压'),
#  ('压', '抑'),
#  ('抑', '。'),
#  ('。', '“'),
#  ('“', '该'),
#  ('该', '死'),
#  ('死', '的'),
#  ('的', '吸'),
#  ('吸', '血'),
#  ('血', '鬼'),
#  ('鬼', '，'),
#  ('，', '没'),
#  ('没', '用'),
#  ('用', '的'),
#  ('的', '血'),
#  ('血', '猎'),
#  ('猎', '。'),
#  ('。', '”'),
#  ('”', '我'),
#  ('我', '无'),
#  ('无', '力'),
#  ('力', '的'),
#  ('的', '诅'),
#  ('诅', '咒'),
#  ('咒', '着'),
#  ('着', '。'),
#  ('。', '“'),
#  ('“', '我'),
#  ('我', '自'),
#  ('自', '己'),
#  ('己', '总'),
#  ('总', '会'),
#  ('会', '有'),
#  ('有', '办'),
#  ('办', '法'),
#  ('法', '的'),
#  ('的', '，'),
#  ('，', '奥'),
#  ('奥', '古'),
#  ('古', '斯'),
#  ('斯', '特'),
#  ('特', '，'),
#  ('，', '等'),
#  ('等', '着'),
#  ('着', '。'),
#  ('。', '”'),
#  ('”', '我'),
#  ('我', '恨'),
#  ('恨', '恨'),
#  ('恨', '的'),
#  ('的', '说'),
#  ('说', '到'),
#  ('到', '。'),
#  ('。', '\u3000'),
#  ('\u3000', '\u3000'),
#  ('\u3000', '奥'),
#  ('奥', '古'),
#  ('古', '斯'),
#  ('斯', '特'),
#  ('特', '是'),
#  ('是', '一'),
#  ('一', '个'),
#  ('个', '吸'),
#  ('吸', '血'),
#  ('血', '鬼'),
#  ('鬼', '。'),
#  ('。', '他'),
#  ('他', '是'),
#  ('是', '四'),
#  ('四', '世'),
#  ('世', '，'),
#  ('，', '现'),
#  ('现', '存'),
#  ('存', '唯'),
#  ('唯', '一'),
#  ('一', '的'),
#  ('的', '四'),
#  ('四', '世'),
#  ('世', '。'),
#  ('。', '\u3000'),
#  ('\u3000', '\u3000'),
#  ('\u3000', '我'),
#  ('我', '是'),
#  ('是', '一'),
#  ('一', '个'),
#  ('个', '血'),
#  ('血', '猎'),
#  ('猎', '。'),
#  ('。', '吸'),
#  ('吸', '血'),
#  ('血', '鬼'),
#  ('鬼', '猎'),
#  ('猎', '手'),
#  ('手', '。'),
#  ('。', '那'),
#  ('那', '男'),
#  ('男', '人'),
#  ('人', '是'),
#  ('是', '我'),
#  ('我', '的'),
#  ('的', '老'),
#  ('老', '师'),
#  ('师', '。'),
#  ('。', '看'),
#  ('看', '来'),
#  ('来', '，'),
#  ('，', '对'),
#  ('对', '于'),
#  ('于', '四'),
#  ('四', '世'),
#  ('世', '。'),
#  ('。', '我'),
#  ('我', '老'),
#  ('老', '师'),
#  ('师', '和'),
#  ('和', '我'),
#  ('我', '都'),
#  ('都', '…'),
#  ('…', '…'),
#  ('…', '没'),
#  ('没', '有'),
#  ('有', '办'),
#  ('办', '法'),
#  ('法', '。'),
#  ('。', '\u3000'),
#  ('\u3000', '\u3000'),
#  ('\u3000', '二'),
#  ('二', '\u3000'),
#  ('\u3000', '\u3000'),
#  ('\u3000', '我'),
#  ('我', '再'),
#  ('再', '次'),
#  ('次', '站'),
#  ('站', '到'),
#  ('到', '1'),
#  ('1', '1'),
#  ('1', '7'),
#  ('7', '号'),
#  ('号', '门'),
#  ('门', '前'),
#  ('前', '。'),
#  ('。', '这'),
#  ('这', '里'),
#  ('里', '是'),
#  ('是', '一'),
#  ('一', '栋'),
#  ('栋', '大'),
#  ('大', '别'),
#  ('别', '墅'),
#  ('墅', '：'),
#  ('：', '墙'),
#  ('墙', '壁'),
#  ('壁', '上'),
#  ('上', '爬'),
#  ('爬', '满'),
#  ('满', '绿'),
#  ('绿', '油'),
#  ('油', '油'),
#  ('油', '的'),
#  ('的', '植'),
#  ('植', '物'),
#  ('物', '，'),
#  ('，', '连'),
#  ('连', '门'),
#  ('门', '上'),
#  ('上', '都'),
#  ('都', '是'),
#  ('是', '，'),
#  ('，', '正'),
#  ('正', '面'),
#  ('面', '的'),
#  ('的', '墙'),
#  ('墙', '上'),
#  ('上', '的'),
#  ('的', '窗'),
#  ('窗', '户'),
#  ('户', '都'),
#  ('都', '被'),
#  ('被', '钉'),
#  ('钉', '上'),
#  ('上', '。'),
#  ('。', '似'),
#  ('似', '乎'),
#  ('乎', '连'),
#  ('连', '光'),
#  ('光', '到'),
#  ('到', '这'),
#  ('这', '里'),
#  ('里', '都'),
#  ('都', '被'),
#  ('被', '什'),
#  ('什', '么'),
#  ('么', '东'),
#  ('东', '西'),
#  ('西', '吞'),
#  ('吞', '噬'),
#  ('噬', '了'),
#  ('了', '。'),
#  ('。', '我'),
#  ('我', '推'),
#  ('推', '开'),
#  ('开', '了'),
#  ('了', '门'),
#  ('门', '，'),
#  ('，', '走'),
#  ('走', '了'),
#  ('了', '进'),
#  ('进', '去'),
#  ('去', '：'),
#  ('：', '这'),
#  ('这', '里'),
#  ('里', '很'),
#  ('很', '阴'),
#  ('阴', '冷'),
#  ('冷', '，'),
#  ('，', '屋'),
#  ('屋', '里'),
#  ('里', '很'),
#  ('很', '暗'),
#  ('暗', '，'),
#  ('，', '几'),
#  ('几', '根'),
#  ('根', '蜡'),
#  ('蜡', '烛'),
#  ('烛', '在'),
#  ('在', '墙'),
#  ('墙', '角'),
#  ('角', '的'),
#  ('的', '烛'),
#  ('烛', '台'),
#  ('台', '上'),
#  ('上', '烧'),
#  ('烧', '着'),
#  ('着', '。'),
#  ('。', '两'),
#  ('两', '排'),
#  ('排', '楼'),
#  ('楼', '梯'),
#  ('梯', '通'),
#  ('通', '向'),
#  ('向', '二'),
#  ('二', '楼'),
#  ('楼', '，'),
#  ('，', '楼'),
#  ('楼', '梯'),
#  ('梯', '中'),
#  ('中', '间'),
#  ('间', '，'),
#  ('，', '一'),
#  ('一', '副'),
#  ('副', '大'),
#  ('大', '油'),
#  ('油', '画'),
#  ('画', '，'),
#  ('，', '画'),
#  ('画', '中'),
#  ('中', '的'),
#  ('的', '人'),
#  ('人', '笑'),
#  ('笑', '的'),
#  ('的', '很'),
#  ('很', '冷'),
#  ('冷', '。'),
#  ('。', '“'),
#  ('“', '奥'),
#  ('奥', '古'),
#  ('古', '斯'),
#  ('斯', '特'),
#  ('特', '，'),
#  ('，', '”'),
#  ('”', '我'),
#  ('我', '对'),
#  ('对', '着'),
#  ('着', '油'),
#  ('油', '画'),
#  ('画', '大'),
#  ('大', '喊'),
#  ('喊', '“'),
#  ('“', '我'),
#  ('我', '知'),
#  ('知', '道'),
#  ('道', '你'),
#  ('你', '在'),
#  ('在', '她'),
#  ('她', '也'),
#  ('也', '在'),
#  ('在', '。'),
#  ('。', '出'),
#  ('出', '来'),
#  ('来', '，'),
#  ('，', '我'),
#  ('我', '们'),
#  ('们', '谈'),
#  ('谈', '谈'),
#  ('谈', '。'),
#  ('。', '”'),
#  ('”', '\u3000'),
#  ('\u3000', '\u3000'),
#  ('\u3000', '“'),
#  ('“', '谈'),
#  ('谈', '什'),
#  ('什', '么'),
#  ('么', '，'),
#  ('，', '小'),
#  ('小', '血'),
#  ('血', '猎'),
#  ('猎', '。'),
#  ('。', '”'),
#  ('”', '一'),
#  ('一', '顾'),
#  ('顾', '温'),
#  ('温', '柔'),
#  ('柔', '到'),
#  ('到', '极'),
#  ('极', '致'),
#  ('致', '的'),
#  ('的', '声'),
#  ('声', '音'),
#  ('音', '从'),
#  ('从', '虚'),
#  ('虚', '无'),
#  ('无', '中'),
#  ('中', '传'),
#  ('传', '来'),
#  ('来', '，'),
#  ('，', '我'),
#  ('我', '知'),
#  ('知', '道'),
#  ('道', '那'),
#  ('那', '是'),
#  ('是', '奥'),
#  ('奥', '古'),
#  ('古', '斯'),
#  ('斯', '特'),
#  ('特', '的'),
#  ('的', '声'),
#  ('声', '音'),
#  ('音', '“'),
#  ('“', '你'),
#  ('你', '又'),
#  ('又', '不'),
#  ('不', '能'),
#  ('能', '伤'),
#  ('伤', '害'),
#  ('害', '到'),
#  ('到', '我'),
#  ('我', '，'),
#  ('，', '所'),
#  ('所', '以'),
#  ('以', '你'),
#  ('你', '想'),
#  ('想', '谈'),
#  ('谈', '的'),
#  ('的', '根'),
#  ('根', '本'),
#  ('本', '没'),
#  ('没', '希'),
#  ('希', '望'),
#  ('望', '。'),
#  ('。', '”'),
#  ('”', '“'),
#  ('“', '放'),
#  ('放', '了'),
#  ('了', '她'),
#  ('她', '，'),
#  ('，', '好'),
#  ('好', '吗'),
#  ('吗', '，'),
#  ('，', '我'),
#  ('我', '求'),
#  ('求', '你'),
#  ('你', '了'),
#  ('了', '。'),
#  ('。', '”'),
#  ('”', '我'),
#  ('我', '又'),
#  ('又', '一'),
#  ('一', '次'),
#  ('次', '没'),
#  ('没', '骨'),
#  ('骨', '气'),
#  ('气', '了'),
#  ('了', '，'),
#  ('，', '在'),
#  ('在', '老'),
#  ('老', '师'),
#  ('师', '那'),
#  ('那', '次'),
#  ('次', '也'),
#  ('也', '一'),
#  ('一', '样'),
#  ('样', '。'),
#  ('。', '“'),
#  ('“', '谁'),
#  ('谁', '?'),
#  ('?', '”'),
#  ('”', '我'),
#  ('我', '知'),
#  ('知', '道'),
#  ('道', '他'),
#  ('他', '明'),
#  ('明', '知'),
#  ('知', '故'),
#  ('故', '问'),
#  ('问', '。'),
#  ('。', '“'),
#  ('“', '方'),
#  ('方', '凌'),
#  ('凌', '。'),
#  ('。', '”'),
#  ('”', '“'),
#  ('“', '哦'),
#  ('哦', '，'),
#  ('，', '你'),
#  ('你', '说'),
#  ('说', '的'),
#  ('的', '一'),
#  ('一', '定'),
#  ('定', '是'),
#  ('是', '凌'),
#  ('凌', '-'),
#  ('-', '奥'),
#  ('奥', '古'),
#  ('古', '斯'),
#  ('斯', '特'),
#  ('特', '，'),
#  ('，', '她'),
#  ('她', '现'),
#  ('现', '在'),
#  ('在', '是'),
#  ('是', '我'),
#  ('我', '的'),
#  ('的', '女'),
#  ('女', '人'),
#  ('人', '。'),
#  ('。', '”'),
#  ('”', '“'),
#  ('“', '她'),
#  ('她', '的'),
#  ('的', '血'),
#  ('血', '液'),
#  ('液', '…'),
#  ('…', '…'),
#  ('…', '”'),
#  ('”', '我'),
#  ('我', '喉'),
#  ('喉', '咙'),
#  ('咙', '沙'),
#  ('沙', '哑'),
#  ('哑', '。'),
#  ('。', '“'),
#  ('“', '放'),
#  ('放', '心'),
#  ('心', '，'),
#  ('，', '四'),
#  ('四', '世'),
#  ('世', '的'),
#  ('的', '原'),
#  ('原', '血'),
#  ('血', '没'),
#  ('没', '有'),
#  ('有', '这'),
#  ('这', '么'),
#  ('么', '快'),
#  ('快', '融'),
#  ('融', '合'),
#  ('合', '的'),
#  ('的', '，'),
#  ('，', '不'),
#  ('不', '过'),
#  ('过', '在'),
#  ('在', '我'),
#  ('我', '的'),
#  ('的', '帮'),
#  ('帮', '助'),
#  ('助', '下'),
#  ('下', '也'),
#  ('也', '快'),
#  ('快', '了'),
#  ('了', '，'),
#  ('，', '现'),
#  ('现', '在'),
#  ('在', '你'),
#  ('你', '知'),
#  ('知', '道'),
#  ('道', '的'),
#  ('的', '够'),
#  ('够', '多'),
#  ('多', '了'),
#  ('了', '，'),
#  ('，', '走'),
#  ('走', '吧'),
#  ('吧', '。'),
#  ('。', '”'),
#  ('”', '“'),
#  ('“', '我'),
#  ('我', '…'),
#  ('…', '…'),
#  ('…', '让'),
#  ('让', '我'),
#  ('我', '在'),
#  ('在', '看'),
#  ('看', '看'),
#  ('看', '她'),
#  ('她', '…'),
#  ('…', '…'),
#  ('…', '”'),
#  ('”', '我'),
#  ('我', '乞'),
#  ('乞', '求'),
#  ('求', '着'),
#  ('着', '。'),
#  ('。', '“'),
#  ('“', '当'),
#  ('当', '她'),
#  ('她', '完'),
#  ('完', '全'),
#  ('全', '变'),
#  ('变', '成'),
#  ('成', '血'),
#  ('血', '族'),
#  ('族', '中'),
#  ('中', '的'),
#  ('的', '骄'),
#  ('骄', '傲'),
#  ('傲', '的'),
#  ('的', '时'),
#  ('时', '候'),
#  ('候', '，'),
#  ('，', '她'),
#  ('她', '会'),
#  ('会', '去'),
#  ('去', '找'),
#  ('找', '你'),
#  ('你', '。'),
#  ('。', '”'),
#  ('”', '然'),
#  ('然', '后'),
#  ('后', '奥'),
#  ('奥', '古'),
#  ('古', '斯'),
#  ('斯', '特'),
#  ('特', '有'),
#  ('有', '一'),
#  ('一', '次'),
#  ('次', '让'),
#  ('让', '我'),
#  ('我', '知'),
#  ('知', '道'),
#  ('道', '我'),
#  ('我', '们'),
#  ('们', '之'),
#  ('之', '间'),
#  ('间', '的'),
#  ('的', '差'),
#  ('差', '距'),
#  ('距', '，'),
#  ('，', '他'),
#  ('他', '把'),
#  ('把', '我'),
#  ('我', '扔'),
#  ('扔', '出'),
#  ('出', '别'),
#  ('别', '墅'),
#  ('墅', '，'),
#  ('，', '我'),
#  ('我', '甚'),
#  ('甚', '至'),
#  ('至', '都'),
#  ('都', '没'),
#  ('没', '有'),
#  ('有', '看'),
#  ('看', '到'),
#  ('到', '他'),
#  ('他', '的'),
#  ('的', '脸'),
#  ('脸', '。'),
#  ('。', '\u3000'),
#  ('\u3000', '\u3000'),
#  ('\u3000', '三'),
#  ('三', '\u3000'),
#  ('\u3000', '\u3000'),
#  ('\u3000', '我'),
#  ('我', '从'),
#  ('从', '地'),
#  ('地', '上'),
#  ('上', '爬'),
#  ('爬', '起'),
#  ('起', '来'),
#  ('来', '，'),
#  ('，', '低'),
#  ('低', '着'),
#  ('着', '头'),
#  ('头', '，'),
#  ('，', '哭'),
#  ('哭', '了'),
#  ('了', '，'),
#  ('，', '“'),
#  ('“', '方'),
#  ('方', '凌'),
#  ('凌', '，'),
#  ('，', '我'),
#  ('我', '爱'),
#  ('爱', '你'),
#  ('你', '。'),
#  ('。', '”'),
#  ('”', '我'),
#  ('我', '对'),
#  ('对', '着'),
#  ('着', '1'),
#  ('1', '1'),
#  ('1', '7'),
#  ('7', '号'),
#  ('号', '别'),
#  ('别', '墅'),
#  ('墅', '吼'),
#  ('吼', '着'),
#  ('着', '，'),
#  ('，', '“'),
#  ('“', '我'),
#  ('我', '要'),
#  ('要', '和'),
#  ('和', '你'),
#  ('你', '在'),
#  ('在', '一'),
#  ('一', '起'),
#  ('起', '。'),
#  ('。', '”'),
#  ('”', '，'),
#  ('，', '可'),
#  ('可', '别'),
#  ('别', '墅'),
#  ('墅', '那'),
#  ('那', '边'),
#  ('边', '没'),
#  ('没', '有'),
#  ('有', '反'),
#  ('反', '应'),
#  ('应', '。'),
#  ('。', '\u3000'),
#  ('\u3000', '\u3000'),
#  ('\u3000', '我'),
#  ('我', '回'),
#  ('回', '家'),
#  ('家', '。'),
#  ('。', '走'),
#  ('走', '在'),
#  ('在', '街'),
#  ('街', '上'),
#  ('上', '，'),
#  ('，', '一'),
#  ('一', '个'),
#  ('个', '人'),
#  ('人', '都'),
#  ('都', '没'),
#  ('没', '有'),
#  ('有', '，'),
#  ('，', '我'),
#  ('我', '边'),
#  ('边', '走'),
#  ('走', '边'),
#  ('边', '哭'),
#  ('哭', '。'),
#  ('。', '我'),
#  ('我', '爱'),
#  ('爱', '她'),
#  ('她', '，'),
#  ('，', '我'),
#  ('我', '是'),
#  ('是', '血'),
#  ('血', '猎'),
#  ('猎', '，'),
#  ('，', '可'),
#  ('可', '她'),
#  ('她', '马'),
#  ('马', '上'),
#  ('上', '要'),
#  ('要', '成'),
#  ('成', '为'),
#  ('为', '吸'),
#  ('吸', '血'),
#  ('血', '鬼'),
#  ('鬼', '了'),
#  ('了', '。'),
#  ('。', '我'),
#  ('我', '还'),
#  ('还', '得'),
#  ('得', '去'),
#  ('去', '找'),
#  ('找', '他'),
#  ('他', '，'),
#  ('，', '那'),
#  ('那', '个'),
#  ('个', '让'),
#  ('让', '我'),
#  ('我', '成'),
#  ('成', '为'),
#  ('为', '血'),
#  ('血', '猎'),
#  ('猎', '的'),
#  ('的', '男'),
#  ('男', '人'),
#  ('人', '，'),
#  ('，', '我'),
#  ('我', '的'),
#  ('的', '老'),
#  ('老', '师'),
#  ('师', '。'),
#  ('。', '\u3000'),
#  ('\u3000', '\u3000'),
#  ('\u3000', '这'),
#  ('这', '是'),
#  ('是', '我'),
#  ('我', '第'),
#  ('第', '四'),
#  ('四', '次'),
#  ('次', '来'),
#  ('来', '了'),
#  ('了', '，'),
#  ('，', '那'),
#  ('那', '男'),
#  ('男', '人'),
#  ('人', '还'),
#  ('还', '在'),
#  ('在', '单'),
#  ('单', '人'),
#  ('人', '沙'),
#  ('沙', '发'),
#  ('发', '坐'),
#  ('坐', '着'),
#  ('着', '，'),
#  ('，', '他'),
#  ('他', '都'),
#  ('都', '没'),
#  ('没', '有'),
#  ('有', '换'),
#  ('换', '过'),
#  ('过', '地'),
#  ('地', '方'),
#  ('方', '，'),
#  ('，', '“'),
#  ('“', '你'),
#  ('你', '去'),
#  ('去', '找'),
#  ('找', '奥'),
#  ('奥', '古'),
#  ('古', '斯'),
#  ('斯', '特'),
#  ('特', '了'),
#  ('了', '吧'),
#  ('吧', '。'),
#  ('。', '”'),
#  ('”', '他'),
#  ('他', '说'),
#  ...]

# %%
# 計算 bi-gram 頻率並應用 Add-one smoothing
bi_gram_freq = {}
word_freq = {}
V = len(set(allContent))  # 詞彙的大小（詞彙中不重複單詞的數量）

# %%
# 初始化 word_freq，包括平滑
for word in set(allContent):
    word_freq[word] = V

# %%
# 計算未平滑的 bi-gram 頻率
for bi_gram in all_bi_grams:
    bi_gram_freq[bi_gram] = bi_gram_freq.get(bi_gram, 0) + 1
    word_freq[bi_gram[0]] += 1

# %%
bi_gram_probs = {bi_gram: freq / word_freq[bi_gram[0]] for bi_gram, freq in bi_gram_freq.items()}

# %%
# 文本生成
import random

current_word = '鬼'
Output = []
Output.append(current_word)

for _ in range(500):  # 生成500個單詞的文本
    next_words = [pair[1] for pair in bi_gram_probs.keys() if pair[0] == current_word]
    next_word_probs = [bi_gram_probs[(current_word, next_word)] for next_word in next_words]
    
    # 確保有可選的後續單詞
    if next_words and next_word_probs:
        current_word = random.choices(next_words, weights=next_word_probs)[0]
        Output.append(current_word)
        print(current_word, end=' ')
        
    else:
        break  # 如果沒有後續單詞，則終止循環
# Out:
# 朋 友 们 的 腿 ， 想 ， 我 ， 一 市 ， 晓 晨 阳 西 乡 间 ， 表 情 悲 伤 势 ， 刚 才 看 别 的 警 。   我 想 ” 徐 子 跑 得 极 力 竭 的 ， 一 声 说 　 　 那 是 冰 洋 的 红 无 法 ！ ”
#  严 实 只 见 的 那 间 里 就 是 我 走 。 ” 砰 ” 说 明 天 里 的 门 进 来 回 到 深 浅 细 胞 胎 ， 但 其 实 ， 缘 ， 狞 ， 夏 天 晚 上 驰 了 。 人 寰 宇 诺 ， 谁 会 有 鬼 节 日 要 看 到 一 个 大 汉 口 气 到 医 院 ， 还 要 继 续 说 ， 下 来 一 片 白 ， 三 天 只 有 的 高 嗓 子 ， 他 们 的 表 形 大 妈 的 回 家 过 川 的 人 间 说 不 能 学 校 一 名 落 在 意 识 ， 卧 室 里 还 白 衣 服 。 　 突 然
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[20], line 9
#       6 Output.append(current_word)
#       8 for _ in range(500):  # 生成500個單詞的文本
# ----> 9     next_words = [pair[1] for pair in bi_gram_probs.keys() if pair[0] == current_word]
#      10     next_word_probs = [bi_gram_probs[(current_word, next_word)] for next_word in next_words]
#      12     # 確保有可選的後續單詞
#
# Cell In[20], line 9, in <listcomp>(.0)
#       6 Output.append(current_word)
#       8 for _ in range(500):  # 生成500個單詞的文本
# ----> 9     next_words = [pair[1] for pair in bi_gram_probs.keys() if pair[0] == current_word]
#      10     next_word_probs = [bi_gram_probs[(current_word, next_word)] for next_word in next_words]
#      12     # 確保有可選的後續單詞
#
# KeyboardInterrupt:

# %%
print(Output)
# Out:
# ['鬼', '仙', '的', '伸', '出', '来', '。', '\u3000', '“', '对', '，', '然', '心', '许', '因', '为', '什', '么', '事', '她', '没', '有', '了', '贾', '宁', '还', '有', '水', '灌', '入', '并', '没', '有', '段', '视', '着', '空', '人', '堆', '放', '弃', '小', '虎', '。', '刚', '走', '了', '。', '搞', '关', '上', '去', '。', '”', '，', '把', '最', '后', '还', '怎', '么', '好', '好', '几', '天', '来', '支', '配', '的', '声', '：', '“', '许', '多', '么', '都', '半', '的', '竹', '巧', '合', '着', '拿', '起', '身', '后', '又', '都', '还', '是', '很', '阴', '暗', '想', '的', '报', '纸', '刘', '凯', '凯', '突', '然', '是', '老', '家', '。', '现', '在', '梦', '境', '，', '也', '不', '顾', '忌', '，', '尤', '其', '他', '的', '房', '。', '那', '一', '种', '胡', '刀', '切', '的', '手', '里', '大', '叔', '，', '但', '那', '你', '刚', '起', '回', '头', '乌', '黑', '子', '，', '却', '刁', '民', '间', '看', '见', '过', '要', '铤', '而', '在', '身', '上', '的', '事', '，', '然', '后', '来', '证', '他', '的', '婴', '儿', '听', '到', '我', '在', '争', '：', '&', 'l', 'i', 'p', '&', 'h', 'e', '同', '的', '，', '拖', '着', '&', 'h', '&', 'r', ' ', ' ', '团', '，', '说', '：', '快', '奔', '着', '走', '到', '高', '，', '终', '于', '他', '在', '这', '一', '周', '都', '没', '有', '我', '忘', '宛', '如', '此', '说', '实', '并', '排', '的', '人', '。', '我', '边', '走', '是', '你', '这', '是', '下', '一', '天', '变', '成', '美', '地', '上', '还', '有', '求', '下', '来', '了', '一', '滴', '着', '自', '己', '一', '排', '到', '他', '们', '不', '相', '信', '的', '血', '的', '心', '，', '月', '的', '，', '当', '着', '电', '脑', '上', '挂', '在', '打', '开', '门', '，', '注', '，', '丁', '，', '对', '她', '为', '了', '假', '的', '步', '向', '群', '大', '起', '来', '自', '前', '，', '绕', '到', '下', '起', '家', '，', '除', '了', '方', '昭', '著', '回', '来', '…', '”', '\u3000', '\u3000', '\u3000', '\u3000', '&', 'r', 'd', 'q', 'u', 'o', '\u3000', '“', '带', '来', '，', '所', '以', '有', '，', '但', '是', '怎', '么', '也', '不', '一', '个', '月', '光', '闪', '过', '来', '了', '。', '我', '们', '传', '身', '，', '修', '建', '立', '即', '僵', '硬', '币', '也', '跟', '弟', '已', '经', '有', '个', '二', '天', '，', '给', '你', '先', '生', '的', '折', '。', '丁', '刚', '刚', '刚', '刚', '想', '到', '那', '就', '专', '业', '至', '极', '却', '有', '人', '的', '脚', '步', '身', '上', '来', '的', '轻', '笑', '着', '荧', '屏', '幕', '黑', '袍', '，', '男', '人', '会', '提', '及', '细', '再', '去', '洗', '这', '个', '犄', '角', '处', '在', '那', '天', '夜', '里', '人', '也', '不', '安', '静', '，', '再', '怀', '里', '迸', '了', '，', '这', '里', '太', '好', '，', '就', '是', '这', '原', '始', '害', '死', '亡', '。', '\n', '在', '师', '很', '，', '如', '没', '有', '及', '的', '决', '定', '距', '离', '他', '们', '穿', '的', '那', '苍', '白', '色', '，', '娇', '妻', '妾', '身', '就', '变', '了', '，', '仿', '佛', '就', '这', '一', '顿', '，', '点', '了', '下', '午', '夜', ' ', '\u3000', '良', '将', '猫']

# %%
# # 將列表中的單詞連接成一個字符串
# combined_text = ' '.join(Output)

# # 指定檔案名和路徑
# output_path = './Results/Bi-Gram_Origin_V2.txt'

# # 寫入文件
# with open(output_path, 'w', encoding='utf-8') as file:
#     file.write(combined_text)

# print("done")

# %% [markdown]
# ---

# %%
# # 計算 bi-gram 頻率並應用 Add-one smoothing
# bi_gram_freq = {}
# V = len(set(allContent))  # 詞彙的大小（詞彙中不重複單詞的數量）
# for bi_gram in all_bi_grams:
#     bi_gram_freq[bi_gram] = bi_gram_freq.get(bi_gram, 0) + 1

# %%
# # 應用 Add-one smoothing 到每個頻率
# for bi_gram in bi_gram_freq:
#     bi_gram_freq[bi_gram] += 1

# %%
# # 計算概率
# bi_gram_probs = {}
# for bi_gram, freq in bi_gram_freq.items():
#     word, _ = bi_gram
#     word_freq = sum(1 for bg in all_bi_grams if bg[0] == word) + V
#     bi_gram_probs[bi_gram] = freq / word_freq

# %%
# # 文本生成
# current_word = '吸血鬼'
# for _ in range(100):  # 生成100個單詞的文本
#     next_words = [pair[1] for pair in bi_gram_probs.keys() if pair[0] == current_word]
#     next_word_probs = [bi_gram_probs[(current_word, next_word)] for next_word in next_words]
    
#     # 確保有可選的後續單詞
#     if next_words and next_word_probs:
#         current_word = random.choices(next_words, weights=next_word_probs)[0]
#         print(current_word, end=' ')
#     else:
#         break  # 如果沒有後續單詞，則終止循環

# %%
# # # 假設 text 是一個包含大量文本的字符串
# # words =   # 分割文本成單詞列表
# # bi_grams = [(words[i], words[i + 1]) for i in range(len(words) - 1)]  # 創建 bi-gram 列表

# # 建立詞彙表
# vocabulary = set(allContent)  
# word_to_index = {word: i for i, word in enumerate(vocabulary)}

# # 計算 bi-gram 頻率
# bi_gram_freq = {}
# for bi_gram in all_bi_grams:
#     if bi_gram in bi_gram_freq:
#         bi_gram_freq[bi_gram] += 1
#     else:
#         bi_gram_freq[bi_gram] = 1

# # 計算概率
# bi_gram_probs = {}
# for bi_gram, freq in bi_gram_freq.items():
#     word, next_word = bi_gram
#     bi_gram_probs[bi_gram] = freq / allContent.count(word)

# # 文本生成
# current_word = '吸血鬼'
# for _ in range(200):  # 生成100個單詞的文本
#     next_words = [pair[1] for pair in bi_gram_probs.keys() if pair[0] == current_word]
#     next_word_probs = [bi_gram_probs[(current_word, next_word)] for next_word in next_words]
#     current_word = random.choices(next_words, weights=next_word_probs)[0]
#     print(current_word, end=' ')
