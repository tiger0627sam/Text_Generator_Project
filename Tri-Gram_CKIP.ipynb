# %%
import random
from itertools import islice

# %%
import os
import json

# 路徑設定為 "Data" 資料夾
folder_path = './Data/Origin/'
files = os.listdir(folder_path)

# 初始化一個空的 tri-gram 列表
all_tri_grams = []

# 讀取資料夾中的所有檔案
allContent = []

for file in files:
    with open(folder_path + file, 'r', encoding='utf-8') as fileRead:
        tempFileJSON = json.load(fileRead)
        tempContentList = tempFileJSON['Context']
        allContent.extend(tempContentList)
        # 生成 tri-grams 而不是 bi-grams
        tri_grams = [(tempContentList[i-2], tempContentList[i-1], tempContentList[i]) for i in range(2, len(tempContentList))]
        all_tri_grams.extend(tri_grams)
        
allContent[:10]  # 顯示前10個內容項目
# Out:
# ['\u3000', '\u3000', '一', '\u3000', '\u3000', '这', '是', '我', '第', '三']

# %%
all_tri_grams[:3000]
# Out:
# [('\u3000', '\u3000', '一'),
#  ('\u3000', '一', '\u3000'),
#  ('一', '\u3000', '\u3000'),
#  ('\u3000', '\u3000', '这'),
#  ('\u3000', '这', '是'),
#  ('这', '是', '我'),
#  ('是', '我', '第'),
#  ('我', '第', '三'),
#  ('第', '三', '次'),
#  ('三', '次', '到'),
#  ('次', '到', '这'),
#  ('到', '这', '里'),
#  ('这', '里', '来'),
#  ('里', '来', '，'),
#  ('来', '，', '屋'),
#  ('，', '屋', '里'),
#  ('屋', '里', '的'),
#  ('里', '的', '摆'),
#  ('的', '摆', '设'),
#  ('摆', '设', '还'),
#  ('设', '还', '是'),
#  ('还', '是', '很'),
#  ('是', '很', '陈'),
#  ('很', '陈', '旧'),
#  ('陈', '旧', '。'),
#  ('旧', '。', '我'),
#  ('。', '我', '局'),
#  ('我', '局', '促'),
#  ('局', '促', '不'),
#  ('促', '不', '安'),
#  ('不', '安', '的'),
#  ('安', '的', '站'),
#  ('的', '站', '着'),
#  ('站', '着', '，'),
#  ('着', '，', '双'),
#  ('，', '双', '手'),
#  ('双', '手', '在'),
#  ('手', '在', '胸'),
#  ('在', '胸', '前'),
#  ('胸', '前', '不'),
#  ('前', '不', '停'),
#  ('不', '停', '的'),
#  ('停', '的', '揉'),
#  ('的', '揉', '搓'),
#  ('揉', '搓', '着'),
#  ('搓', '着', '“'),
#  ('着', '“', '我'),
#  ('“', '我', '…'),
#  ('我', '…', '…'),
#  ('…', '…', '我'),
#  ('…', '我', '这'),
#  ('我', '这', '次'),
#  ('这', '次', '…'),
#  ('次', '…', '…'),
#  ('…', '…', '”'),
#  ('…', '”', '“'),
#  ('”', '“', '我'),
#  ('“', '我', '知'),
#  ('我', '知', '道'),
#  ('知', '道', '你'),
#  ('道', '你', '来'),
#  ('你', '来', '是'),
#  ('来', '是', '为'),
#  ('是', '为', '了'),
#  ('为', '了', '什'),
#  ('了', '什', '么'),
#  ('什', '么', '，'),
#  ('么', '，', '回'),
#  ('，', '回', '去'),
#  ('回', '去', '吧'),
#  ('去', '吧', '…'),
#  ('吧', '…', '…'),
#  ('…', '…', '”'),
#  ('…', '”', '我'),
#  ('”', '我', '对'),
#  ('我', '对', '面'),
#  ('对', '面', '的'),
#  ('面', '的', '那'),
#  ('的', '那', '个'),
#  ('那', '个', '男'),
#  ('个', '男', '人'),
#  ('男', '人', '说'),
#  ('人', '说', '话'),
#  ('说', '话', '了'),
#  ('话', '了', '，'),
#  ('了', '，', '声'),
#  ('，', '声', '音'),
#  ('声', '音', '还'),
#  ('音', '还', '是'),
#  ('还', '是', '很'),
#  ('是', '很', '有'),
#  ('很', '有', '力'),
#  ('有', '力', '。'),
#  ('力', '。', '“'),
#  ('。', '“', '可'),
#  ('“', '可', '是'),
#  ('可', '是', '也'),
#  ('是', '也', '只'),
#  ('也', '只', '有'),
#  ('只', '有', '你'),
#  ('有', '你', '了'),
#  ('你', '了', '。'),
#  ('了', '。', '”'),
#  ('。', '”', '“'),
#  ('”', '“', '没'),
#  ('“', '没', '办'),
#  ('没', '办', '法'),
#  ('办', '法', '，'),
#  ('法', '，', '我'),
#  ('，', '我', '也'),
#  ('我', '也', '不'),
#  ('也', '不', '能'),
#  ('不', '能', '清'),
#  ('能', '清', '释'),
#  ('清', '释', '她'),
#  ('释', '她', '的'),
#  ('她', '的', '血'),
#  ('的', '血', '液'),
#  ('血', '液', '。'),
#  ('液', '。', '”'),
#  ('。', '”', '“'),
#  ('”', '“', '你'),
#  ('“', '你', '一'),
#  ('你', '一', '定'),
#  ('一', '定', '会'),
#  ('定', '会', '有'),
#  ('会', '有', '办'),
#  ('有', '办', '法'),
#  ('办', '法', '的'),
#  ('法', '的', '。'),
#  ('的', '。', '”'),
#  ('。', '”', '我'),
#  ('”', '我', '争'),
#  ('我', '争', '取'),
#  ('争', '取', '着'),
#  ('取', '着', '最'),
#  ('着', '最', '后'),
#  ('最', '后', '一'),
#  ('后', '一', '丝'),
#  ('一', '丝', '希'),
#  ('丝', '希', '望'),
#  ('希', '望', '，'),
#  ('望', '，', '“'),
#  ('，', '“', '你'),
#  ('“', '你', '未'),
#  ('你', '未', '免'),
#  ('未', '免', '太'),
#  ('免', '太', '小'),
#  ('太', '小', '看'),
#  ('小', '看', '四'),
#  ('看', '四', '世'),
#  ('四', '世', '的'),
#  ('世', '的', '原'),
#  ('的', '原', '血'),
#  ('原', '血', '了'),
#  ('血', '了', '吧'),
#  ('了', '吧', '。'),
#  ('吧', '。', '”'),
#  ('。', '”', '那'),
#  ('”', '那', '男'),
#  ('那', '男', '人'),
#  ('男', '人', '有'),
#  ('人', '有', '些'),
#  ('有', '些', '急'),
#  ('些', '急', '了'),
#  ('急', '了', '。'),
#  ('了', '。', '“'),
#  ('。', '“', '可'),
#  ('“', '可', '，'),
#  ('可', '，', '除'),
#  ('，', '除', '了'),
#  ('除', '了', '你'),
#  ('了', '你', '，'),
#  ('你', '，', '我'),
#  ('，', '我', '也'),
#  ('我', '也', '不'),
#  ('也', '不', '知'),
#  ('不', '知', '道'),
#  ('知', '道', '去'),
#  ('道', '去', '找'),
#  ('去', '找', '谁'),
#  ('找', '谁', '了'),
#  ('谁', '了', '，'),
#  ('了', '，', '你'),
#  ('，', '你', '可'),
#  ('你', '可', '是'),
#  ('可', '是', '我'),
#  ('是', '我', '能'),
#  ('我', '能', '找'),
#  ('能', '找', '到'),
#  ('找', '到', '的'),
#  ('到', '的', '最'),
#  ('的', '最', '厉'),
#  ('最', '厉', '害'),
#  ('厉', '害', '的'),
#  ('害', '的', '血'),
#  ('的', '血', '猎'),
#  ('血', '猎', '了'),
#  ('猎', '了', '。'),
#  ('了', '。', '”'),
#  ('。', '”', '“'),
#  ('”', '“', '出'),
#  ('“', '出', '去'),
#  ('出', '去', '吧'),
#  ('去', '吧', '。'),
#  ('吧', '。', '”'),
#  ('。', '”', '男'),
#  ('”', '男', '人'),
#  ('男', '人', '最'),
#  ('人', '最', '后'),
#  ('最', '后', '说'),
#  ('后', '说', '了'),
#  ('说', '了', '一'),
#  ('了', '一', '句'),
#  ('一', '句', '。'),
#  ('句', '。', '\u3000'),
#  ('。', '\u3000', '\u3000'),
#  ('\u3000', '\u3000', '从'),
#  ('\u3000', '从', '大'),
#  ('从', '大', '门'),
#  ('大', '门', '走'),
#  ('门', '走', '出'),
#  ('走', '出', '来'),
#  ('出', '来', '的'),
#  ('来', '的', '时'),
#  ('的', '时', '候'),
#  ('时', '候', '，'),
#  ('候', '，', '我'),
#  ('，', '我', '感'),
#  ('我', '感', '觉'),
#  ('感', '觉', '自'),
#  ('觉', '自', '己'),
#  ('自', '己', '快'),
#  ('己', '快', '死'),
#  ('快', '死', '掉'),
#  ('死', '掉', '了'),
#  ('掉', '了', '，'),
#  ('了', '，', '屋'),
#  ('，', '屋', '里'),
#  ('屋', '里', '的'),
#  ('里', '的', '气'),
#  ('的', '气', '氛'),
#  ('气', '氛', '确'),
#  ('氛', '确', '实'),
#  ('确', '实', '很'),
#  ('实', '很', '压'),
#  ('很', '压', '抑'),
#  ('压', '抑', '。'),
#  ('抑', '。', '“'),
#  ('。', '“', '该'),
#  ('“', '该', '死'),
#  ('该', '死', '的'),
#  ('死', '的', '吸'),
#  ('的', '吸', '血'),
#  ('吸', '血', '鬼'),
#  ('血', '鬼', '，'),
#  ('鬼', '，', '没'),
#  ('，', '没', '用'),
#  ('没', '用', '的'),
#  ('用', '的', '血'),
#  ('的', '血', '猎'),
#  ('血', '猎', '。'),
#  ('猎', '。', '”'),
#  ('。', '”', '我'),
#  ('”', '我', '无'),
#  ('我', '无', '力'),
#  ('无', '力', '的'),
#  ('力', '的', '诅'),
#  ('的', '诅', '咒'),
#  ('诅', '咒', '着'),
#  ('咒', '着', '。'),
#  ('着', '。', '“'),
#  ('。', '“', '我'),
#  ('“', '我', '自'),
#  ('我', '自', '己'),
#  ('自', '己', '总'),
#  ('己', '总', '会'),
#  ('总', '会', '有'),
#  ('会', '有', '办'),
#  ('有', '办', '法'),
#  ('办', '法', '的'),
#  ('法', '的', '，'),
#  ('的', '，', '奥'),
#  ('，', '奥', '古'),
#  ('奥', '古', '斯'),
#  ('古', '斯', '特'),
#  ('斯', '特', '，'),
#  ('特', '，', '等'),
#  ('，', '等', '着'),
#  ('等', '着', '。'),
#  ('着', '。', '”'),
#  ('。', '”', '我'),
#  ('”', '我', '恨'),
#  ('我', '恨', '恨'),
#  ('恨', '恨', '的'),
#  ('恨', '的', '说'),
#  ('的', '说', '到'),
#  ('说', '到', '。'),
#  ('到', '。', '\u3000'),
#  ('。', '\u3000', '\u3000'),
#  ('\u3000', '\u3000', '奥'),
#  ('\u3000', '奥', '古'),
#  ('奥', '古', '斯'),
#  ('古', '斯', '特'),
#  ('斯', '特', '是'),
#  ('特', '是', '一'),
#  ('是', '一', '个'),
#  ('一', '个', '吸'),
#  ('个', '吸', '血'),
#  ('吸', '血', '鬼'),
#  ('血', '鬼', '。'),
#  ('鬼', '。', '他'),
#  ('。', '他', '是'),
#  ('他', '是', '四'),
#  ('是', '四', '世'),
#  ('四', '世', '，'),
#  ('世', '，', '现'),
#  ('，', '现', '存'),
#  ('现', '存', '唯'),
#  ('存', '唯', '一'),
#  ('唯', '一', '的'),
#  ('一', '的', '四'),
#  ('的', '四', '世'),
#  ('四', '世', '。'),
#  ('世', '。', '\u3000'),
#  ('。', '\u3000', '\u3000'),
#  ('\u3000', '\u3000', '我'),
#  ('\u3000', '我', '是'),
#  ('我', '是', '一'),
#  ('是', '一', '个'),
#  ('一', '个', '血'),
#  ('个', '血', '猎'),
#  ('血', '猎', '。'),
#  ('猎', '。', '吸'),
#  ('。', '吸', '血'),
#  ('吸', '血', '鬼'),
#  ('血', '鬼', '猎'),
#  ('鬼', '猎', '手'),
#  ('猎', '手', '。'),
#  ('手', '。', '那'),
#  ('。', '那', '男'),
#  ('那', '男', '人'),
#  ('男', '人', '是'),
#  ('人', '是', '我'),
#  ('是', '我', '的'),
#  ('我', '的', '老'),
#  ('的', '老', '师'),
#  ('老', '师', '。'),
#  ('师', '。', '看'),
#  ('。', '看', '来'),
#  ('看', '来', '，'),
#  ('来', '，', '对'),
#  ('，', '对', '于'),
#  ('对', '于', '四'),
#  ('于', '四', '世'),
#  ('四', '世', '。'),
#  ('世', '。', '我'),
#  ('。', '我', '老'),
#  ('我', '老', '师'),
#  ('老', '师', '和'),
#  ('师', '和', '我'),
#  ('和', '我', '都'),
#  ('我', '都', '…'),
#  ('都', '…', '…'),
#  ('…', '…', '没'),
#  ('…', '没', '有'),
#  ('没', '有', '办'),
#  ('有', '办', '法'),
#  ('办', '法', '。'),
#  ('法', '。', '\u3000'),
#  ('。', '\u3000', '\u3000'),
#  ('\u3000', '\u3000', '二'),
#  ('\u3000', '二', '\u3000'),
#  ('二', '\u3000', '\u3000'),
#  ('\u3000', '\u3000', '我'),
#  ('\u3000', '我', '再'),
#  ('我', '再', '次'),
#  ('再', '次', '站'),
#  ('次', '站', '到'),
#  ('站', '到', '1'),
#  ('到', '1', '1'),
#  ('1', '1', '7'),
#  ('1', '7', '号'),
#  ('7', '号', '门'),
#  ('号', '门', '前'),
#  ('门', '前', '。'),
#  ('前', '。', '这'),
#  ('。', '这', '里'),
#  ('这', '里', '是'),
#  ('里', '是', '一'),
#  ('是', '一', '栋'),
#  ('一', '栋', '大'),
#  ('栋', '大', '别'),
#  ('大', '别', '墅'),
#  ('别', '墅', '：'),
#  ('墅', '：', '墙'),
#  ('：', '墙', '壁'),
#  ('墙', '壁', '上'),
#  ('壁', '上', '爬'),
#  ('上', '爬', '满'),
#  ('爬', '满', '绿'),
#  ('满', '绿', '油'),
#  ('绿', '油', '油'),
#  ('油', '油', '的'),
#  ('油', '的', '植'),
#  ('的', '植', '物'),
#  ('植', '物', '，'),
#  ('物', '，', '连'),
#  ('，', '连', '门'),
#  ('连', '门', '上'),
#  ('门', '上', '都'),
#  ('上', '都', '是'),
#  ('都', '是', '，'),
#  ('是', '，', '正'),
#  ('，', '正', '面'),
#  ('正', '面', '的'),
#  ('面', '的', '墙'),
#  ('的', '墙', '上'),
#  ('墙', '上', '的'),
#  ('上', '的', '窗'),
#  ('的', '窗', '户'),
#  ('窗', '户', '都'),
#  ('户', '都', '被'),
#  ('都', '被', '钉'),
#  ('被', '钉', '上'),
#  ('钉', '上', '。'),
#  ('上', '。', '似'),
#  ('。', '似', '乎'),
#  ('似', '乎', '连'),
#  ('乎', '连', '光'),
#  ('连', '光', '到'),
#  ('光', '到', '这'),
#  ('到', '这', '里'),
#  ('这', '里', '都'),
#  ('里', '都', '被'),
#  ('都', '被', '什'),
#  ('被', '什', '么'),
#  ('什', '么', '东'),
#  ('么', '东', '西'),
#  ('东', '西', '吞'),
#  ('西', '吞', '噬'),
#  ('吞', '噬', '了'),
#  ('噬', '了', '。'),
#  ('了', '。', '我'),
#  ('。', '我', '推'),
#  ('我', '推', '开'),
#  ('推', '开', '了'),
#  ('开', '了', '门'),
#  ('了', '门', '，'),
#  ('门', '，', '走'),
#  ('，', '走', '了'),
#  ('走', '了', '进'),
#  ('了', '进', '去'),
#  ('进', '去', '：'),
#  ('去', '：', '这'),
#  ('：', '这', '里'),
#  ('这', '里', '很'),
#  ('里', '很', '阴'),
#  ('很', '阴', '冷'),
#  ('阴', '冷', '，'),
#  ('冷', '，', '屋'),
#  ('，', '屋', '里'),
#  ('屋', '里', '很'),
#  ('里', '很', '暗'),
#  ('很', '暗', '，'),
#  ('暗', '，', '几'),
#  ('，', '几', '根'),
#  ('几', '根', '蜡'),
#  ('根', '蜡', '烛'),
#  ('蜡', '烛', '在'),
#  ('烛', '在', '墙'),
#  ('在', '墙', '角'),
#  ('墙', '角', '的'),
#  ('角', '的', '烛'),
#  ('的', '烛', '台'),
#  ('烛', '台', '上'),
#  ('台', '上', '烧'),
#  ('上', '烧', '着'),
#  ('烧', '着', '。'),
#  ('着', '。', '两'),
#  ('。', '两', '排'),
#  ('两', '排', '楼'),
#  ('排', '楼', '梯'),
#  ('楼', '梯', '通'),
#  ('梯', '通', '向'),
#  ('通', '向', '二'),
#  ('向', '二', '楼'),
#  ('二', '楼', '，'),
#  ('楼', '，', '楼'),
#  ('，', '楼', '梯'),
#  ('楼', '梯', '中'),
#  ('梯', '中', '间'),
#  ('中', '间', '，'),
#  ('间', '，', '一'),
#  ('，', '一', '副'),
#  ('一', '副', '大'),
#  ('副', '大', '油'),
#  ('大', '油', '画'),
#  ('油', '画', '，'),
#  ('画', '，', '画'),
#  ('，', '画', '中'),
#  ('画', '中', '的'),
#  ('中', '的', '人'),
#  ('的', '人', '笑'),
#  ('人', '笑', '的'),
#  ('笑', '的', '很'),
#  ('的', '很', '冷'),
#  ('很', '冷', '。'),
#  ('冷', '。', '“'),
#  ('。', '“', '奥'),
#  ('“', '奥', '古'),
#  ('奥', '古', '斯'),
#  ('古', '斯', '特'),
#  ('斯', '特', '，'),
#  ('特', '，', '”'),
#  ('，', '”', '我'),
#  ('”', '我', '对'),
#  ('我', '对', '着'),
#  ('对', '着', '油'),
#  ('着', '油', '画'),
#  ('油', '画', '大'),
#  ('画', '大', '喊'),
#  ('大', '喊', '“'),
#  ('喊', '“', '我'),
#  ('“', '我', '知'),
#  ('我', '知', '道'),
#  ('知', '道', '你'),
#  ('道', '你', '在'),
#  ('你', '在', '她'),
#  ('在', '她', '也'),
#  ('她', '也', '在'),
#  ('也', '在', '。'),
#  ('在', '。', '出'),
#  ('。', '出', '来'),
#  ('出', '来', '，'),
#  ('来', '，', '我'),
#  ('，', '我', '们'),
#  ('我', '们', '谈'),
#  ('们', '谈', '谈'),
#  ('谈', '谈', '。'),
#  ('谈', '。', '”'),
#  ('。', '”', '\u3000'),
#  ('”', '\u3000', '\u3000'),
#  ('\u3000', '\u3000', '“'),
#  ('\u3000', '“', '谈'),
#  ('“', '谈', '什'),
#  ('谈', '什', '么'),
#  ('什', '么', '，'),
#  ('么', '，', '小'),
#  ('，', '小', '血'),
#  ('小', '血', '猎'),
#  ('血', '猎', '。'),
#  ('猎', '。', '”'),
#  ('。', '”', '一'),
#  ('”', '一', '顾'),
#  ('一', '顾', '温'),
#  ('顾', '温', '柔'),
#  ('温', '柔', '到'),
#  ('柔', '到', '极'),
#  ('到', '极', '致'),
#  ('极', '致', '的'),
#  ('致', '的', '声'),
#  ('的', '声', '音'),
#  ('声', '音', '从'),
#  ('音', '从', '虚'),
#  ('从', '虚', '无'),
#  ('虚', '无', '中'),
#  ('无', '中', '传'),
#  ('中', '传', '来'),
#  ('传', '来', '，'),
#  ('来', '，', '我'),
#  ('，', '我', '知'),
#  ('我', '知', '道'),
#  ('知', '道', '那'),
#  ('道', '那', '是'),
#  ('那', '是', '奥'),
#  ('是', '奥', '古'),
#  ('奥', '古', '斯'),
#  ('古', '斯', '特'),
#  ('斯', '特', '的'),
#  ('特', '的', '声'),
#  ('的', '声', '音'),
#  ('声', '音', '“'),
#  ('音', '“', '你'),
#  ('“', '你', '又'),
#  ('你', '又', '不'),
#  ('又', '不', '能'),
#  ('不', '能', '伤'),
#  ('能', '伤', '害'),
#  ('伤', '害', '到'),
#  ('害', '到', '我'),
#  ('到', '我', '，'),
#  ('我', '，', '所'),
#  ('，', '所', '以'),
#  ('所', '以', '你'),
#  ('以', '你', '想'),
#  ('你', '想', '谈'),
#  ('想', '谈', '的'),
#  ('谈', '的', '根'),
#  ('的', '根', '本'),
#  ('根', '本', '没'),
#  ('本', '没', '希'),
#  ('没', '希', '望'),
#  ('希', '望', '。'),
#  ('望', '。', '”'),
#  ('。', '”', '“'),
#  ('”', '“', '放'),
#  ('“', '放', '了'),
#  ('放', '了', '她'),
#  ('了', '她', '，'),
#  ('她', '，', '好'),
#  ('，', '好', '吗'),
#  ('好', '吗', '，'),
#  ('吗', '，', '我'),
#  ('，', '我', '求'),
#  ('我', '求', '你'),
#  ('求', '你', '了'),
#  ('你', '了', '。'),
#  ('了', '。', '”'),
#  ('。', '”', '我'),
#  ('”', '我', '又'),
#  ('我', '又', '一'),
#  ('又', '一', '次'),
#  ('一', '次', '没'),
#  ('次', '没', '骨'),
#  ('没', '骨', '气'),
#  ('骨', '气', '了'),
#  ('气', '了', '，'),
#  ('了', '，', '在'),
#  ('，', '在', '老'),
#  ('在', '老', '师'),
#  ('老', '师', '那'),
#  ('师', '那', '次'),
#  ('那', '次', '也'),
#  ('次', '也', '一'),
#  ('也', '一', '样'),
#  ('一', '样', '。'),
#  ('样', '。', '“'),
#  ('。', '“', '谁'),
#  ('“', '谁', '?'),
#  ('谁', '?', '”'),
#  ('?', '”', '我'),
#  ('”', '我', '知'),
#  ('我', '知', '道'),
#  ('知', '道', '他'),
#  ('道', '他', '明'),
#  ('他', '明', '知'),
#  ('明', '知', '故'),
#  ('知', '故', '问'),
#  ('故', '问', '。'),
#  ('问', '。', '“'),
#  ('。', '“', '方'),
#  ('“', '方', '凌'),
#  ('方', '凌', '。'),
#  ('凌', '。', '”'),
#  ('。', '”', '“'),
#  ('”', '“', '哦'),
#  ('“', '哦', '，'),
#  ('哦', '，', '你'),
#  ('，', '你', '说'),
#  ('你', '说', '的'),
#  ('说', '的', '一'),
#  ('的', '一', '定'),
#  ('一', '定', '是'),
#  ('定', '是', '凌'),
#  ('是', '凌', '-'),
#  ('凌', '-', '奥'),
#  ('-', '奥', '古'),
#  ('奥', '古', '斯'),
#  ('古', '斯', '特'),
#  ('斯', '特', '，'),
#  ('特', '，', '她'),
#  ('，', '她', '现'),
#  ('她', '现', '在'),
#  ('现', '在', '是'),
#  ('在', '是', '我'),
#  ('是', '我', '的'),
#  ('我', '的', '女'),
#  ('的', '女', '人'),
#  ('女', '人', '。'),
#  ('人', '。', '”'),
#  ('。', '”', '“'),
#  ('”', '“', '她'),
#  ('“', '她', '的'),
#  ('她', '的', '血'),
#  ('的', '血', '液'),
#  ('血', '液', '…'),
#  ('液', '…', '…'),
#  ('…', '…', '”'),
#  ('…', '”', '我'),
#  ('”', '我', '喉'),
#  ('我', '喉', '咙'),
#  ('喉', '咙', '沙'),
#  ('咙', '沙', '哑'),
#  ('沙', '哑', '。'),
#  ('哑', '。', '“'),
#  ('。', '“', '放'),
#  ('“', '放', '心'),
#  ('放', '心', '，'),
#  ('心', '，', '四'),
#  ('，', '四', '世'),
#  ('四', '世', '的'),
#  ('世', '的', '原'),
#  ('的', '原', '血'),
#  ('原', '血', '没'),
#  ('血', '没', '有'),
#  ('没', '有', '这'),
#  ('有', '这', '么'),
#  ('这', '么', '快'),
#  ('么', '快', '融'),
#  ('快', '融', '合'),
#  ('融', '合', '的'),
#  ('合', '的', '，'),
#  ('的', '，', '不'),
#  ('，', '不', '过'),
#  ('不', '过', '在'),
#  ('过', '在', '我'),
#  ('在', '我', '的'),
#  ('我', '的', '帮'),
#  ('的', '帮', '助'),
#  ('帮', '助', '下'),
#  ('助', '下', '也'),
#  ('下', '也', '快'),
#  ('也', '快', '了'),
#  ('快', '了', '，'),
#  ('了', '，', '现'),
#  ('，', '现', '在'),
#  ('现', '在', '你'),
#  ('在', '你', '知'),
#  ('你', '知', '道'),
#  ('知', '道', '的'),
#  ('道', '的', '够'),
#  ('的', '够', '多'),
#  ('够', '多', '了'),
#  ('多', '了', '，'),
#  ('了', '，', '走'),
#  ('，', '走', '吧'),
#  ('走', '吧', '。'),
#  ('吧', '。', '”'),
#  ('。', '”', '“'),
#  ('”', '“', '我'),
#  ('“', '我', '…'),
#  ('我', '…', '…'),
#  ('…', '…', '让'),
#  ('…', '让', '我'),
#  ('让', '我', '在'),
#  ('我', '在', '看'),
#  ('在', '看', '看'),
#  ('看', '看', '她'),
#  ('看', '她', '…'),
#  ('她', '…', '…'),
#  ('…', '…', '”'),
#  ('…', '”', '我'),
#  ('”', '我', '乞'),
#  ('我', '乞', '求'),
#  ('乞', '求', '着'),
#  ('求', '着', '。'),
#  ('着', '。', '“'),
#  ('。', '“', '当'),
#  ('“', '当', '她'),
#  ('当', '她', '完'),
#  ('她', '完', '全'),
#  ('完', '全', '变'),
#  ('全', '变', '成'),
#  ('变', '成', '血'),
#  ('成', '血', '族'),
#  ('血', '族', '中'),
#  ('族', '中', '的'),
#  ('中', '的', '骄'),
#  ('的', '骄', '傲'),
#  ('骄', '傲', '的'),
#  ('傲', '的', '时'),
#  ('的', '时', '候'),
#  ('时', '候', '，'),
#  ('候', '，', '她'),
#  ('，', '她', '会'),
#  ('她', '会', '去'),
#  ('会', '去', '找'),
#  ('去', '找', '你'),
#  ('找', '你', '。'),
#  ('你', '。', '”'),
#  ('。', '”', '然'),
#  ('”', '然', '后'),
#  ('然', '后', '奥'),
#  ('后', '奥', '古'),
#  ('奥', '古', '斯'),
#  ('古', '斯', '特'),
#  ('斯', '特', '有'),
#  ('特', '有', '一'),
#  ('有', '一', '次'),
#  ('一', '次', '让'),
#  ('次', '让', '我'),
#  ('让', '我', '知'),
#  ('我', '知', '道'),
#  ('知', '道', '我'),
#  ('道', '我', '们'),
#  ('我', '们', '之'),
#  ('们', '之', '间'),
#  ('之', '间', '的'),
#  ('间', '的', '差'),
#  ('的', '差', '距'),
#  ('差', '距', '，'),
#  ('距', '，', '他'),
#  ('，', '他', '把'),
#  ('他', '把', '我'),
#  ('把', '我', '扔'),
#  ('我', '扔', '出'),
#  ('扔', '出', '别'),
#  ('出', '别', '墅'),
#  ('别', '墅', '，'),
#  ('墅', '，', '我'),
#  ('，', '我', '甚'),
#  ('我', '甚', '至'),
#  ('甚', '至', '都'),
#  ('至', '都', '没'),
#  ('都', '没', '有'),
#  ('没', '有', '看'),
#  ('有', '看', '到'),
#  ('看', '到', '他'),
#  ('到', '他', '的'),
#  ('他', '的', '脸'),
#  ('的', '脸', '。'),
#  ('脸', '。', '\u3000'),
#  ('。', '\u3000', '\u3000'),
#  ('\u3000', '\u3000', '三'),
#  ('\u3000', '三', '\u3000'),
#  ('三', '\u3000', '\u3000'),
#  ('\u3000', '\u3000', '我'),
#  ('\u3000', '我', '从'),
#  ('我', '从', '地'),
#  ('从', '地', '上'),
#  ('地', '上', '爬'),
#  ('上', '爬', '起'),
#  ('爬', '起', '来'),
#  ('起', '来', '，'),
#  ('来', '，', '低'),
#  ('，', '低', '着'),
#  ('低', '着', '头'),
#  ('着', '头', '，'),
#  ('头', '，', '哭'),
#  ('，', '哭', '了'),
#  ('哭', '了', '，'),
#  ('了', '，', '“'),
#  ('，', '“', '方'),
#  ('“', '方', '凌'),
#  ('方', '凌', '，'),
#  ('凌', '，', '我'),
#  ('，', '我', '爱'),
#  ('我', '爱', '你'),
#  ('爱', '你', '。'),
#  ('你', '。', '”'),
#  ('。', '”', '我'),
#  ('”', '我', '对'),
#  ('我', '对', '着'),
#  ('对', '着', '1'),
#  ('着', '1', '1'),
#  ('1', '1', '7'),
#  ('1', '7', '号'),
#  ('7', '号', '别'),
#  ('号', '别', '墅'),
#  ('别', '墅', '吼'),
#  ('墅', '吼', '着'),
#  ('吼', '着', '，'),
#  ('着', '，', '“'),
#  ('，', '“', '我'),
#  ('“', '我', '要'),
#  ('我', '要', '和'),
#  ('要', '和', '你'),
#  ('和', '你', '在'),
#  ('你', '在', '一'),
#  ('在', '一', '起'),
#  ('一', '起', '。'),
#  ('起', '。', '”'),
#  ('。', '”', '，'),
#  ('”', '，', '可'),
#  ('，', '可', '别'),
#  ('可', '别', '墅'),
#  ('别', '墅', '那'),
#  ('墅', '那', '边'),
#  ('那', '边', '没'),
#  ('边', '没', '有'),
#  ('没', '有', '反'),
#  ('有', '反', '应'),
#  ('反', '应', '。'),
#  ('应', '。', '\u3000'),
#  ('。', '\u3000', '\u3000'),
#  ('\u3000', '\u3000', '我'),
#  ('\u3000', '我', '回'),
#  ('我', '回', '家'),
#  ('回', '家', '。'),
#  ('家', '。', '走'),
#  ('。', '走', '在'),
#  ('走', '在', '街'),
#  ('在', '街', '上'),
#  ('街', '上', '，'),
#  ('上', '，', '一'),
#  ('，', '一', '个'),
#  ('一', '个', '人'),
#  ('个', '人', '都'),
#  ('人', '都', '没'),
#  ('都', '没', '有'),
#  ('没', '有', '，'),
#  ('有', '，', '我'),
#  ('，', '我', '边'),
#  ('我', '边', '走'),
#  ('边', '走', '边'),
#  ('走', '边', '哭'),
#  ('边', '哭', '。'),
#  ('哭', '。', '我'),
#  ('。', '我', '爱'),
#  ('我', '爱', '她'),
#  ('爱', '她', '，'),
#  ('她', '，', '我'),
#  ('，', '我', '是'),
#  ('我', '是', '血'),
#  ('是', '血', '猎'),
#  ('血', '猎', '，'),
#  ('猎', '，', '可'),
#  ('，', '可', '她'),
#  ('可', '她', '马'),
#  ('她', '马', '上'),
#  ('马', '上', '要'),
#  ('上', '要', '成'),
#  ('要', '成', '为'),
#  ('成', '为', '吸'),
#  ('为', '吸', '血'),
#  ('吸', '血', '鬼'),
#  ('血', '鬼', '了'),
#  ('鬼', '了', '。'),
#  ('了', '。', '我'),
#  ('。', '我', '还'),
#  ('我', '还', '得'),
#  ('还', '得', '去'),
#  ('得', '去', '找'),
#  ('去', '找', '他'),
#  ('找', '他', '，'),
#  ('他', '，', '那'),
#  ('，', '那', '个'),
#  ('那', '个', '让'),
#  ('个', '让', '我'),
#  ('让', '我', '成'),
#  ('我', '成', '为'),
#  ('成', '为', '血'),
#  ('为', '血', '猎'),
#  ('血', '猎', '的'),
#  ('猎', '的', '男'),
#  ('的', '男', '人'),
#  ('男', '人', '，'),
#  ('人', '，', '我'),
#  ('，', '我', '的'),
#  ('我', '的', '老'),
#  ('的', '老', '师'),
#  ('老', '师', '。'),
#  ('师', '。', '\u3000'),
#  ('。', '\u3000', '\u3000'),
#  ('\u3000', '\u3000', '这'),
#  ('\u3000', '这', '是'),
#  ('这', '是', '我'),
#  ('是', '我', '第'),
#  ('我', '第', '四'),
#  ('第', '四', '次'),
#  ('四', '次', '来'),
#  ('次', '来', '了'),
#  ('来', '了', '，'),
#  ('了', '，', '那'),
#  ('，', '那', '男'),
#  ('那', '男', '人'),
#  ('男', '人', '还'),
#  ('人', '还', '在'),
#  ('还', '在', '单'),
#  ('在', '单', '人'),
#  ('单', '人', '沙'),
#  ('人', '沙', '发'),
#  ('沙', '发', '坐'),
#  ('发', '坐', '着'),
#  ('坐', '着', '，'),
#  ('着', '，', '他'),
#  ('，', '他', '都'),
#  ('他', '都', '没'),
#  ('都', '没', '有'),
#  ('没', '有', '换'),
#  ('有', '换', '过'),
#  ('换', '过', '地'),
#  ('过', '地', '方'),
#  ('地', '方', '，'),
#  ('方', '，', '“'),
#  ('，', '“', '你'),
#  ('“', '你', '去'),
#  ('你', '去', '找'),
#  ('去', '找', '奥'),
#  ('找', '奥', '古'),
#  ('奥', '古', '斯'),
#  ('古', '斯', '特'),
#  ('斯', '特', '了'),
#  ('特', '了', '吧'),
#  ('了', '吧', '。'),
#  ('吧', '。', '”'),
#  ('。', '”', '他'),
#  ('”', '他', '说'),
#  ('他', '说', '。'),
#  ...]

# %%
# 計算 Tri-gram 頻率並應用 Add-one smoothing
tri_gram_freq = {}
word_pair_freq = {}
V = len(set(allContent))  # 詞彙的大小（詞彙中不重複單詞的數量）

# %%
# 初始化 word_pair_freq，包括平滑
for word1, word2 in [(tg[0], tg[1]) for tg in tri_grams]:
    word_pair_freq[(word1, word2)] = V

# %%
# 計算未平滑的 tri-gram 頻率
for tri_gram in tri_grams:
    tri_gram_freq[tri_gram] = tri_gram_freq.get(tri_gram, 0) + 1
    word_pair_freq[(tri_gram[0], tri_gram[1])] += 1

# %%
dict(islice(tri_gram_freq.items(), 500))
# Out:
# {('\u3000', '\u3000', '我'): 2,
#  ('\u3000', '我', '有'): 1,
#  ('我', '有', '一'): 1,
#  ('有', '一', '小'): 1,
#  ('一', '小', '学'): 1,
#  ('小', '学', '（'): 1,
#  ('学', '（', '云'): 1,
#  ('（', '云', '师'): 1,
#  ('云', '师', '附'): 1,
#  ('师', '附', '小'): 1,
#  ('附', '小', '）'): 1,
#  ('小', '）', '女'): 1,
#  ('）', '女', '同'): 1,
#  ('女', '同', '学'): 1,
#  ('同', '学', '，'): 2,
#  ('学', '，', '但'): 1,
#  ('，', '但', '只'): 1,
#  ('但', '只', '同'): 1,
#  ('只', '同', '年'): 1,
#  ('同', '年', '级'): 1,
#  ('年', '级', '不'): 1,
#  ('级', '不', '同'): 1,
#  ('不', '同', '班'): 1,
#  ('同', '班', '，'): 1,
#  ('班', '，', '名'): 1,
#  ('，', '名', '邓'): 1,
#  ('名', '邓', '银'): 1,
#  ('邓', '银', '华'): 4,
#  ('银', '华', '，'): 2,
#  ('华', '，', '我'): 1,
#  ('，', '我', '今'): 1,
#  ('我', '今', '天'): 1,
#  ('今', '天', '来'): 1,
#  ('天', '来', '讲'): 1,
#  ('来', '讲', '她'): 1,
#  ('讲', '她', '家'): 1,
#  ('她', '家', '的'): 1,
#  ('家', '的', '一'): 1,
#  ('的', '一', '则'): 1,
#  ('一', '则', '故'): 1,
#  ('则', '故', '事'): 1,
#  ('故', '事', '。'): 1,
#  ('事', '。', '邓'): 1,
#  ('。', '邓', '银'): 1,
#  ('银', '华', '不'): 1,
#  ('华', '不', '但'): 1,
#  ('不', '但', '成'): 1,
#  ('但', '成', '绩'): 1,
#  ('成', '绩', '好'): 1,
#  ('绩', '好', '，'): 1,
#  ('好', '，', '人'): 1,
#  ('，', '人', '也'): 1,
#  ('人', '也', '长'): 1,
#  ('也', '长', '得'): 1,
#  ('长', '得', '非'): 1,
#  ('得', '非', '常'): 1,
#  ('非', '常', '娇'): 1,
#  ('常', '娇', '小'): 1,
#  ('娇', '小', '可'): 1,
#  ('小', '可', '爱'): 1,
#  ('可', '爱', '，'): 1,
#  ('爱', '，', '把'): 1,
#  ('，', '把', '我'): 1,
#  ('把', '我', '一'): 1,
#  ('我', '一', '个'): 1,
#  ('一', '个', '同'): 1,
#  ('个', '同', '班'): 1,
#  ('同', '班', '叫'): 1,
#  ('班', '叫', '李'): 1,
#  ('叫', '李', '冬'): 1,
#  ('李', '冬', '华'): 1,
#  ('冬', '华', '的'): 1,
#  ('华', '的', '男'): 1,
#  ('的', '男', '生'): 1,
#  ('男', '生', '迷'): 1,
#  ('生', '迷', '得'): 1,
#  ('迷', '得', '一'): 1,
#  ('得', '一', '愣'): 1,
#  ('一', '愣', '一'): 1,
#  ('愣', '一', '愣'): 1,
#  ('一', '愣', '的'): 1,
#  ('愣', '的', '，'): 1,
#  ('的', '，', '后'): 1,
#  ('，', '后', '来'): 3,
#  ('后', '来', '上'): 1,
#  ('来', '上', '初'): 1,
#  ('上', '初', '中'): 1,
#  ('初', '中', '后'): 1,
#  ('中', '后', '还'): 1,
#  ('后', '还', '给'): 1,
#  ('还', '给', '人'): 1,
#  ('给', '人', '家'): 1,
#  ('人', '家', '女'): 1,
#  ('家', '女', '孩'): 1,
#  ('女', '孩', '子'): 2,
#  ('孩', '子', '写'): 1,
#  ('子', '写', '过'): 1,
#  ('写', '过', '带'): 1,
#  ('过', '带', '血'): 1,
#  ('带', '血', '的'): 1,
#  ('血', '的', '情'): 1,
#  ('的', '情', '书'): 1,
#  ('情', '书', '。'): 1,
#  ('书', '。', '但'): 1,
#  ('。', '但', '我'): 1,
#  ('但', '我', '不'): 2,
#  ('我', '不', '是'): 1,
#  ('不', '是', '琼'): 1,
#  ('是', '琼', '瑶'): 1,
#  ('琼', '瑶', '阿'): 1,
#  ('瑶', '阿', '姨'): 1,
#  ('阿', '姨', '，'): 1,
#  ('姨', '，', '对'): 1,
#  ('，', '对', '这'): 1,
#  ('对', '这', '些'): 1,
#  ('这', '些', '情'): 1,
#  ('些', '情', '啊'): 1,
#  ('情', '啊', '爱'): 1,
#  ('啊', '爱', '啊'): 1,
#  ('爱', '啊', '天'): 1,
#  ('啊', '天', '生'): 1,
#  ('天', '生', '迟'): 1,
#  ('生', '迟', '钝'): 1,
#  ('迟', '钝', '，'): 1,
#  ('钝', '，', '而'): 1,
#  ('，', '而', '且'): 2,
#  ('而', '且', '那'): 1,
#  ('且', '那', '也'): 1,
#  ('那', '也', '不'): 1,
#  ('也', '不', '是'): 2,
#  ('不', '是', '我'): 1,
#  ('是', '我', '写'): 1,
#  ('我', '写', '这'): 1,
#  ('写', '这', '篇'): 1,
#  ('这', '篇', '文'): 2,
#  ('篇', '文', '章'): 2,
#  ('文', '章', '的'): 1,
#  ('章', '的', '初'): 1,
#  ('的', '初', '衷'): 1,
#  ('初', '衷', '，'): 1,
#  ('衷', '，', '所'): 1,
#  ('，', '所', '以'): 1,
#  ('所', '以', '就'): 1,
#  ('以', '就', '不'): 1,
#  ('就', '不', '再'): 1,
#  ('不', '再', '八'): 1,
#  ('再', '八', '卦'): 1,
#  ('八', '卦', '。'): 1,
#  ('卦', '。', '\u3000'): 1,
#  ('。', '\u3000', '\u3000'): 10,
#  ('\u3000', '\u3000', '言'): 1,
#  ('\u3000', '言', '归'): 1,
#  ('言', '归', '正'): 1,
#  ('归', '正', '传'): 1,
#  ('正', '传', '，'): 1,
#  ('传', '，', '话'): 1,
#  ('，', '话', '说'): 1,
#  ('话', '说', '大'): 1,
#  ('说', '大', '约'): 1,
#  ('大', '约', '1'): 1,
#  ('约', '1', '9'): 1,
#  ('1', '9', '9'): 1,
#  ('9', '9', '8'): 1,
#  ('9', '8', '的'): 1,
#  ('8', '的', '时'): 1,
#  ('的', '时', '候'): 1,
#  ('时', '候', '（'): 1,
#  ('候', '（', '对'): 1,
#  ('（', '对', '！'): 1,
#  ('对', '！', '就'): 1,
#  ('！', '就', '夏'): 1,
#  ('就', '夏', '洛'): 1,
#  ('夏', '洛', '和'): 1,
#  ('洛', '和', '娜'): 1,
#  ('和', '娜', '姐'): 1,
#  ('娜', '姐', '合'): 1,
#  ('姐', '合', '唱'): 1,
#  ('合', '唱', '《'): 1,
#  ('唱', '《', '相'): 1,
#  ('《', '相', '约'): 1,
#  ('相', '约', '9'): 1,
#  ('约', '9', '8'): 1,
#  ('9', '8', '》'): 1,
#  ('8', '》', '那'): 1,
#  ('》', '那', '年'): 1,
#  ('那', '年', '）'): 1,
#  ('年', '）', '，'): 1,
#  ('）', '，', '我'): 1,
#  ('，', '我', '老'): 3,
#  ('我', '老', '爸'): 6,
#  ('老', '爸', '从'): 1,
#  ('爸', '从', '老'): 1,
#  ('从', '老', '家'): 1,
#  ('老', '家', '回'): 1,
#  ('家', '回', '成'): 1,
#  ('回', '成', '都'): 1,
#  ('成', '都', '，'): 1,
#  ('都', '，', '给'): 1,
#  ('，', '给', '我'): 1,
#  ('给', '我', '讲'): 2,
#  ('我', '讲', '了'): 1,
#  ('讲', '了', '一'): 1,
#  ('了', '一', '则'): 1,
#  ('一', '则', '稀'): 1,
#  ('则', '稀', '罕'): 1,
#  ('稀', '罕', '事'): 1,
#  ('罕', '事', '：'): 1,
#  ('事', '：', '\u3000'): 1,
#  ('：', '\u3000', '\u3000'): 1,
#  ('\u3000', '我', '老'): 1,
#  ('老', '爸', '与'): 1,
#  ('爸', '与', '邓'): 1,
#  ('与', '邓', '银'): 1,
#  ('银', '华', '老'): 1,
#  ('华', '老', '爸'): 1,
#  ('老', '爸', '是'): 1,
#  ('爸', '是', '老'): 1,
#  ('是', '老', '同'): 1,
#  ('老', '同', '学'): 1,
#  ('学', '，', '一'): 1,
#  ('，', '一', '天'): 1,
#  ('一', '天', '经'): 1,
#  ('天', '经', '过'): 1,
#  ('经', '过', '老'): 1,
#  ('过', '老', '邓'): 1,
#  ('老', '邓', '家'): 4,
#  ('邓', '家', '开'): 1,
#  ('家', '开', '的'): 1,
#  ('开', '的', '副'): 1,
#  ('的', '副', '食'): 1,
#  ('副', '食', '店'): 2,
#  ('食', '店', '时'): 1,
#  ('店', '时', '闲'): 1,
#  ('时', '闲', '聊'): 1,
#  ('闲', '聊', '起'): 1,
#  ('聊', '起', '来'): 1,
#  ('起', '来', '。'): 2,
#  ('来', '。', '（'): 1,
#  ('。', '（', '如'): 1,
#  ('（', '如', '果'): 1,
#  ('如', '果', '看'): 1,
#  ('果', '看', '帖'): 1,
#  ('看', '帖', '的'): 1,
#  ('帖', '的', '有'): 1,
#  ('的', '有', '老'): 1,
#  ('有', '老', '云'): 1,
#  ('老', '云', '阳'): 1,
#  ('云', '阳', '人'): 1,
#  ('阳', '人', '，'): 1,
#  ('人', '，', '我'): 1,
#  ('，', '我', '告'): 1,
#  ('我', '告', '诉'): 1,
#  ('告', '诉', '你'): 1,
#  ('诉', '你', '，'): 1,
#  ('你', '，', '老'): 1,
#  ('，', '老', '邓'): 11,
#  ('老', '邓', '的'): 1,
#  ('邓', '的', '店'): 1,
#  ('的', '店', '就'): 1,
#  ('店', '就', '是'): 1,
#  ('就', '是', '老'): 1,
#  ('是', '老', '城'): 1,
#  ('老', '城', '西'): 1,
#  ('城', '西', '坪'): 1,
#  ('西', '坪', '电'): 2,
#  ('坪', '电', '影'): 2,
#  ('电', '影', '院'): 2,
#  ('影', '院', '丁'): 1,
#  ('院', '丁', '字'): 1,
#  ('丁', '字', '路'): 1,
#  ('字', '路', '口'): 1,
#  ('路', '口', '正'): 1,
#  ('口', '正', '对'): 1,
#  ('正', '对', '的'): 1,
#  ('对', '的', '那'): 1,
#  ('的', '那', '家'): 1,
#  ('那', '家', '。'): 1,
#  ('家', '。', '）'): 1,
#  ('。', '）', '老'): 1,
#  ('）', '老', '邓'): 1,
#  ('老', '邓', '说'): 1,
#  ('邓', '说', '：'): 1,
#  ('说', '：', '半'): 1,
#  ('：', '半', '个'): 1,
#  ('半', '个', '月'): 1,
#  ('个', '月', '前'): 1,
#  ('月', '前', '，'): 1,
#  ('前', '，', '他'): 1,
#  ('，', '他', '家'): 1,
#  ('他', '家', '的'): 1,
#  ('家', '的', '“'): 1,
#  ('的', '“', '滚'): 1,
#  ('“', '滚', '装'): 1,
#  ('滚', '装', '船'): 4,
#  ('装', '船', '”'): 1,
#  ('船', '”', '（'): 1,
#  ('”', '（', '专'): 1,
#  ('（', '专', '门'): 1,
#  ('专', '门', '运'): 1,
#  ('门', '运', '载'): 1,
#  ('运', '载', '货'): 1,
#  ('载', '货', '车'): 1,
#  ('货', '车', '的'): 1,
#  ('车', '的', '长'): 1,
#  ('的', '长', '途'): 1,
#  ('长', '途', '船'): 1,
#  ('途', '船', '只'): 1,
#  ('船', '只', '）'): 1,
#  ('只', '）', '正'): 1,
#  ('）', '正', '在'): 1,
#  ('正', '在', '长'): 1,
#  ('在', '长', '江'): 1,
#  ('长', '江', '上'): 1,
#  ('江', '上', '航'): 1,
#  ('上', '航', '行'): 1,
#  ('航', '行', '，'): 1,
#  ('行', '，', '忽'): 1,
#  ('，', '忽', '然'): 1,
#  ('忽', '然', '看'): 1,
#  ('然', '看', '到'): 1,
#  ('看', '到', '江'): 1,
#  ('到', '江', '中'): 1,
#  ('江', '中', '浮'): 1,
#  ('中', '浮', '起'): 1,
#  ('浮', '起', '一'): 1,
#  ('起', '一', '物'): 1,
#  ('一', '物', '—'): 1,
#  ('物', '—', '—'): 1,
#  ('—', '—', '有'): 1,
#  ('—', '有', '脚'): 1,
#  ('有', '脚', '盆'): 1,
#  ('脚', '盆', '大'): 1,
#  ('盆', '大', '小'): 1,
#  ('大', '小', '，'): 1,
#  ('小', '，', '圆'): 1,
#  ('，', '圆', '球'): 1,
#  ('圆', '球', '状'): 1,
#  ('球', '状', '，'): 1,
#  ('状', '，', '乌'): 1,
#  ('，', '乌', '黑'): 1,
#  ('乌', '黑', '锃'): 1,
#  ('黑', '锃', '亮'): 1,
#  ('锃', '亮', '地'): 1,
#  ('亮', '地', '反'): 1,
#  ('地', '反', '着'): 1,
#  ('反', '着', '光'): 1,
#  ('着', '光', '。'): 1,
#  ('光', '。', '老'): 1,
#  ('。', '老', '邓'): 1,
#  ('老', '邓', '认'): 1,
#  ('邓', '认', '为'): 1,
#  ('认', '为', '定'): 1,
#  ('为', '定', '是'): 1,
#  ('定', '是', '宝'): 1,
#  ('是', '宝', '贝'): 1,
#  ('宝', '贝', '，'): 1,
#  ('贝', '，', '赶'): 1,
#  ('，', '赶', '紧'): 2,
#  ('赶', '紧', '让'): 1,
#  ('紧', '让', '船'): 1,
#  ('让', '船', '员'): 1,
#  ('船', '员', '取'): 1,
#  ('员', '取', '来'): 1,
#  ('取', '来', '渔'): 1,
#  ('来', '渔', '网'): 1,
#  ('渔', '网', '，'): 1,
#  ('网', '，', '待'): 1,
#  ('，', '待', '船'): 1,
#  ('待', '船', '靠'): 1,
#  ('船', '靠', '近'): 1,
#  ('靠', '近', '后'): 1,
#  ('近', '后', '，'): 1,
#  ('后', '，', '一'): 1,
#  ('，', '一', '网'): 1,
#  ('一', '网', '就'): 1,
#  ('网', '就', '把'): 1,
#  ('就', '把', '它'): 1,
#  ('把', '它', '捞'): 1,
#  ('它', '捞', '了'): 1,
#  ('捞', '了', '起'): 1,
#  ('了', '起', '来'): 1,
#  ('来', '。', '放'): 1,
#  ('。', '放', '到'): 1,
#  ('放', '到', '甲'): 1,
#  ('到', '甲', '板'): 1,
#  ('甲', '板', '上'): 2,
#  ('板', '上', '一'): 1,
#  ('上', '一', '看'): 1,
#  ('一', '看', '，'): 1,
#  ('看', '，', '原'): 1,
#  ('，', '原', '来'): 1,
#  ('原', '来', '是'): 1,
#  ('来', '是', '只'): 1,
#  ('是', '只', '巨'): 1,
#  ('只', '巨', '龟'): 1,
#  ('巨', '龟', '，'): 1,
#  ('龟', '，', '龟'): 1,
#  ('，', '龟', '壳'): 1,
#  ('龟', '壳', '直'): 1,
#  ('壳', '直', '径'): 1,
#  ('直', '径', '就'): 1,
#  ('径', '就', '有'): 1,
#  ('就', '有', '6'): 1,
#  ('有', '6', '0'): 1,
#  ('6', '0', '厘'): 1,
#  ('0', '厘', '米'): 1,
#  ('厘', '米', '，'): 1,
#  ('米', '，', '而'): 1,
#  ('而', '且', '上'): 1,
#  ('且', '上', '面'): 1,
#  ('上', '面', '还'): 1,
#  ('面', '还', '刻'): 1,
#  ('还', '刻', '有'): 1,
#  ('刻', '有', '一'): 1,
#  ('有', '一', '些'): 1,
#  ('一', '些', '文'): 1,
#  ('些', '文', '字'): 1,
#  ('文', '字', '：'): 1,
#  ('字', '：', '“'): 1,
#  ('：', '“', 'X'): 1,
#  ('“', 'X', 'X'): 2,
#  ('X', 'X', '于'): 2,
#  ('X', '于', 'X'): 2,
#  ('于', 'X', 'X'): 2,
#  ('X', 'X', '年'): 2,
#  ('X', '年', '遇'): 1,
#  ('年', '遇', '而'): 1,
#  ('遇', '而', '放'): 1,
#  ('而', '放', '生'): 1,
#  ('放', '生', '”'): 1,
#  ('生', '”', '、'): 1,
#  ('”', '、', '“'): 1,
#  ('、', '“', 'X'): 1,
#  ('X', '年', '结'): 1,
#  ('年', '结', '缘'): 1,
#  ('结', '缘', '”'): 1,
#  ('缘', '”', '…'): 1,
#  ('”', '…', '…'): 1,
#  ('…', '…', '从'): 1,
#  ('…', '从', '年'): 1,
#  ('从', '年', '号'): 1,
#  ('年', '号', '上'): 1,
#  ('号', '上', '来'): 1,
#  ('上', '来', '看'): 1,
#  ('来', '看', '，'): 1,
#  ('看', '，', '明'): 1,
#  ('，', '明', '、'): 1,
#  ('明', '、', '清'): 1,
#  ('、', '清', '年'): 1,
#  ('清', '年', '间'): 1,
#  ('年', '间', '的'): 1,
#  ('间', '的', '都'): 1,
#  ('的', '都', '有'): 1,
#  ('都', '有', '，'): 1,
#  ('有', '，', '另'): 1,
#  ('，', '另', '外'): 1,
#  ('另', '外', '还'): 1,
#  ('外', '还', '有'): 1,
#  ('还', '有', '少'): 1,
#  ('有', '少', '许'): 1,
#  ('少', '许', '距'): 1,
#  ('许', '距', '离'): 1,
#  ('距', '离', '很'): 1,
#  ('离', '很', '近'): 1,
#  ('很', '近', '的'): 1,
#  ('近', '的', '小'): 1,
#  ('的', '小', '孔'): 1,
#  ('小', '孔', '，'): 1,
#  ('孔', '，', '两'): 1,
#  ('，', '两', '孔'): 1,
#  ('两', '孔', '一'): 1,
#  ('孔', '一', '组'): 1,
#  ('一', '组', '，'): 1,
#  ('组', '，', '他'): 1,
#  ('，', '他', '们'): 1,
#  ('他', '们', '估'): 1,
#  ('们', '估', '计'): 1,
#  ('估', '计', '是'): 2,
#  ('计', '是', '古'): 1,
#  ('是', '古', '人'): 1,
#  ('古', '人', '曾'): 1,
#  ('人', '曾', '在'): 1,
#  ('曾', '在', '上'): 1,
#  ('在', '上', '面'): 1,
#  ('上', '面', '安'): 1,
#  ('面', '安', '装'): 1,
#  ('安', '装', '过'): 1,
#  ('装', '过', '金'): 1,
#  ('过', '金', '银'): 1,
#  ('金', '银', '饰'): 1,
#  ('银', '饰', '品'): 1,
#  ('饰', '品', '，'): 1,
#  ('品', '，', '但'): 1,
#  ('，', '但', '历'): 1,
#  ('但', '历', '经'): 1,
#  ('历', '经', '岁'): 1,
#  ('经', '岁', '月'): 1,
#  ('岁', '月', '的'): 1,
#  ('月', '的', '洗'): 1,
#  ('的', '洗', '礼'): 1}

# %%
dict(islice(word_pair_freq.items(), 2000))
# Out:
# {('\u3000', '\u3000'): 5912,
#  ('\u3000', '我'): 5896,
#  ('我', '有'): 5895,
#  ('有', '一'): 5896,
#  ('一', '小'): 5895,
#  ('小', '学'): 5895,
#  ('学', '（'): 5895,
#  ('（', '云'): 5895,
#  ('云', '师'): 5895,
#  ('师', '附'): 5895,
#  ('附', '小'): 5895,
#  ('小', '）'): 5895,
#  ('）', '女'): 5895,
#  ('女', '同'): 5895,
#  ('同', '学'): 5896,
#  ('学', '，'): 5896,
#  ('，', '但'): 5901,
#  ('但', '只'): 5895,
#  ('只', '同'): 5895,
#  ('同', '年'): 5895,
#  ('年', '级'): 5895,
#  ('级', '不'): 5895,
#  ('不', '同'): 5895,
#  ('同', '班'): 5896,
#  ('班', '，'): 5895,
#  ('，', '名'): 5895,
#  ('名', '邓'): 5895,
#  ('邓', '银'): 5898,
#  ('银', '华'): 5898,
#  ('华', '，'): 5896,
#  ('，', '我'): 5907,
#  ('我', '今'): 5895,
#  ('今', '天'): 5895,
#  ('天', '来'): 5895,
#  ('来', '讲'): 5895,
#  ('讲', '她'): 5895,
#  ('她', '家'): 5895,
#  ('家', '的'): 5896,
#  ('的', '一'): 5895,
#  ('一', '则'): 5896,
#  ('则', '故'): 5895,
#  ('故', '事'): 5895,
#  ('事', '。'): 5895,
#  ('。', '邓'): 5895,
#  ('华', '不'): 5895,
#  ('不', '但'): 5895,
#  ('但', '成'): 5895,
#  ('成', '绩'): 5895,
#  ('绩', '好'): 5895,
#  ('好', '，'): 5896,
#  ('，', '人'): 5895,
#  ('人', '也'): 5895,
#  ('也', '长'): 5895,
#  ('长', '得'): 5895,
#  ('得', '非'): 5895,
#  ('非', '常'): 5895,
#  ('常', '娇'): 5895,
#  ('娇', '小'): 5895,
#  ('小', '可'): 5895,
#  ('可', '爱'): 5895,
#  ('爱', '，'): 5895,
#  ('，', '把'): 5897,
#  ('把', '我'): 5895,
#  ('我', '一'): 5896,
#  ('一', '个'): 5896,
#  ('个', '同'): 5895,
#  ('班', '叫'): 5895,
#  ('叫', '李'): 5895,
#  ('李', '冬'): 5895,
#  ('冬', '华'): 5895,
#  ('华', '的'): 5895,
#  ('的', '男'): 5895,
#  ('男', '生'): 5895,
#  ('生', '迷'): 5895,
#  ('迷', '得'): 5895,
#  ('得', '一'): 5895,
#  ('一', '愣'): 5896,
#  ('愣', '一'): 5895,
#  ('愣', '的'): 5895,
#  ('的', '，'): 5896,
#  ('，', '后'): 5897,
#  ('后', '来'): 5898,
#  ('来', '上'): 5895,
#  ('上', '初'): 5895,
#  ('初', '中'): 5895,
#  ('中', '后'): 5895,
#  ('后', '还'): 5895,
#  ('还', '给'): 5895,
#  ('给', '人'): 5895,
#  ('人', '家'): 5896,
#  ('家', '女'): 5895,
#  ('女', '孩'): 5896,
#  ('孩', '子'): 5896,
#  ('子', '写'): 5895,
#  ('写', '过'): 5895,
#  ('过', '带'): 5895,
#  ('带', '血'): 5895,
#  ('血', '的'): 5895,
#  ('的', '情'): 5895,
#  ('情', '书'): 5895,
#  ('书', '。'): 5895,
#  ('。', '但'): 5895,
#  ('但', '我'): 5896,
#  ('我', '不'): 5897,
#  ('不', '是'): 5898,
#  ('是', '琼'): 5895,
#  ('琼', '瑶'): 5895,
#  ('瑶', '阿'): 5895,
#  ('阿', '姨'): 5895,
#  ('姨', '，'): 5895,
#  ('，', '对'): 5895,
#  ('对', '这'): 5895,
#  ('这', '些'): 5895,
#  ('些', '情'): 5895,
#  ('情', '啊'): 5895,
#  ('啊', '爱'): 5895,
#  ('爱', '啊'): 5895,
#  ('啊', '天'): 5895,
#  ('天', '生'): 5895,
#  ('生', '迟'): 5895,
#  ('迟', '钝'): 5895,
#  ('钝', '，'): 5895,
#  ('，', '而'): 5896,
#  ('而', '且'): 5897,
#  ('且', '那'): 5895,
#  ('那', '也'): 5896,
#  ('也', '不'): 5896,
#  ('是', '我'): 5895,
#  ('我', '写'): 5895,
#  ('写', '这'): 5895,
#  ('这', '篇'): 5896,
#  ('篇', '文'): 5896,
#  ('文', '章'): 5897,
#  ('章', '的'): 5895,
#  ('的', '初'): 5895,
#  ('初', '衷'): 5895,
#  ('衷', '，'): 5895,
#  ('，', '所'): 5896,
#  ('所', '以'): 5895,
#  ('以', '就'): 5895,
#  ('就', '不'): 5895,
#  ('不', '再'): 5896,
#  ('再', '八'): 5895,
#  ('八', '卦'): 5895,
#  ('卦', '。'): 5895,
#  ('。', '\u3000'): 5904,
#  ('\u3000', '言'): 5895,
#  ('言', '归'): 5895,
#  ('归', '正'): 5895,
#  ('正', '传'): 5895,
#  ('传', '，'): 5895,
#  ('，', '话'): 5895,
#  ('话', '说'): 5895,
#  ('说', '大'): 5895,
#  ('大', '约'): 5895,
#  ('约', '1'): 5895,
#  ('1', '9'): 5895,
#  ('9', '9'): 5895,
#  ('9', '8'): 5896,
#  ('8', '的'): 5895,
#  ('的', '时'): 5895,
#  ('时', '候'): 5895,
#  ('候', '（'): 5895,
#  ('（', '对'): 5895,
#  ('对', '！'): 5895,
#  ('！', '就'): 5895,
#  ('就', '夏'): 5895,
#  ('夏', '洛'): 5895,
#  ('洛', '和'): 5895,
#  ('和', '娜'): 5895,
#  ('娜', '姐'): 5895,
#  ('姐', '合'): 5895,
#  ('合', '唱'): 5895,
#  ('唱', '《'): 5895,
#  ('《', '相'): 5895,
#  ('相', '约'): 5895,
#  ('约', '9'): 5895,
#  ('8', '》'): 5895,
#  ('》', '那'): 5895,
#  ('那', '年'): 5895,
#  ('年', '）'): 5895,
#  ('）', '，'): 5899,
#  ('我', '老'): 5900,
#  ('老', '爸'): 5901,
#  ('爸', '从'): 5895,
#  ('从', '老'): 5895,
#  ('老', '家'): 5895,
#  ('家', '回'): 5895,
#  ('回', '成'): 5895,
#  ('成', '都'): 5897,
#  ('都', '，'): 5895,
#  ('，', '给'): 5896,
#  ('给', '我'): 5896,
#  ('我', '讲'): 5896,
#  ('讲', '了'): 5895,
#  ('了', '一'): 5898,
#  ('则', '稀'): 5895,
#  ('稀', '罕'): 5895,
#  ('罕', '事'): 5895,
#  ('事', '：'): 5895,
#  ('：', '\u3000'): 5895,
#  ('爸', '与'): 5895,
#  ('与', '邓'): 5895,
#  ('华', '老'): 5895,
#  ('爸', '是'): 5895,
#  ('是', '老'): 5896,
#  ('老', '同'): 5895,
#  ('，', '一'): 5898,
#  ('一', '天'): 5895,
#  ('天', '经'): 5895,
#  ('经', '过'): 5895,
#  ('过', '老'): 5895,
#  ('老', '邓'): 5913,
#  ('邓', '家'): 5898,
#  ('家', '开'): 5895,
#  ('开', '的'): 5895,
#  ('的', '副'): 5895,
#  ('副', '食'): 5896,
#  ('食', '店'): 5896,
#  ('店', '时'): 5895,
#  ('时', '闲'): 5895,
#  ('闲', '聊'): 5895,
#  ('聊', '起'): 5895,
#  ('起', '来'): 5896,
#  ('来', '。'): 5896,
#  ('。', '（'): 5896,
#  ('（', '如'): 5895,
#  ('如', '果'): 5895,
#  ('果', '看'): 5895,
#  ('看', '帖'): 5895,
#  ('帖', '的'): 5895,
#  ('的', '有'): 5895,
#  ('有', '老'): 5895,
#  ('老', '云'): 5895,
#  ('云', '阳'): 5896,
#  ('阳', '人'): 5895,
#  ('人', '，'): 5896,
#  ('我', '告'): 5895,
#  ('告', '诉'): 5895,
#  ('诉', '你'): 5895,
#  ('你', '，'): 5895,
#  ('，', '老'): 5905,
#  ('邓', '的'): 5895,
#  ('的', '店'): 5895,
#  ('店', '就'): 5895,
#  ('就', '是'): 5896,
#  ('老', '城'): 5895,
#  ('城', '西'): 5895,
#  ('西', '坪'): 5896,
#  ('坪', '电'): 5896,
#  ('电', '影'): 5896,
#  ('影', '院'): 5896,
#  ('院', '丁'): 5895,
#  ('丁', '字'): 5895,
#  ('字', '路'): 5895,
#  ('路', '口'): 5896,
#  ('口', '正'): 5895,
#  ('正', '对'): 5895,
#  ('对', '的'): 5895,
#  ('的', '那'): 5895,
#  ('那', '家'): 5895,
#  ('家', '。'): 5895,
#  ('。', '）'): 5896,
#  ('）', '老'): 5895,
#  ('邓', '说'): 5895,
#  ('说', '：'): 5897,
#  ('：', '半'): 5895,
#  ('半', '个'): 5895,
#  ('个', '月'): 5895,
#  ('月', '前'): 5895,
#  ('前', '，'): 5895,
#  ('，', '他'): 5898,
#  ('他', '家'): 5896,
#  ('的', '“'): 5896,
#  ('“', '滚'): 5895,
#  ('滚', '装'): 5898,
#  ('装', '船'): 5898,
#  ('船', '”'): 5895,
#  ('”', '（'): 5895,
#  ('（', '专'): 5895,
#  ('专', '门'): 5895,
#  ('门', '运'): 5895,
#  ('运', '载'): 5895,
#  ('载', '货'): 5895,
#  ('货', '车'): 5897,
#  ('车', '的'): 5895,
#  ('的', '长'): 5895,
#  ('长', '途'): 5895,
#  ('途', '船'): 5895,
#  ('船', '只'): 5895,
#  ('只', '）'): 5895,
#  ('）', '正'): 5895,
#  ('正', '在'): 5896,
#  ('在', '长'): 5895,
#  ('长', '江'): 5896,
#  ('江', '上'): 5895,
#  ('上', '航'): 5895,
#  ('航', '行'): 5895,
#  ('行', '，'): 5895,
#  ('，', '忽'): 5895,
#  ('忽', '然'): 5895,
#  ('然', '看'): 5895,
#  ('看', '到'): 5895,
#  ('到', '江'): 5895,
#  ('江', '中'): 5895,
#  ('中', '浮'): 5895,
#  ('浮', '起'): 5895,
#  ('起', '一'): 5895,
#  ('一', '物'): 5895,
#  ('物', '—'): 5895,
#  ('—', '—'): 5896,
#  ('—', '有'): 5895,
#  ('有', '脚'): 5895,
#  ('脚', '盆'): 5895,
#  ('盆', '大'): 5895,
#  ('大', '小'): 5895,
#  ('小', '，'): 5895,
#  ('，', '圆'): 5895,
#  ('圆', '球'): 5895,
#  ('球', '状'): 5895,
#  ('状', '，'): 5895,
#  ('，', '乌'): 5895,
#  ('乌', '黑'): 5895,
#  ('黑', '锃'): 5895,
#  ('锃', '亮'): 5895,
#  ('亮', '地'): 5895,
#  ('地', '反'): 5895,
#  ('反', '着'): 5895,
#  ('着', '光'): 5895,
#  ('光', '。'): 5895,
#  ('。', '老'): 5895,
#  ('邓', '认'): 5895,
#  ('认', '为'): 5895,
#  ('为', '定'): 5895,
#  ('定', '是'): 5895,
#  ('是', '宝'): 5895,
#  ('宝', '贝'): 5896,
#  ('贝', '，'): 5895,
#  ('，', '赶'): 5896,
#  ('赶', '紧'): 5896,
#  ('紧', '让'): 5895,
#  ('让', '船'): 5895,
#  ('船', '员'): 5896,
#  ('员', '取'): 5895,
#  ('取', '来'): 5895,
#  ('来', '渔'): 5895,
#  ('渔', '网'): 5895,
#  ('网', '，'): 5895,
#  ('，', '待'): 5895,
#  ('待', '船'): 5895,
#  ('船', '靠'): 5895,
#  ('靠', '近'): 5895,
#  ('近', '后'): 5895,
#  ('后', '，'): 5899,
#  ('一', '网'): 5895,
#  ('网', '就'): 5895,
#  ('就', '把'): 5895,
#  ('把', '它'): 5895,
#  ('它', '捞'): 5895,
#  ('捞', '了'): 5895,
#  ('了', '起'): 5895,
#  ('。', '放'): 5895,
#  ('放', '到'): 5895,
#  ('到', '甲'): 5895,
#  ('甲', '板'): 5896,
#  ('板', '上'): 5896,
#  ('上', '一'): 5895,
#  ('一', '看'): 5895,
#  ('看', '，'): 5896,
#  ('，', '原'): 5895,
#  ('原', '来'): 5895,
#  ('来', '是'): 5895,
#  ('是', '只'): 5895,
#  ('只', '巨'): 5895,
#  ('巨', '龟'): 5897,
#  ('龟', '，'): 5895,
#  ('，', '龟'): 5895,
#  ('龟', '壳'): 5896,
#  ('壳', '直'): 5895,
#  ('直', '径'): 5895,
#  ('径', '就'): 5895,
#  ('就', '有'): 5895,
#  ('有', '6'): 5895,
#  ('6', '0'): 5895,
#  ('0', '厘'): 5895,
#  ('厘', '米'): 5895,
#  ('米', '，'): 5895,
#  ('且', '上'): 5895,
#  ('上', '面'): 5897,
#  ('面', '还'): 5895,
#  ('还', '刻'): 5895,
#  ('刻', '有'): 5895,
#  ('一', '些'): 5895,
#  ('些', '文'): 5895,
#  ('文', '字'): 5895,
#  ('字', '：'): 5895,
#  ('：', '“'): 5898,
#  ('“', 'X'): 5896,
#  ('X', 'X'): 5898,
#  ('X', '于'): 5896,
#  ('于', 'X'): 5896,
#  ('X', '年'): 5896,
#  ('年', '遇'): 5895,
#  ('遇', '而'): 5895,
#  ('而', '放'): 5895,
#  ('放', '生'): 5898,
#  ('生', '”'): 5895,
#  ('”', '、'): 5895,
#  ('、', '“'): 5895,
#  ('年', '结'): 5895,
#  ('结', '缘'): 5896,
#  ('缘', '”'): 5895,
#  ('”', '…'): 5895,
#  ('…', '…'): 5899,
#  ('…', '从'): 5895,
#  ('从', '年'): 5895,
#  ('年', '号'): 5895,
#  ('号', '上'): 5895,
#  ('上', '来'): 5895,
#  ('来', '看'): 5896,
#  ('，', '明'): 5895,
#  ('明', '、'): 5895,
#  ('、', '清'): 5895,
#  ('清', '年'): 5895,
#  ('年', '间'): 5895,
#  ('间', '的'): 5895,
#  ('的', '都'): 5895,
#  ('都', '有'): 5895,
#  ('有', '，'): 5896,
#  ('，', '另'): 5895,
#  ('另', '外'): 5895,
#  ('外', '还'): 5895,
#  ('还', '有'): 5895,
#  ('有', '少'): 5895,
#  ('少', '许'): 5895,
#  ('许', '距'): 5895,
#  ('距', '离'): 5895,
#  ('离', '很'): 5895,
#  ('很', '近'): 5895,
#  ('近', '的'): 5895,
#  ('的', '小'): 5895,
#  ('小', '孔'): 5895,
#  ('孔', '，'): 5895,
#  ('，', '两'): 5895,
#  ('两', '孔'): 5895,
#  ('孔', '一'): 5895,
#  ('一', '组'): 5895,
#  ('组', '，'): 5895,
#  ('他', '们'): 5897,
#  ('们', '估'): 5895,
#  ('估', '计'): 5896,
#  ('计', '是'): 5896,
#  ('是', '古'): 5895,
#  ('古', '人'): 5895,
#  ('人', '曾'): 5895,
#  ('曾', '在'): 5895,
#  ('在', '上'): 5895,
#  ('面', '安'): 5895,
#  ('安', '装'): 5895,
#  ('装', '过'): 5895,
#  ('过', '金'): 5895,
#  ('金', '银'): 5896,
#  ('银', '饰'): 5895,
#  ('饰', '品'): 5895,
#  ('品', '，'): 5895,
#  ('但', '历'): 5895,
#  ('历', '经'): 5895,
#  ('经', '岁'): 5895,
#  ('岁', '月'): 5895,
#  ('月', '的'): 5895,
#  ('的', '洗'): 5896,
#  ('洗', '礼'): 5895,
#  ('礼', '，'): 5895,
#  ('，', '金'): 5895,
#  ('银', '磨'): 5895,
#  ('磨', '耗'): 5895,
#  ('耗', '，'): 5895,
#  ('，', '现'): 5895,
#  ('现', '在'): 5895,
#  ('在', '只'): 5895,
#  ('只', '剩'): 5895,
#  ('剩', '下'): 5895,
#  ('下', '了'): 5895,
#  ('了', '孔'): 5895,
#  ('孔', '洞'): 5895,
#  ('洞', '。'): 5895,
#  ('\u3000', '船'): 5895,
#  ('船', '一'): 5895,
#  ('一', '靠'): 5895,
#  ('靠', '云'): 5895,
#  ('阳', '港'): 5895,
#  ('港', '，'): 5895,
#  ('邓', '得'): 5895,
#  ('得', '到'): 5895,
#  ('到', '“'): 5895,
#  ('“', '灵'): 5895,
#  ('灵', '龟'): 5898,
#  ('龟', '”'): 5895,
#  ('”', '的'): 5895,
#  ('的', '消'): 5895,
#  ('消', '息'): 5895,
#  ('息', '就'): 5895,
#  ('就', '在'): 5896,
#  ('在', '小'): 5895,
#  ('小', '县'): 5895,
#  ('县', '城'): 5895,
#  ('城', '内'): 5895,
#  ('内', '不'): 5895,
#  ('不', '径'): 5895,
#  ('径', '而'): 5895,
#  ('而', '走'): 5895,
#  ('走', '。'): 5895,
#  ('\u3000', '开'): 5895,
#  ('开', '始'): 5895,
#  ('始', '时'): 5895,
#  ('时', '，'): 5896,
#  ('邓', '把'): 5895,
#  ('把', '巨'): 5895,
#  ('龟', '安'): 5895,
#  ('安', '置'): 5895,
#  ('置', '在'): 5895,
#  ('在', '家'): 5895,
#  ('家', '中'): 5896,
#  ('中', '的'): 5895,
#  ('洗', '衣'): 5895,
#  ('衣', '池'): 5895,
#  ('池', '内'): 5895,
#  ('内', '，'): 5896,
#  ('，', '供'): 5895,
#  ('供', '若'): 5895,
#  ('若', '上'): 5895,
#  ('上', '宾'): 5895,
#  ('宾', '，'): 5895,
#  ('但', '每'): 5895,
#  ('每', '日'): 5895,
#  ('日', '闻'): 5895,
#  ('闻', '讯'): 5895,
#  ('讯', '前'): 5895,
#  ('前', '来'): 5895,
#  ('来', '观'): 5895,
#  ('观', '摩'): 5895,
#  ('摩', '、'): 5895,
#  ('、', '猎'): 5895,
#  ('猎', '奇'): 5895,
#  ('奇', '的'): 5895,
#  ('的', '人'): 5895,
#  ('人', '们'): 5896,
#  ('们', '把'): 5895,
#  ('把', '他'): 5895,
#  ('家', '挤'): 5895,
#  ('挤', '得'): 5895,
#  ('得', '个'): 5895,
#  ('个', '水'): 5895,
#  ('水', '泄'): 5895,
#  ('泄', '不'): 5895,
#  ('不', '通'): 5895,
#  ('通', '，'): 5895,
#  ('，', '有'): 5896,
#  ('有', '的'): 5897,
#  ('的', '啧'): 5895,
#  ('啧', '啧'): 5895,
#  ('啧', '称'): 5895,
#  ('称', '奇'): 5895,
#  ('奇', '，'): 5896,
#  ('的', '顶'): 5895,
#  ('顶', '礼'): 5895,
#  ('礼', '膜'): 5895,
#  ('膜', '拜'): 5895,
#  ('拜', '，'): 5895,
#  ('，', '好'): 5895,
#  ('好', '不'): 5895,
#  ('不', '热'): 5895,
#  ('热', '闹'): 5895,
#  ('闹', '。'): 5895,
#  ('。', '而'): 5895,
#  ('且', '所'): 5895,
#  ('所', '来'): 5895,
#  ('来', '之'): 5895,
#  ('之', '人'): 5895,
#  ('，', '大'): 5895,
#  ('大', '多'): 5895,
#  ('多', '都'): 5895,
#  ('都', '是'): 5896,
#  ('是', '非'): 5895,
#  ('非', '富'): 5895,
#  ('富', '即'): 5895,
#  ('即', '贵'): 5895,
#  ('贵', '之'): 5895,
#  ('之', '辈'): 5895,
#  ('辈', '（'): 5895,
#  ('（', '因'): 5895,
#  ('因', '为'): 5897,
#  ('为', '老'): 5895,
#  ('邓', '也'): 5895,
#  ('也', '算'): 5895,
#  ('算', '富'): 5895,
#  ('富', '商'): 5895,
#  ('商', '）'): 5895,
#  ('家', '每'): 5895,
#  ('每', '天'): 5896,
#  ('天', '接'): 5895,
#  ('接', '待'): 5896,
#  ('待', '客'): 5895,
#  ('客', '人'): 5897,
#  ('人', '的'): 5895,
#  ('的', '茶'): 5895,
#  ('茶', '水'): 5895,
#  ('水', '不'): 5895,
#  ('不', '计'): 5895,
#  ('计', '，'): 5895,
#  ('，', '光'): 5895,
#  ('光', '消'): 5895,
#  ('消', '耗'): 5895,
#  ('耗', '的'): 5895,
#  ('的', '香'): 5895,
#  ('香', '烟'): 5895,
#  ('烟', '都'): 5895,
#  ('都', '以'): 5895,
#  ('以', '条'): 5895,
#  ('条', '计'): 5895,
#  ('计', '。'): 5895,
#  ('\u3000', '说'): 5895,
#  ('说', '来'): 5895,
#  ('来', '也'): 5896,
#  ('也', '奇'): 5895,
#  ('，', '该'): 5895,
#  ('该', '巨'): 5895,
#  ('龟', '似'): 5895,
#  ('似', '乎'): 5895,
#  ('乎', '能'): 5895,
#  ('能', '听'): 5895,
#  ('听', '懂'): 5895,
#  ('懂', '人'): 5895,
#  ('人', '话'): 5895,
#  ('话', '，'): 5896,
#  ('，', '因'): 5896,
#  ('为', '如'): 5895,
#  ('如', '有'): 5895,
#  ('有', '客'): 5895,
#  ('人', '在'): 5895,
#  ('在', '旁'): 5895,
#  ('旁', '说'): 5895,
#  ('“', '好'): 5895,
#  ('好', '大'): 5895,
#  ('大', '一'): 5895,
#  ('一', '只'): 5895,
#  ('只', '乌'): 5895,
#  ('乌', '龟'): 5895,
#  ('龟', '！'): 5895,
#  ('！', '”'): 5897,
#  ('”', '它'): 5896,
#  ('它', '只'): 5895,
#  ('只', '管'): 5895,
#  ('管', '把'): 5895,
#  ('把', '头'): 5895,
#  ('头', '缩'): 5895,
#  ('缩', '在'): 5895,
#  ('在', '壳'): 5895,
#  ('壳', '里'): 5895,
#  ('里', '，'): 5895,
#  ('，', '理'): 5895,
#  ('理', '都'): 5895,
#  ('都', '不'): 5895,
#  ('不', '理'): 5895,
#  ('理', '；'): 5895,
#  ('；', '但'): 5895,
#  ('但', '若'): 5895,
#  ('若', '你'): 5895,
#  ('你', '言'): 5895,
#  ('言', '：'): 5896,
#  ('“', '真'): 5895,
#  ('真', '乃'): 5895,
#  ('乃', '神'): 5895,
#  ('神', '物'): 5895,
#  ('物', '！'): 5895,
#  ('”', '或'): 5895,
#  ('或', '你'): 5895,
#  ('你', '唤'): 5895,
#  ('唤', '它'): 5896,
#  ('它', '“'): 5895,
#  ('“', '龟'): 5898,
#  ('龟', '仙'): 5904,
#  ('仙', '！'): 5895,
#  ('它', '便'): 5895,
#  ('便', '会'): 5895,
#  ('会', '把'): 5895,
#  ('把', '脖'): 5895,
#  ('脖', '子'): 5895,
#  ('子', '伸'): 5895,
#  ('伸', '出'): 5895,
#  ('出', '来'): 5896,
#  ('看', '你'): 5895,
#  ('你', '一'): 5895,
#  ('一', '眼'): 5896,
#  ('眼', '，'): 5896,
#  ('，', '然'): 5896,
#  ('然', '后'): 5896,
#  ('后', '仍'): 5895,
#  ('仍', '旧'): 5896,
#  ('旧', '缩'): 5895,
#  ('缩', '回'): 5895,
#  ('回', '壳'): 5895,
#  ('壳', '内'): 5895,
#  ('内', '。'): 5895,
#  ('。', '于'): 5896,
#  ('于', '是'): 5899,
#  ('是', '乎'): 5895,
#  ('乎', '，'): 5895,
#  ('来', '所'): 5895,
#  ('所', '有'): 5896,
#  ('的', '客'): 5895,
#  ('人', '都'): 5895,
#  ('都', '唤'): 5895,
#  ('它', '为'): 5895,
#  ('为', '龟'): 5895,
#  ('仙', '，'): 5896,
#  ('为', '只'): 5895,
#  ('只', '有'): 5895,
#  ('有', '这'): 5895,
#  ('这', '样'): 5897,
#  ('样', '才'): 5895,
#  ('才', '能'): 5895,
#  ('能', '一'): 5895,
#  ('一', '睹'): 5895,
#  ('睹', '仙'): 5895,
#  ('仙', '颜'): 5895,
#  ('颜', '。'): 5895,
#  ('\u3000', '但'): 5895,
#  ('但', '老'): 5895,
#  ('中', '每'): 5895,
#  ('天', '都'): 5895,
#  ('都', '人'): 5895,
#  ('人', '山'): 5895,
#  ('山', '人'): 5895,
#  ('人', '海'): 5895,
#  ('海', '的'): 5895,
#  ('他', '是'): 5895,
#  ('是', '不'): 5896,
#  ('不', '胜'): 5895,
#  ('胜', '其'): 5895,
#  ('其', '烦'): 5895,
#  ('烦', '，'): 5895,
#  ('，', '于'): 5897,
#  ('是', '就'): 5895,
#  ('就', '跟'): 5896,
#  ('跟', '家'): 5895,
#  ('家', '人'): 5895,
#  ('人', '、'): 5895,
#  ('、', '亲'): 5895,
#  ('亲', '戚'): 5895,
#  ('戚', '们'): 5895,
#  ('们', '商'): 5895,
#  ('商', '量'): 5895,
#  ('量', '：'): 5895,
#  ('：', '长'): 5895,
#  ('长', '此'): 5895,
#  ('此', '以'): 5895,
#  ('以', '往'): 5895,
#  ('往', '也'): 5895,
#  ('是', '办'): 5895,
#  ('办', '法'): 5895,
#  ('法', '，'): 5896,
#  ('但', '怎'): 5895,
#  ('怎', '么'): 5895,
#  ('么', '来'): 5895,
#  ('来', '处'): 5895,
#  ('处', '理'): 5895,
#  ('理', '这'): 5895,
#  ('这', '只'): 5896,
#  ('只', '“'): 5895,
#  ('仙', '”'): 5897,
#  ('”', '呢'): 5895,
#  ('呢', '？'): 5895,
#  ('？', '\u3000'): 5895,
#  ('\u3000', '有'): 5895,
#  ('有', '人'): 5896,
#  ('人', '提'): 5895,
#  ('提', '议'): 5895,
#  ('议', '：'): 5895,
#  ('：', '既'): 5895,
#  ('既', '是'): 5895,
#  ('是', '“'): 5895,
#  ('”', '，'): 5897,
#  ('，', '说'): 5896,
#  ('说', '不'): 5895,
#  ('不', '定'): 5896,
#  ('定', '吃'): 5895,
#  ('吃', '了'): 5896,
#  ('了', '它'): 5896,
#  ('它', '就'): 5895,
#  ('就', '可'): 5895,
#  ('可', '以'): 5896,
#  ('以', '长'): 5895,
#  ('长', '生'): 5895,
#  ('生', '不'): 5895,
#  ('不', '老'): 5895,
#  ('老', '哩'): 5895,
#  ('哩', '？'): 5895,
#  ('？', '就'): 5895,
#  ('跟', '唐'): 5895,
#  ('唐', '僧'): 5895,
#  ('僧', '肉'): 5895,
#  ('肉', '一'): 5895,
#  ('一', '样'): 5895,
#  ('样', '金'): 5895,
#  ('金', '贵'): 5895,
#  ('贵', '，'): 5895,
#  ('，', '可'): 5896,
#  ('可', '别'): 5895,
#  ('别', '浪'): 5895,
#  ('浪', '费'): 5895,
#  ('费', '了'): 5895,
#  ('了', '。'): 5895,
#  ('\u3000', '又'): 5896,
#  ('又', '有'): 5895,
#  ('人', '言'): 5895,
#  ('：', '人'): 5895,
#  ('家', '活'): 5895,
#  ('活', '了'): 5895,
#  ('了', '几'): 5895,
#  ('几', '百'): 5895,
#  ('百', '上'): 5895,
#  ('上', '千'): 5895,
#  ('千', '年'): 5895,
#  ('年', '，'): 5895,
#  ('，', '没'): 5895,
#  ('没', '看'): 5895,
#  ('看', '见'): 5895,
#  ('见', '它'): 5895,
#  ('它', '背'): 5895,
#  ('背', '上'): 5895,
#  ('上', '的'): 5896,
#  ('的', '字'): 5895,
#  ('字', '么'): 5895,
#  ('么', '？'): 5895,
#  ('？', '别'): 5895,
#  ('别', '人'): 5895,
#  ('人', '个'): 5895,
#  ('个', '个'): 5895,
#  ('个', '都'): 5895,
#  ('都', '放'): 5895,
#  ('生', '，'): 5897,
#  ('，', '你'): 5895,
#  ('你', '吃'): 5895,
#  ('它', '不'): 5895,
#  ('不', '招'): 5895,
#  ('招', '灾'): 5895,
#  ('灾', '才'): 5895,
#  ('才', '怪'): 5895,
#  ('怪', '哩'): 5895,
#  ('哩', '。'): 5895,
#  ('\u3000', '人'): 5895,
#  ('人', '多'): 5895,
#  ('多', '嘴'): 5895,
#  ('嘴', '杂'): 5895,
#  ('杂', '，'): 5895,
#  ('邓', '一'): 5895,
#  ('一', '时'): 5895,
#  ('时', '拿'): 5895,
#  ('拿', '不'): 5895,
#  ('定', '主'): 5895,
#  ('主', '意'): 5895,
#  ('意', '，'): 5896,
#  ('来', '实'): 5895,
#  ('实', '在'): 5895,
#  ('在', '没'): 5895,
#  ('没', '法'): 5895,
#  ('给', '它'): 5895,
#  ('它', '拍'): 5895,
#  ('拍', '了'): 5895,
#  ('了', '照'): 5895,
#  ('照', '片'): 5898,
#  ('片', '后'): 5896,
#  ('，', '又'): 5895,
#  ('又', '悄'): 5895,
#  ('悄', '悄'): 5895,
#  ('悄', '地'): 5895,
#  ('地', '转'): 5895,
#  ('转', '运'): 5895,
#  ('运', '到'): 5895,
#  ('到', '滚'): 5895,
#  ('船', '上'): 5895,
#  ('上', '，'): 5897,
#  ('，', '这'): 5897,
#  ('样', '一'): 5896,
#  ('一', '来'): 5895,
#  ('来', '可'): 5895,
#  ('以', '不'): 5895,
#  ('再', '受'): 5895,
#  ('受', '人'): 5895,
#  ('们', '打'): 5895,
#  ('打', '扰'): 5895,
#  ('扰', '；'): 5895,
#  ('；', '二'): 5895,
#  ('二', '来'): 5895,
#  ('也', '希'): 5895,
#  ('希', '望'): 5896,
#  ('望', '龟'): 5895,
#  ('仙', '能'): 5895,
#  ('能', '保'): 5895,
#  ('保', '佑'): 5895,
#  ('佑', '一'): 5895,
#  ('一', '船'): 5895,
#  ('船', '平'): 5895,
#  ('平', '安'): 5895,
#  ('安', '。'): 5895,
#  ('\u3000', '隔'): 5895,
#  ('隔', '日'): 5895,
#  ('日', '，'): 5895,
#  ('邓', '遇'): 5895,
#  ('遇', '一'): 5895,
#  ('一', '道'): 5895,
#  ('道', '家'): 5896,
#  ('家', '朋'): 5896,
#  ('朋', '友'): 5896,
#  ('友', '（'): 5895,
#  ('（', '我'): 5896,
#  ('爸', '也'): 5896,
#  ('也', '认'): 5895,
#  ('认', '识'): 5896,
#  ('识', '，'): 5895,
#  ('不', '认'): 5895,
#  ('识', '）'): 5895,
#  ('是', '拿'): 5895,
#  ('拿', '出'): 5895,
#  ('出', '龟'): 5895,
#  ('仙', '照'): 5895,
#  ('片', '让'): 5895,
#  ('让', '其'): 5895,
#  ('其', '“'): 5895,
#  ('“', '掌'): 5895,
#  ('掌', '眼'): 5895,
#  ('眼', '”'): 5895,
#  ('，', '不'): 5896,
#  ('不', '想'): 5895,
#  ('想', '道'): 5895,
#  ('友', '看'): 5895,
#  ('看', '了'): 5895,
#  ('眼', '照'): 5895,
#  ('后', '说'): 5895,
#  ('说', '道'): 5895,
#  ('道', '：'): 5895,
#  ('“', '你'): 5895,
#  ('你', '还'): 5895,
#  ('还', '不'): 5895,
#  ('不', '将'): 5895,
#  ('将', '它'): 5895,
#  ('它', '放'): 5895,
#  ('，', '它'): 5895,
#  ('它', '已'): 5895,
#  ('已', '经'): 5895,
#  ('经', '有'): 5895,
#  ('有', '些'): 5897,
#  ('些', '怒'): 5895,
#  ('怒', '意'): 5895,
#  ('意', '了'): 5895,
#  ('了', '，'): 5895,
#  ('紧', '放'): 5895,
#  ('，', '越'): 5895,
#  ('越', '快'): 5895,
#  ('快', '越'): 5895,
#  ('越', '好'): 5895,
#  ('不', '然'): 5895,
#  ('然', '你'): 5895,
#  ('你', '家'): 5895,
#  ('家', '会'): 5895,
#  ('会', '招'): 5895,
#  ('招', '来'): 5895,
#  ('来', '无'): 5895,
#  ('无', '妄'): 5895,
#  ('妄', '之'): 5895,
#  ('之', '灾'): 5895,
#  ('灾', '。'): 5895,
#  ('。', '”'): 5895,
#  ('”', '\u3000'): 5895,
#  ('\u3000', '老'): 5896,
#  ('邓', '听'): 5895,
#  ('听', '了'): 5895,
#  ('了', '心'): 5895,
#  ('心', '里'): 5895,
#  ('里', '自'): 5895,
#  ('自', '然'): 5896,
#  ('然', '也'): 5895,
#  ('也', '有'): 5895,
#  ('些', '忐'): 5895,
#  ('忐', '忑'): 5895,
#  ('忑', '，'): 5895,
#  ('但', '这'): 5895,
#  ('一', '件'): 5896,
#  ('件', '“'): 5895,
#  ('“', '宝'): 5895,
#  ('贝', '”'): 5895,
#  ('说', '放'): 5895,
#  ('放', '手'): 5896,
#  ('手', '就'): 5895,
#  ('就', '放'): 5895,
#  ('手', '，'): 5895,
#  ('，', '那'): 5895,
#  ('也', '是'): 5895,
#  ('是', '万'): 5895,
#  ...}

# %%
# 計算概率
tri_gram_probs = {tri_gram: freq / word_pair_freq[(tri_gram[0], tri_gram[1])] for tri_gram, freq in tri_gram_freq.items()}

# %%
dict(islice(tri_gram_probs.items(), 500))
# Out:
# {('\u3000', '\u3000', '我'): 0.00033829499323410016,
#  ('\u3000', '我', '有'): 0.00016960651289009497,
#  ('我', '有', '一'): 0.00016963528413910093,
#  ('有', '一', '小'): 0.00016960651289009497,
#  ('一', '小', '学'): 0.00016963528413910093,
#  ('小', '学', '（'): 0.00016963528413910093,
#  ('学', '（', '云'): 0.00016963528413910093,
#  ('（', '云', '师'): 0.00016963528413910093,
#  ('云', '师', '附'): 0.00016963528413910093,
#  ('师', '附', '小'): 0.00016963528413910093,
#  ('附', '小', '）'): 0.00016963528413910093,
#  ('小', '）', '女'): 0.00016963528413910093,
#  ('）', '女', '同'): 0.00016963528413910093,
#  ('女', '同', '学'): 0.00016963528413910093,
#  ('同', '学', '，'): 0.00033921302578018993,
#  ('学', '，', '但'): 0.00016960651289009497,
#  ('，', '但', '只'): 0.0001694628029147602,
#  ('但', '只', '同'): 0.00016963528413910093,
#  ('只', '同', '年'): 0.00016963528413910093,
#  ('同', '年', '级'): 0.00016963528413910093,
#  ('年', '级', '不'): 0.00016963528413910093,
#  ('级', '不', '同'): 0.00016963528413910093,
#  ('不', '同', '班'): 0.00016963528413910093,
#  ('同', '班', '，'): 0.00016960651289009497,
#  ('班', '，', '名'): 0.00016963528413910093,
#  ('，', '名', '邓'): 0.00016963528413910093,
#  ('名', '邓', '银'): 0.00016963528413910093,
#  ('邓', '银', '华'): 0.0006781959986436081,
#  ('银', '华', '，'): 0.00033909799932180403,
#  ('华', '，', '我'): 0.00016960651289009497,
#  ('，', '我', '今'): 0.00016929067208396818,
#  ('我', '今', '天'): 0.00016963528413910093,
#  ('今', '天', '来'): 0.00016963528413910093,
#  ('天', '来', '讲'): 0.00016963528413910093,
#  ('来', '讲', '她'): 0.00016963528413910093,
#  ('讲', '她', '家'): 0.00016963528413910093,
#  ('她', '家', '的'): 0.00016963528413910093,
#  ('家', '的', '一'): 0.00016960651289009497,
#  ('的', '一', '则'): 0.00016963528413910093,
#  ('一', '则', '故'): 0.00016960651289009497,
#  ('则', '故', '事'): 0.00016963528413910093,
#  ('故', '事', '。'): 0.00016963528413910093,
#  ('事', '。', '邓'): 0.00016963528413910093,
#  ('。', '邓', '银'): 0.00016963528413910093,
#  ('银', '华', '不'): 0.00016954899966090201,
#  ('华', '不', '但'): 0.00016963528413910093,
#  ('不', '但', '成'): 0.00016963528413910093,
#  ('但', '成', '绩'): 0.00016963528413910093,
#  ('成', '绩', '好'): 0.00016963528413910093,
#  ('绩', '好', '，'): 0.00016963528413910093,
#  ('好', '，', '人'): 0.00016960651289009497,
#  ('，', '人', '也'): 0.00016963528413910093,
#  ('人', '也', '长'): 0.00016963528413910093,
#  ('也', '长', '得'): 0.00016963528413910093,
#  ('长', '得', '非'): 0.00016963528413910093,
#  ('得', '非', '常'): 0.00016963528413910093,
#  ('非', '常', '娇'): 0.00016963528413910093,
#  ('常', '娇', '小'): 0.00016963528413910093,
#  ('娇', '小', '可'): 0.00016963528413910093,
#  ('小', '可', '爱'): 0.00016963528413910093,
#  ('可', '爱', '，'): 0.00016963528413910093,
#  ('爱', '，', '把'): 0.00016963528413910093,
#  ('，', '把', '我'): 0.00016957775139901646,
#  ('把', '我', '一'): 0.00016963528413910093,
#  ('我', '一', '个'): 0.00016960651289009497,
#  ('一', '个', '同'): 0.00016960651289009497,
#  ('个', '同', '班'): 0.00016963528413910093,
#  ('同', '班', '叫'): 0.00016960651289009497,
#  ('班', '叫', '李'): 0.00016963528413910093,
#  ('叫', '李', '冬'): 0.00016963528413910093,
#  ('李', '冬', '华'): 0.00016963528413910093,
#  ('冬', '华', '的'): 0.00016963528413910093,
#  ('华', '的', '男'): 0.00016963528413910093,
#  ('的', '男', '生'): 0.00016963528413910093,
#  ('男', '生', '迷'): 0.00016963528413910093,
#  ('生', '迷', '得'): 0.00016963528413910093,
#  ('迷', '得', '一'): 0.00016963528413910093,
#  ('得', '一', '愣'): 0.00016963528413910093,
#  ('一', '愣', '一'): 0.00016960651289009497,
#  ('愣', '一', '愣'): 0.00016963528413910093,
#  ('一', '愣', '的'): 0.00016960651289009497,
#  ('愣', '的', '，'): 0.00016963528413910093,
#  ('的', '，', '后'): 0.00016960651289009497,
#  ('，', '后', '来'): 0.0005087332541970493,
#  ('后', '来', '上'): 0.00016954899966090201,
#  ('来', '上', '初'): 0.00016963528413910093,
#  ('上', '初', '中'): 0.00016963528413910093,
#  ('初', '中', '后'): 0.00016963528413910093,
#  ('中', '后', '还'): 0.00016963528413910093,
#  ('后', '还', '给'): 0.00016963528413910093,
#  ('还', '给', '人'): 0.00016963528413910093,
#  ('给', '人', '家'): 0.00016963528413910093,
#  ('人', '家', '女'): 0.00016960651289009497,
#  ('家', '女', '孩'): 0.00016963528413910093,
#  ('女', '孩', '子'): 0.00033921302578018993,
#  ('孩', '子', '写'): 0.00016960651289009497,
#  ('子', '写', '过'): 0.00016963528413910093,
#  ('写', '过', '带'): 0.00016963528413910093,
#  ('过', '带', '血'): 0.00016963528413910093,
#  ('带', '血', '的'): 0.00016963528413910093,
#  ('血', '的', '情'): 0.00016963528413910093,
#  ('的', '情', '书'): 0.00016963528413910093,
#  ('情', '书', '。'): 0.00016963528413910093,
#  ('书', '。', '但'): 0.00016963528413910093,
#  ('。', '但', '我'): 0.00016963528413910093,
#  ('但', '我', '不'): 0.00033921302578018993,
#  ('我', '不', '是'): 0.00016957775139901646,
#  ('不', '是', '琼'): 0.00016954899966090201,
#  ('是', '琼', '瑶'): 0.00016963528413910093,
#  ('琼', '瑶', '阿'): 0.00016963528413910093,
#  ('瑶', '阿', '姨'): 0.00016963528413910093,
#  ('阿', '姨', '，'): 0.00016963528413910093,
#  ('姨', '，', '对'): 0.00016963528413910093,
#  ('，', '对', '这'): 0.00016963528413910093,
#  ('对', '这', '些'): 0.00016963528413910093,
#  ('这', '些', '情'): 0.00016963528413910093,
#  ('些', '情', '啊'): 0.00016963528413910093,
#  ('情', '啊', '爱'): 0.00016963528413910093,
#  ('啊', '爱', '啊'): 0.00016963528413910093,
#  ('爱', '啊', '天'): 0.00016963528413910093,
#  ('啊', '天', '生'): 0.00016963528413910093,
#  ('天', '生', '迟'): 0.00016963528413910093,
#  ('生', '迟', '钝'): 0.00016963528413910093,
#  ('迟', '钝', '，'): 0.00016963528413910093,
#  ('钝', '，', '而'): 0.00016963528413910093,
#  ('，', '而', '且'): 0.00033921302578018993,
#  ('而', '且', '那'): 0.00016957775139901646,
#  ('且', '那', '也'): 0.00016963528413910093,
#  ('那', '也', '不'): 0.00016960651289009497,
#  ('也', '不', '是'): 0.00033921302578018993,
#  ('不', '是', '我'): 0.00016954899966090201,
#  ('是', '我', '写'): 0.00016963528413910093,
#  ('我', '写', '这'): 0.00016963528413910093,
#  ('写', '这', '篇'): 0.00016963528413910093,
#  ('这', '篇', '文'): 0.00033921302578018993,
#  ('篇', '文', '章'): 0.00033921302578018993,
#  ('文', '章', '的'): 0.00016957775139901646,
#  ('章', '的', '初'): 0.00016963528413910093,
#  ('的', '初', '衷'): 0.00016963528413910093,
#  ('初', '衷', '，'): 0.00016963528413910093,
#  ('衷', '，', '所'): 0.00016963528413910093,
#  ('，', '所', '以'): 0.00016960651289009497,
#  ('所', '以', '就'): 0.00016963528413910093,
#  ('以', '就', '不'): 0.00016963528413910093,
#  ('就', '不', '再'): 0.00016963528413910093,
#  ('不', '再', '八'): 0.00016960651289009497,
#  ('再', '八', '卦'): 0.00016963528413910093,
#  ('八', '卦', '。'): 0.00016963528413910093,
#  ('卦', '。', '\u3000'): 0.00016963528413910093,
#  ('。', '\u3000', '\u3000'): 0.0016937669376693768,
#  ('\u3000', '\u3000', '言'): 0.00016914749661705008,
#  ('\u3000', '言', '归'): 0.00016963528413910093,
#  ('言', '归', '正'): 0.00016963528413910093,
#  ('归', '正', '传'): 0.00016963528413910093,
#  ('正', '传', '，'): 0.00016963528413910093,
#  ('传', '，', '话'): 0.00016963528413910093,
#  ('，', '话', '说'): 0.00016963528413910093,
#  ('话', '说', '大'): 0.00016963528413910093,
#  ('说', '大', '约'): 0.00016963528413910093,
#  ('大', '约', '1'): 0.00016963528413910093,
#  ('约', '1', '9'): 0.00016963528413910093,
#  ('1', '9', '9'): 0.00016963528413910093,
#  ('9', '9', '8'): 0.00016963528413910093,
#  ('9', '8', '的'): 0.00016960651289009497,
#  ('8', '的', '时'): 0.00016963528413910093,
#  ('的', '时', '候'): 0.00016963528413910093,
#  ('时', '候', '（'): 0.00016963528413910093,
#  ('候', '（', '对'): 0.00016963528413910093,
#  ('（', '对', '！'): 0.00016963528413910093,
#  ('对', '！', '就'): 0.00016963528413910093,
#  ('！', '就', '夏'): 0.00016963528413910093,
#  ('就', '夏', '洛'): 0.00016963528413910093,
#  ('夏', '洛', '和'): 0.00016963528413910093,
#  ('洛', '和', '娜'): 0.00016963528413910093,
#  ('和', '娜', '姐'): 0.00016963528413910093,
#  ('娜', '姐', '合'): 0.00016963528413910093,
#  ('姐', '合', '唱'): 0.00016963528413910093,
#  ('合', '唱', '《'): 0.00016963528413910093,
#  ('唱', '《', '相'): 0.00016963528413910093,
#  ('《', '相', '约'): 0.00016963528413910093,
#  ('相', '约', '9'): 0.00016963528413910093,
#  ('约', '9', '8'): 0.00016963528413910093,
#  ('9', '8', '》'): 0.00016960651289009497,
#  ('8', '》', '那'): 0.00016963528413910093,
#  ('》', '那', '年'): 0.00016963528413910093,
#  ('那', '年', '）'): 0.00016963528413910093,
#  ('年', '）', '，'): 0.00016963528413910093,
#  ('）', '，', '我'): 0.00016952025767079165,
#  ('，', '我', '老'): 0.0005078720162519045,
#  ('我', '老', '爸'): 0.001016949152542373,
#  ('老', '爸', '从'): 0.0001694628029147602,
#  ('爸', '从', '老'): 0.00016963528413910093,
#  ('从', '老', '家'): 0.00016963528413910093,
#  ('老', '家', '回'): 0.00016963528413910093,
#  ('家', '回', '成'): 0.00016963528413910093,
#  ('回', '成', '都'): 0.00016963528413910093,
#  ('成', '都', '，'): 0.00016957775139901646,
#  ('都', '，', '给'): 0.00016963528413910093,
#  ('，', '给', '我'): 0.00016960651289009497,
#  ('给', '我', '讲'): 0.00033921302578018993,
#  ('我', '讲', '了'): 0.00016960651289009497,
#  ('讲', '了', '一'): 0.00016963528413910093,
#  ('了', '一', '则'): 0.00016954899966090201,
#  ('一', '则', '稀'): 0.00016960651289009497,
#  ('则', '稀', '罕'): 0.00016963528413910093,
#  ('稀', '罕', '事'): 0.00016963528413910093,
#  ('罕', '事', '：'): 0.00016963528413910093,
#  ('事', '：', '\u3000'): 0.00016963528413910093,
#  ('：', '\u3000', '\u3000'): 0.00016963528413910093,
#  ('\u3000', '我', '老'): 0.00016960651289009497,
#  ('老', '爸', '与'): 0.0001694628029147602,
#  ('爸', '与', '邓'): 0.00016963528413910093,
#  ('与', '邓', '银'): 0.00016963528413910093,
#  ('银', '华', '老'): 0.00016954899966090201,
#  ('华', '老', '爸'): 0.00016963528413910093,
#  ('老', '爸', '是'): 0.0001694628029147602,
#  ('爸', '是', '老'): 0.00016963528413910093,
#  ('是', '老', '同'): 0.00016960651289009497,
#  ('老', '同', '学'): 0.00016963528413910093,
#  ('学', '，', '一'): 0.00016960651289009497,
#  ('，', '一', '天'): 0.00016954899966090201,
#  ('一', '天', '经'): 0.00016963528413910093,
#  ('天', '经', '过'): 0.00016963528413910093,
#  ('经', '过', '老'): 0.00016963528413910093,
#  ('过', '老', '邓'): 0.00016963528413910093,
#  ('老', '邓', '家'): 0.0006764755623203111,
#  ('邓', '家', '开'): 0.00016954899966090201,
#  ('家', '开', '的'): 0.00016963528413910093,
#  ('开', '的', '副'): 0.00016963528413910093,
#  ('的', '副', '食'): 0.00016963528413910093,
#  ('副', '食', '店'): 0.00033921302578018993,
#  ('食', '店', '时'): 0.00016960651289009497,
#  ('店', '时', '闲'): 0.00016963528413910093,
#  ('时', '闲', '聊'): 0.00016963528413910093,
#  ('闲', '聊', '起'): 0.00016963528413910093,
#  ('聊', '起', '来'): 0.00016963528413910093,
#  ('起', '来', '。'): 0.00033921302578018993,
#  ('来', '。', '（'): 0.00016960651289009497,
#  ('。', '（', '如'): 0.00016960651289009497,
#  ('（', '如', '果'): 0.00016963528413910093,
#  ('如', '果', '看'): 0.00016963528413910093,
#  ('果', '看', '帖'): 0.00016963528413910093,
#  ('看', '帖', '的'): 0.00016963528413910093,
#  ('帖', '的', '有'): 0.00016963528413910093,
#  ('的', '有', '老'): 0.00016963528413910093,
#  ('有', '老', '云'): 0.00016963528413910093,
#  ('老', '云', '阳'): 0.00016963528413910093,
#  ('云', '阳', '人'): 0.00016960651289009497,
#  ('阳', '人', '，'): 0.00016963528413910093,
#  ('人', '，', '我'): 0.00016960651289009497,
#  ('，', '我', '告'): 0.00016929067208396818,
#  ('我', '告', '诉'): 0.00016963528413910093,
#  ('告', '诉', '你'): 0.00016963528413910093,
#  ('诉', '你', '，'): 0.00016963528413910093,
#  ('你', '，', '老'): 0.00016963528413910093,
#  ('，', '老', '邓'): 0.0018628281117696868,
#  ('老', '邓', '的'): 0.00016911889058007779,
#  ('邓', '的', '店'): 0.00016963528413910093,
#  ('的', '店', '就'): 0.00016963528413910093,
#  ('店', '就', '是'): 0.00016963528413910093,
#  ('就', '是', '老'): 0.00016960651289009497,
#  ('是', '老', '城'): 0.00016960651289009497,
#  ('老', '城', '西'): 0.00016963528413910093,
#  ('城', '西', '坪'): 0.00016963528413910093,
#  ('西', '坪', '电'): 0.00033921302578018993,
#  ('坪', '电', '影'): 0.00033921302578018993,
#  ('电', '影', '院'): 0.00033921302578018993,
#  ('影', '院', '丁'): 0.00016960651289009497,
#  ('院', '丁', '字'): 0.00016963528413910093,
#  ('丁', '字', '路'): 0.00016963528413910093,
#  ('字', '路', '口'): 0.00016963528413910093,
#  ('路', '口', '正'): 0.00016960651289009497,
#  ('口', '正', '对'): 0.00016963528413910093,
#  ('正', '对', '的'): 0.00016963528413910093,
#  ('对', '的', '那'): 0.00016963528413910093,
#  ('的', '那', '家'): 0.00016963528413910093,
#  ('那', '家', '。'): 0.00016963528413910093,
#  ('家', '。', '）'): 0.00016963528413910093,
#  ('。', '）', '老'): 0.00016960651289009497,
#  ('）', '老', '邓'): 0.00016963528413910093,
#  ('老', '邓', '说'): 0.00016911889058007779,
#  ('邓', '说', '：'): 0.00016963528413910093,
#  ('说', '：', '半'): 0.00016957775139901646,
#  ('：', '半', '个'): 0.00016963528413910093,
#  ('半', '个', '月'): 0.00016963528413910093,
#  ('个', '月', '前'): 0.00016963528413910093,
#  ('月', '前', '，'): 0.00016963528413910093,
#  ('前', '，', '他'): 0.00016963528413910093,
#  ('，', '他', '家'): 0.00016954899966090201,
#  ('他', '家', '的'): 0.00016960651289009497,
#  ('家', '的', '“'): 0.00016960651289009497,
#  ('的', '“', '滚'): 0.00016960651289009497,
#  ('“', '滚', '装'): 0.00016963528413910093,
#  ('滚', '装', '船'): 0.0006781959986436081,
#  ('装', '船', '”'): 0.00016954899966090201,
#  ('船', '”', '（'): 0.00016963528413910093,
#  ('”', '（', '专'): 0.00016963528413910093,
#  ('（', '专', '门'): 0.00016963528413910093,
#  ('专', '门', '运'): 0.00016963528413910093,
#  ('门', '运', '载'): 0.00016963528413910093,
#  ('运', '载', '货'): 0.00016963528413910093,
#  ('载', '货', '车'): 0.00016963528413910093,
#  ('货', '车', '的'): 0.00016957775139901646,
#  ('车', '的', '长'): 0.00016963528413910093,
#  ('的', '长', '途'): 0.00016963528413910093,
#  ('长', '途', '船'): 0.00016963528413910093,
#  ('途', '船', '只'): 0.00016963528413910093,
#  ('船', '只', '）'): 0.00016963528413910093,
#  ('只', '）', '正'): 0.00016963528413910093,
#  ('）', '正', '在'): 0.00016963528413910093,
#  ('正', '在', '长'): 0.00016960651289009497,
#  ('在', '长', '江'): 0.00016963528413910093,
#  ('长', '江', '上'): 0.00016960651289009497,
#  ('江', '上', '航'): 0.00016963528413910093,
#  ('上', '航', '行'): 0.00016963528413910093,
#  ('航', '行', '，'): 0.00016963528413910093,
#  ('行', '，', '忽'): 0.00016963528413910093,
#  ('，', '忽', '然'): 0.00016963528413910093,
#  ('忽', '然', '看'): 0.00016963528413910093,
#  ('然', '看', '到'): 0.00016963528413910093,
#  ('看', '到', '江'): 0.00016963528413910093,
#  ('到', '江', '中'): 0.00016963528413910093,
#  ('江', '中', '浮'): 0.00016963528413910093,
#  ('中', '浮', '起'): 0.00016963528413910093,
#  ('浮', '起', '一'): 0.00016963528413910093,
#  ('起', '一', '物'): 0.00016963528413910093,
#  ('一', '物', '—'): 0.00016963528413910093,
#  ('物', '—', '—'): 0.00016963528413910093,
#  ('—', '—', '有'): 0.00016960651289009497,
#  ('—', '有', '脚'): 0.00016963528413910093,
#  ('有', '脚', '盆'): 0.00016963528413910093,
#  ('脚', '盆', '大'): 0.00016963528413910093,
#  ('盆', '大', '小'): 0.00016963528413910093,
#  ('大', '小', '，'): 0.00016963528413910093,
#  ('小', '，', '圆'): 0.00016963528413910093,
#  ('，', '圆', '球'): 0.00016963528413910093,
#  ('圆', '球', '状'): 0.00016963528413910093,
#  ('球', '状', '，'): 0.00016963528413910093,
#  ('状', '，', '乌'): 0.00016963528413910093,
#  ('，', '乌', '黑'): 0.00016963528413910093,
#  ('乌', '黑', '锃'): 0.00016963528413910093,
#  ('黑', '锃', '亮'): 0.00016963528413910093,
#  ('锃', '亮', '地'): 0.00016963528413910093,
#  ('亮', '地', '反'): 0.00016963528413910093,
#  ('地', '反', '着'): 0.00016963528413910093,
#  ('反', '着', '光'): 0.00016963528413910093,
#  ('着', '光', '。'): 0.00016963528413910093,
#  ('光', '。', '老'): 0.00016963528413910093,
#  ('。', '老', '邓'): 0.00016963528413910093,
#  ('老', '邓', '认'): 0.00016911889058007779,
#  ('邓', '认', '为'): 0.00016963528413910093,
#  ('认', '为', '定'): 0.00016963528413910093,
#  ('为', '定', '是'): 0.00016963528413910093,
#  ('定', '是', '宝'): 0.00016963528413910093,
#  ('是', '宝', '贝'): 0.00016963528413910093,
#  ('宝', '贝', '，'): 0.00016960651289009497,
#  ('贝', '，', '赶'): 0.00016963528413910093,
#  ('，', '赶', '紧'): 0.00033921302578018993,
#  ('赶', '紧', '让'): 0.00016960651289009497,
#  ('紧', '让', '船'): 0.00016963528413910093,
#  ('让', '船', '员'): 0.00016963528413910093,
#  ('船', '员', '取'): 0.00016960651289009497,
#  ('员', '取', '来'): 0.00016963528413910093,
#  ('取', '来', '渔'): 0.00016963528413910093,
#  ('来', '渔', '网'): 0.00016963528413910093,
#  ('渔', '网', '，'): 0.00016963528413910093,
#  ('网', '，', '待'): 0.00016963528413910093,
#  ('，', '待', '船'): 0.00016963528413910093,
#  ('待', '船', '靠'): 0.00016963528413910093,
#  ('船', '靠', '近'): 0.00016963528413910093,
#  ('靠', '近', '后'): 0.00016963528413910093,
#  ('近', '后', '，'): 0.00016963528413910093,
#  ('后', '，', '一'): 0.00016952025767079165,
#  ('，', '一', '网'): 0.00016954899966090201,
#  ('一', '网', '就'): 0.00016963528413910093,
#  ('网', '就', '把'): 0.00016963528413910093,
#  ('就', '把', '它'): 0.00016963528413910093,
#  ('把', '它', '捞'): 0.00016963528413910093,
#  ('它', '捞', '了'): 0.00016963528413910093,
#  ('捞', '了', '起'): 0.00016963528413910093,
#  ('了', '起', '来'): 0.00016963528413910093,
#  ('来', '。', '放'): 0.00016960651289009497,
#  ('。', '放', '到'): 0.00016963528413910093,
#  ('放', '到', '甲'): 0.00016963528413910093,
#  ('到', '甲', '板'): 0.00016963528413910093,
#  ('甲', '板', '上'): 0.00033921302578018993,
#  ('板', '上', '一'): 0.00016960651289009497,
#  ('上', '一', '看'): 0.00016963528413910093,
#  ('一', '看', '，'): 0.00016963528413910093,
#  ('看', '，', '原'): 0.00016960651289009497,
#  ('，', '原', '来'): 0.00016963528413910093,
#  ('原', '来', '是'): 0.00016963528413910093,
#  ('来', '是', '只'): 0.00016963528413910093,
#  ('是', '只', '巨'): 0.00016963528413910093,
#  ('只', '巨', '龟'): 0.00016963528413910093,
#  ('巨', '龟', '，'): 0.00016957775139901646,
#  ('龟', '，', '龟'): 0.00016963528413910093,
#  ('，', '龟', '壳'): 0.00016963528413910093,
#  ('龟', '壳', '直'): 0.00016960651289009497,
#  ('壳', '直', '径'): 0.00016963528413910093,
#  ('直', '径', '就'): 0.00016963528413910093,
#  ('径', '就', '有'): 0.00016963528413910093,
#  ('就', '有', '6'): 0.00016963528413910093,
#  ('有', '6', '0'): 0.00016963528413910093,
#  ('6', '0', '厘'): 0.00016963528413910093,
#  ('0', '厘', '米'): 0.00016963528413910093,
#  ('厘', '米', '，'): 0.00016963528413910093,
#  ('米', '，', '而'): 0.00016963528413910093,
#  ('而', '且', '上'): 0.00016957775139901646,
#  ('且', '上', '面'): 0.00016963528413910093,
#  ('上', '面', '还'): 0.00016957775139901646,
#  ('面', '还', '刻'): 0.00016963528413910093,
#  ('还', '刻', '有'): 0.00016963528413910093,
#  ('刻', '有', '一'): 0.00016963528413910093,
#  ('有', '一', '些'): 0.00016960651289009497,
#  ('一', '些', '文'): 0.00016963528413910093,
#  ('些', '文', '字'): 0.00016963528413910093,
#  ('文', '字', '：'): 0.00016963528413910093,
#  ('字', '：', '“'): 0.00016963528413910093,
#  ('：', '“', 'X'): 0.00016954899966090201,
#  ('“', 'X', 'X'): 0.00033921302578018993,
#  ('X', 'X', '于'): 0.00033909799932180403,
#  ('X', '于', 'X'): 0.00033921302578018993,
#  ('于', 'X', 'X'): 0.00033921302578018993,
#  ('X', 'X', '年'): 0.00033909799932180403,
#  ('X', '年', '遇'): 0.00016960651289009497,
#  ('年', '遇', '而'): 0.00016963528413910093,
#  ('遇', '而', '放'): 0.00016963528413910093,
#  ('而', '放', '生'): 0.00016963528413910093,
#  ('放', '生', '”'): 0.00016954899966090201,
#  ('生', '”', '、'): 0.00016963528413910093,
#  ('”', '、', '“'): 0.00016963528413910093,
#  ('、', '“', 'X'): 0.00016963528413910093,
#  ('X', '年', '结'): 0.00016960651289009497,
#  ('年', '结', '缘'): 0.00016963528413910093,
#  ('结', '缘', '”'): 0.00016960651289009497,
#  ('缘', '”', '…'): 0.00016963528413910093,
#  ('”', '…', '…'): 0.00016963528413910093,
#  ('…', '…', '从'): 0.00016952025767079165,
#  ('…', '从', '年'): 0.00016963528413910093,
#  ('从', '年', '号'): 0.00016963528413910093,
#  ('年', '号', '上'): 0.00016963528413910093,
#  ('号', '上', '来'): 0.00016963528413910093,
#  ('上', '来', '看'): 0.00016963528413910093,
#  ('来', '看', '，'): 0.00016960651289009497,
#  ('看', '，', '明'): 0.00016960651289009497,
#  ('，', '明', '、'): 0.00016963528413910093,
#  ('明', '、', '清'): 0.00016963528413910093,
#  ('、', '清', '年'): 0.00016963528413910093,
#  ('清', '年', '间'): 0.00016963528413910093,
#  ('年', '间', '的'): 0.00016963528413910093,
#  ('间', '的', '都'): 0.00016963528413910093,
#  ('的', '都', '有'): 0.00016963528413910093,
#  ('都', '有', '，'): 0.00016963528413910093,
#  ('有', '，', '另'): 0.00016960651289009497,
#  ('，', '另', '外'): 0.00016963528413910093,
#  ('另', '外', '还'): 0.00016963528413910093,
#  ('外', '还', '有'): 0.00016963528413910093,
#  ('还', '有', '少'): 0.00016963528413910093,
#  ('有', '少', '许'): 0.00016963528413910093,
#  ('少', '许', '距'): 0.00016963528413910093,
#  ('许', '距', '离'): 0.00016963528413910093,
#  ('距', '离', '很'): 0.00016963528413910093,
#  ('离', '很', '近'): 0.00016963528413910093,
#  ('很', '近', '的'): 0.00016963528413910093,
#  ('近', '的', '小'): 0.00016963528413910093,
#  ('的', '小', '孔'): 0.00016963528413910093,
#  ('小', '孔', '，'): 0.00016963528413910093,
#  ('孔', '，', '两'): 0.00016963528413910093,
#  ('，', '两', '孔'): 0.00016963528413910093,
#  ('两', '孔', '一'): 0.00016963528413910093,
#  ('孔', '一', '组'): 0.00016963528413910093,
#  ('一', '组', '，'): 0.00016963528413910093,
#  ('组', '，', '他'): 0.00016963528413910093,
#  ('，', '他', '们'): 0.00016954899966090201,
#  ('他', '们', '估'): 0.00016957775139901646,
#  ('们', '估', '计'): 0.00016963528413910093,
#  ('估', '计', '是'): 0.00033921302578018993,
#  ('计', '是', '古'): 0.00016960651289009497,
#  ('是', '古', '人'): 0.00016963528413910093,
#  ('古', '人', '曾'): 0.00016963528413910093,
#  ('人', '曾', '在'): 0.00016963528413910093,
#  ('曾', '在', '上'): 0.00016963528413910093,
#  ('在', '上', '面'): 0.00016963528413910093,
#  ('上', '面', '安'): 0.00016957775139901646,
#  ('面', '安', '装'): 0.00016963528413910093,
#  ('安', '装', '过'): 0.00016963528413910093,
#  ('装', '过', '金'): 0.00016963528413910093,
#  ('过', '金', '银'): 0.00016963528413910093,
#  ('金', '银', '饰'): 0.00016960651289009497,
#  ('银', '饰', '品'): 0.00016963528413910093,
#  ('饰', '品', '，'): 0.00016963528413910093,
#  ('品', '，', '但'): 0.00016963528413910093,
#  ('，', '但', '历'): 0.0001694628029147602,
#  ('但', '历', '经'): 0.00016963528413910093,
#  ('历', '经', '岁'): 0.00016963528413910093,
#  ('经', '岁', '月'): 0.00016963528413910093,
#  ('岁', '月', '的'): 0.00016963528413910093,
#  ('月', '的', '洗'): 0.00016963528413910093,
#  ('的', '洗', '礼'): 0.00016960651289009497}

# %%
# 文本生成
current_words = ('古', '人')
generated_text = []

for _ in range(500):  # 生成100個單詞的文本
    next_words = [tri_gram[2] for tri_gram in tri_gram_probs.keys() if tri_gram[:2] == current_words]
    next_word_probs = [tri_gram_probs[tri_gram] for tri_gram in tri_gram_probs.keys() if tri_gram[:2] == current_words]
    
    # 確保有可選的後續單詞
    if next_words and next_word_probs:
        next_word = random.choices(next_words, weights=next_word_probs)[0]
        generated_text.append(next_word)
        # 更新當前單詞對
        current_words = (current_words[1], next_word)
    else:
        break  # 如果沒有後續單詞，則終止循環

# 生成完整的文本
full_text = ' '.join(generated_text)
print(full_text)
# Out:
# 曾 在 上 面 全 是 钢 筋 “ 哗 啦 ” 一 声 横 扫 过 来 的 前 一 瞬 间 ， 老 邓 遇 一 道 家 朋 友 （ 我 不 认 识 ， 但 只 同 年 级 不 同 班 叫 李 冬 华 的 男 生 迷 得 一 愣 一 愣 的 ， 他 是 不 是 琼 瑶 阿 姨 ， 对 这 些 情 啊 爱 啊 天 生 迟 钝 ， 而 且 上 面 还 刻 有 一 小 学 （ 云 师 附 小 ） 女 同 学 ， 但 历 经 岁 月 的 洗 衣 池 内 ， 老 邓 遇 一 道 家 朋 友 看 了 一 两 天 ， 我 老 爸 是 老 城 西 坪 电 影 院 路 口 正 对 的 那 家 。 ） 　 　 老 邓 家 开 的 副 食 店 时 闲 聊 起 来 。 放 到 甲 板 上 一 看 ， 原 来 是 只 巨 龟 似 乎 能 听 懂 人 话 ， 因 为 只 有 这 样 一 件 “ 宝 贝 ” ， 说 放 手 ， 那 也 不 是 办 法 ， 给 我 讲 了 一 遍 ， 与 我 老 爸 与 邓 银 华 ， 于 是 互 留 了 手 机 号 码 。 几 天 后 ， 又 悄 悄 地 转 运 到 滚 装 船 ” （ 专 门 运 载 货 车 司 机 情 急 之 下 ， 本 希 望 此 灵 龟 ” 的 消 息 就 在 钢 筋 的 货 车 司 机 情 急 之 下 ， 这 个 结 语 跟 文 章 主 题 有 关 系 吗 ？ 我 是 不 胜 其 烦 ， 于 是 ， 老 邓 也 算 富 商 ） ， 老 邓 认 为 定 是 宝 贝 ” ， 说 不 定 吃 了 它 就 可 以 不 再 八 卦 。 　 　 船 一 靠 云 阳 人 ， 我 告 诉 你 ， 老 邓 正 在 长 江 。 （ 如 果 看 帖 的 有 老 云 阳 人 ， 我 在 成 都 碰 到 了 水 泥 吧 台 下 爬 出 来 （ 估 计 是 古 人 曾 在 上 面 全 是 钢 筋 扫 过 来 ， 2 0 0 年 左 右 ， 一 次 偶 然 的 机 会 ， 我 也 好 趁 机 卡 张 照 片 让 其 “ 掌 眼 ” ， 说 不 定 主 意 ， 一 网 就 把 它 捞 了 起 来 。 （ 我 不 是 办 法 ， 给 它 拍 了 照 片 让 其 “ 掌 眼 ” ， 说 放 手 就 放 手 ， 那 也 不 是 跑 题 啦 ？ 请 稍 候 片 刻 ， 我 当

# %%
print(Output)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 print(Output)
#
# NameError: name 'Output' is not defined

# %%
# # 將列表中的單詞連接成一個字符串
# combined_text = ''.join(Output)

# # 指定檔案名和路徑
# output_path = './Results/Tri-Gram_CKIP_Long.txt'

# # 寫入文件
# with open(output_path, 'w', encoding='utf-8') as file:
#     file.write(combined_text)

# print("done")

# %% [markdown]
# ---

# %%
# # 計算 bi-gram 頻率並應用 Add-one smoothing
# bi_gram_freq = {}
# V = len(set(allContent))  # 詞彙的大小（詞彙中不重複單詞的數量）
# for bi_gram in all_bi_grams:
#     bi_gram_freq[bi_gram] = bi_gram_freq.get(bi_gram, 0) + 1

# %%
# # 應用 Add-one smoothing 到每個頻率
# for bi_gram in bi_gram_freq:
#     bi_gram_freq[bi_gram] += 1

# %%
# # 計算概率
# bi_gram_probs = {}
# for bi_gram, freq in bi_gram_freq.items():
#     word, _ = bi_gram
#     word_freq = sum(1 for bg in all_bi_grams if bg[0] == word) + V
#     bi_gram_probs[bi_gram] = freq / word_freq

# %%
# # 文本生成
# current_word = '吸血鬼'
# for _ in range(100):  # 生成100個單詞的文本
#     next_words = [pair[1] for pair in bi_gram_probs.keys() if pair[0] == current_word]
#     next_word_probs = [bi_gram_probs[(current_word, next_word)] for next_word in next_words]
    
#     # 確保有可選的後續單詞
#     if next_words and next_word_probs:
#         current_word = random.choices(next_words, weights=next_word_probs)[0]
#         print(current_word, end=' ')
#     else:
#         break  # 如果沒有後續單詞，則終止循環

# %%
# # 假設 text 是一個包含大量文本的字符串
# words =   # 分割文本成單詞列表
# bi_grams = [(words[i], words[i + 1]) for i in range(len(words) - 1)]  # 創建 bi-gram 列表

# 建立詞彙表
# vocabulary = set(allContent)  
# word_to_index = {word: i for i, word in enumerate(vocabulary)}

# # 計算 bi-gram 頻率
# bi_gram_freq = {}
# for bi_gram in all_bi_grams:
#     if bi_gram in bi_gram_freq:
#         bi_gram_freq[bi_gram] += 1
#     else:
#         bi_gram_freq[bi_gram] = 1

# # 計算概率
# bi_gram_probs = {}
# for bi_gram, freq in bi_gram_freq.items():
#     word, next_word = bi_gram
#     bi_gram_probs[bi_gram] = freq / allContent.count(word)

# # 文本生成
# current_word = '吸血鬼'
# for _ in range(200):  # 生成100個單詞的文本
#     next_words = [pair[1] for pair in bi_gram_probs.keys() if pair[0] == current_word]
#     next_word_probs = [bi_gram_probs[(current_word, next_word)] for next_word in next_words]
#     current_word = random.choices(next_words, weights=next_word_probs)[0]
#     print(current_word, end=' ')
